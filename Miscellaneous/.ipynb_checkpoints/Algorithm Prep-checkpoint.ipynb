# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats
import math

# %%
data = pd.read_csv('Cleaned_Data.csv')
data.head(5)
# Out:
# C:\Users\alvin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (15,17,19,21,23,25,27,29,31,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Full Name  Last Name  Grad Year Position   Height   Height Source  \
# 0   Korey Foreman    Foreman       2021       DE    6' 4"    nike_opening
# 1  J.T. Tuimoloau  Tuimoloau       2021       DE    6' 4"  national_preps
# 2       JC Latham     Latham       2021       OT    6' 6"  national_preps
# 3    Emeka Egbuka     Egbuka       2021       WR  6' 0.5"    nike_opening
# 4   Dallas Turner     Turner       2021       DE  6' 2.5"     rivals_camp
#
#    Weight   Weight Source  Zcruit Rating Committed To  ...  Hand Size Source  \
# 0   248.0    nike_opening        96.6970          USC  ...               NaN
# 1   275.0  national_preps        96.6970          NaN  ...               NaN
# ...

# %%
import re

vals = data["Height"].values
for element in vals:
    z = re.match("^(\d)'\s*(\d*\.*\d*)", element)
    if z:
        print((z.groups()))
# Out:
# ('6', '4')
# ('6', '4')
# ('6', '6')
# ('6', '0.5')
# ('6', '2.5')
# ('6', '4.5')
# ('6', '5.5')
# ('6', '4')
# ('6', '1')
# ('6', '1')
# ('6', '4.5')
# ('6', '5.25')
# ('6', '5')
# ('6', '6')
# ('6', '2')
# ('6', '5')
# ('6', '2')
# ('6', '4')
# ('6', '8')
# ('6', '4')
# ('5', '10.75')
# ('6', '0.25')
# ('6', '0')
# ('5', '11')
# ('6', '4.5')
# ('6', '0')
# ('5', '11.75')
# ('6', '2')
# ('5', '10.5')
# ('6', '3.25')
# ('5', '11')
# ('6', '1')
# ('6', '4.75')
# ('5', '10')
# ('6', '5.5')
# ('6', '0')
# ('6', '5')
# ('6', '2')
# ('6', '2')
# ('6', '2')
# ('6', '2')
# ('6', '2')
# ('5', '10')
# ('6', '3.5')
# ('5', '9.25')
# ('5', '11')
# ('6', '4')
# ('6', '3')
# ('5', '9.5')
# ('6', '3')
# ('6', '4.5')
# ('5', '7')
# ('6', '0.5')
# ('6', '5.5')
# ('6', '3')
# ('6', '0')
# ('6', '2')
# ('6', '1')
# ('6', '4')
# ('6', '5')
# ('6', '1')
# ('6', '2')
# ('6', '5')
# ('6', '3')
# ('6', '0.5')
# ('6', '1')
# ('6', '3')
# ('6', '3.5')
# ('5', '9')
# ('6', '2.25')
# ('6', '0')
# ...

# %%
height_regex = "^(\d)'\s*(\d*\.*\d*)"
def height_str_to_val(height_str):
    match = re.match("^(\d)'\s*(\d*\.*\d*)", height_str)
    groups = match.groups()
    feet, inches = int(groups[0]), float(groups[1])
    return feet * 12 + inches

# %%
data['Height'] = data['Height'].apply(height_str_to_val)

# %% [markdown]
# DB - Height, Weight, Forty Yard Dash, Shuttle, 3 Cone, Vertical Jump

# %%
cb = data[data['Position'] == 'CB']
cb = cb[['Full Name', 'Position', 'Height', 'Weight', 'Forty Yard Dash', 'Shuttle', '3 Cone', 'Vertical Jump']]
cb.head(20)
# Out:
#              Full Name Position  Height  Weight  Forty Yard Dash  Shuttle  \
# 22      Domani Jackson       CB   72.00   181.0            4.510    4.250
# 25      Jason Marshall       CB   72.00   167.5            4.590      NaN
# 26      Terrion Arnold       CB   71.75   175.0            4.560      NaN
# 31   Jaheim Singletary       CB   73.00   172.5            4.620      NaN
# 35       Travis Hunter       CB   72.00   165.0              NaN      NaN
# 38     William Johnson       CB   74.00   180.0              NaN      NaN
# 55    Jakailin Johnson       CB   72.00   170.0            4.500      NaN
# 60        Nyland Green       CB   73.00   172.0            4.610      NaN
# 76      Jordan Hancock       CB   72.00   158.5            4.630      NaN
# 90     Khamauri Rogers       CB   71.00   143.0              NaN      NaN
# 108    Daylen Everette       CB   73.00   180.0              NaN      NaN
# 156      Sharif Denson       CB   70.00   160.0            4.600      NaN
# ...

# %%
def create_percentile(position, event):
    """Take in a position - CB, WR, QB, etc. and an event - Fourty Yard Dash, Weight, 3 Cone and return a list of percentile values
        of 0, 10th, ... 100th percentile. Reverse for all speed events (lower is better) such as 40, 3 Cone, and Shuttle."""
    sorted_athletes = data[data['Position'] == position]     
    event_values = (sorted_athletes[event].astype(float)).dropna()
    percentile = []
    for i in np.arange(0, 1.01, 0.01):
        percentile.append(event_values.quantile(i))
    if (event == "Forty Yard Dash") or (event == "Shuttle") or (event == "3 Cone"):
        return percentile[::-1]
    return percentile

# %% [markdown]
# Input 1: [89.0, 130.0, 139.0, 145.0, 150.0, 156.5, 160.0, 165.5, 170.0, 180.0, 287.0]
# Input 2: 181
#
# 181 falls into the 90th percentile -> score: 9

# %%
def value_to_score(event, value):
    if (event == "Forty Yard Dash") or (event == "Shuttle") or (event == "3 Cone"):
        return round(((100 - scipy.stats.percentileofscore(metric_dict[event], value, kind='rank')) / 10), 2)
    else:
        return round(((scipy.stats.percentileofscore(metric_dict[event], value, kind='rank')) / 10), 1)

# %%
metric_dict = {}
for metric in cb.columns[2:8]:
    metric_dict[metric] = create_percentile('CB', metric)

# %%
metric_dict
# Out:
# {'Height': [57.0,
#   62.0,
#   63.0,
#   64.0,
#   64.0,
#   64.0,
#   65.0,
#   65.0,
#   65.0,
#   65.1875,
#   66.0,
#   66.0,
#   66.0,
#   66.0,
#   66.0,
#   66.0,
#   66.0,
#   67.0,
#   67.0,
#   67.0,
#   67.0,
#   67.0,
#   67.0,
#   67.0,
#   67.0,
#   67.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   68.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.0,
#   69.5,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.0,
#   70.5,
#   71.0,
#   71.0,
#   71.0,
#   71.0,
#   71.0,
#   71.0,
#   71.0,
#   71.0,
#   71.0,
#   71.0,
#   71.0,
#   71.75,
#   72.0,
#   72.0,
#   72.0,
#   72.0,
#   72.0,
#   72.0,
#   72.0,
#   72.0,
#   72.0,
#   73.0,
#   73.0,
#   73.0,
#   73.0,
#   73.0,
#   73.5,
#   74.0,
# ...

# %%
def add_score(metric, data):
    data = data.dropna()
    data[metric + " " + "Score"] = data.apply(lambda x: value_to_score(metric, x[metric]), axis = 1)
    return data

# %%
data_new = cb
chosen_metrics = data_new.columns[2:8]
for metric in chosen_metrics:
    data_new = add_score(metric, data_new)
# Out:
# <ipython-input-414-dd2af720b2aa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric + " " + "Score"] = data.apply(lambda x: value_to_score(metric, x[metric]), axis = 1)

# %%
data_new.head(20)
# Out:
#               Full Name Position  Height  Weight  Forty Yard Dash  Shuttle  \
# 231      Shawn Russ Jr.       CB   72.00   168.0            5.027    4.555
# 296    Antonio Robinson       CB   67.75   151.5            5.097    4.434
# 411        Jaden Mickey       CB   66.00   130.0            5.120    4.348
# 412     Marcus Scott II       CB   72.00   145.0            4.910    5.900
# 497      Omarion Cooper       CB   71.50   168.0            4.967    4.955
# 499     Jaylin Marshall       CB   73.00   173.0            4.590    4.873
# 534      Trevell Mullen       CB   71.00   145.5            4.794    4.886
# 566         Fabian Ross       CB   71.00   193.0            4.660    4.451
# 575       Kaleb Higgins       CB   73.25   185.5            4.846    4.218
# 634         Ryan Barnes       CB   68.00   136.0            5.044    4.477
# 655       Camron Miller       CB   72.00   169.0            4.635    4.373
# ...

# %%
scores = [x + " " + "Score" for x in chosen_metrics]
scores
# Out:
# ['Height Score',
#  'Weight Score',
#  'Forty Yard Dash Score',
#  'Shuttle Score',
#  '3 Cone Score',
#  'Vertical Jump Score']

# %%
data_score_only = data_new[["Full Name", "Position"] + scores]
data_score_only.head(20)
# Out:
#               Full Name Position  Height Score  Weight Score  \
# 231      Shawn Russ Jr.       CB           8.6           7.2
# 296    Antonio Robinson       CB           2.6           4.2
# 411        Jaden Mickey       CB           1.4           1.1
# 412     Marcus Scott II       CB           8.6           3.1
# 497      Omarion Cooper       CB           8.0           7.2
# 499     Jaylin Marshall       CB           9.3           8.2
# 534      Trevell Mullen       CB           7.5           3.2
# 566         Fabian Ross       CB           7.5           9.8
# 575       Kaleb Higgins       CB           9.5           9.6
# 634         Ryan Barnes       CB           3.3           1.8
# 655       Camron Miller       CB           8.6           7.3
# 683     Adontae Balfour       CB           8.6           3.5
# 684   Tar'varish Dawson       CB           4.6           3.6
# 723     Darian Chestnut       CB           5.3           9.2
# ...

# %% [markdown]
# Generate a score report for all the players at a chosen position with chosen metrics.
#
# 1. Make sure heights are cleaned. Drop NAs?
# 2. Run the percentile, value_to_score, and add_score functions

# %%
type(data['Height'].values[0]) == np.float64
# Out:
# True

# %%
if type(data['Height'].values[0]) != np.float64:
    data['Height'] = data['Height'].apply(height_str_to_val)

def create_percentile(position, event):
    """Take in a position - CB, WR, QB, etc. and an event - Fourty Yard Dash, Weight, 3 Cone and return a list of percentile values
        of 0, 10th, ... 100th percentile. Reverse for all speed events (lower is better) such as 40, 3 Cone, and Shuttle."""
    sorted_athletes = data[data['Position'] == position]     
    event_values = (sorted_athletes[event].astype(float)).dropna()
    percentile = []
    for i in np.arange(0, 1.01, 0.01):
        percentile.append(event_values.quantile(i))
    if (event == "Forty Yard Dash") or (event == "Shuttle") or (event == "3 Cone"):
        return percentile[::-1]
    return percentile 

def value_to_score(event, value):
    """Take in an event - Fourty Yard Dash, Weight, etc and player's value and generate player's score for that event using 
    the percentiles for that event for their position."""
    if (event == "Forty Yard Dash") or (event == "Shuttle") or (event == "3 Cone"):
        return round(((100 - scipy.stats.percentileofscore(metric_dict[event], value, kind='rank')) / 10), 2)
    else:
        return round(((scipy.stats.percentileofscore(metric_dict[event], value, kind='rank')) / 10), 2)
    
def add_score(metric, data):
    #data = data.dropna()
    print(data.shape)
    data[metric + " " + "Score"] = data.apply(lambda x: value_to_score(metric, x[metric]), axis = 1)
    return data

def data_representation_for_algorithm(data, position, metric_list):
    #Only work with players at given position
    data = data[data['Position'] == position]
    data.dropna()
    
    #Generate percentiles for each metric at respective position
    metric_dict = {}
    for metric in metric_list:
        metric_dict[metric] = create_percentile(position, metric)
    print(metric_dict['Wingspan'])
    
    #Given percentiles, generate scores for each player's metrics at chosen position. 
    #For example, if player's height is in 82nd percentile for position, the player's score should be rougly 8.2 for Height
    print(data.shape)
    print(round(((scipy.stats.percentileofscore(metric_dict['Wingspan'], 80, kind='rank')) / 10), 2))
    data_scores = data[["Full Name", "Position"] + metric_list]
    print(data_scores.shape)
    for metric in metric_list:
        data_scores = add_score(metric, data_scores)
    
    score_labels = [x + " " + "Score" for x in metric_list]
    data_score_only = data_scores[["Full Name", "Position"] + score_labels]
    return data_score_only

# %%
cb_metrics = ["Height", "Weight", "Forty Yard Dash", "Shuttle", "3 Cone"]

# %%
data_representation_for_algorithm(data, 'CB', cb_metrics)
# Out:
# dict_keys(['Height', 'Weight', 'Forty Yard Dash', 'Shuttle', '3 Cone'])
# (3976, 39)
# (3976, 7)
# (3976, 7)
# (3976, 8)
# (3976, 9)
# <ipython-input-472-7c654d2386c3>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric + " " + "Score"] = data.apply(lambda x: value_to_score(metric, x[metric]), axis = 1)
# (3976, 10)
# (3976, 11)
#                Full Name Position  Height Score  Weight Score  \
# 22        Domani Jackson       CB          8.61          9.41
# 25        Jason Marshall       CB          8.61          7.23
# 26        Terrion Arnold       CB          8.12          8.51
# 31     Jaheim Singletary       CB          9.31          8.12
# 35         Travis Hunter       CB          8.61          6.68
# ...

# %%
relevant_zcruit_metrics = ["Height", "Weight", "Wingspan", "Arm Length", "Hand Size", "Forty Yard Dash", "Shuttle", "3 Cone", "Vertical Jump", "Broad Jump", "Powerball Toss"]

# %%
data_relevant = data[["Full Name", "Position"] + relevant_zcruit_metrics]
data_relevant.head(5)
# Out:
#         Full Name Position  Height  Weight  Wingspan  Arm Length  Hand Size  \
# 0   Korey Foreman       DE    76.0   248.0       NaN         NaN        NaN
# 1  J.T. Tuimoloau       DE    76.0   275.0       NaN         NaN        NaN
# 2       JC Latham       OT    78.0   279.0       NaN         NaN        NaN
# 3    Emeka Egbuka       WR    72.5   190.0      75.0         NaN       9.00
# 4   Dallas Turner       DE    74.5   223.0      83.5       34.25       9.84
#
#    Forty Yard Dash  Shuttle  3 Cone  Vertical Jump  Broad Jump  Powerball Toss
# 0            4.880    4.700   7.758           30.4       104.0            44.5
# 1            4.750      NaN     NaN            NaN         NaN             NaN
# 2            5.460    4.870     NaN           26.8         NaN             NaN
# 3            4.859    4.200   7.083           35.1       112.0            41.0
# 4            4.991    4.487   7.752           26.0       115.0             NaN

# %% [markdown]
# DE - Height, Weight, Wingspan, Arm Length, Forty Yard Dash, Shuttle, Vertical Jump, Powerball Toss

# %%
de_metrics = ["Height", "Weight", "Wingspan", "Arm Length", "Forty Yard Dash", "Shuttle", "Vertical Jump", "Powerball Toss", "3 Cone"]

# %%
data_representation_for_algorithm(data, "DE", de_metrics)
# Out:
# [68.0, 70.97, 71.44, 72.0, 72.38, 73.0, 73.32, 73.5, 74.13, 74.25, 74.35, 74.5, 74.5, 74.75, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.0, 75.185, 75.5, 75.5, 75.5, 76.0, 76.0, 76.0, 76.0, 76.0, 76.0, 76.0, 76.27000000000001, 76.5, 76.5, 76.5, 76.5, 76.5, 76.68, 76.91499999999999, 77.0, 77.0, 77.0, 77.0, 77.0, 77.075, 77.25, 77.5, 77.5, 77.5, 77.5, 77.5, 77.94, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.0, 78.305, 78.5, 78.5, 78.5, 78.5, 78.98, 79.0, 79.0, 79.0, 79.0, 79.0, 79.0, 79.25, 79.5, 79.5, 79.58, 79.815, 80.0, 80.0, 80.0, 80.0, 80.0, 80.25, 80.5, 80.945, 81.0, 81.0, 81.0, 81.13499999999999, 81.25, 81.5, 81.67999999999999, 82.0, 82.11999999999999, 83.0, 83.06, 84.03, 85.0]
# (4229, 39)
# 8.22
# (4229, 11)
# (4229, 11)
# (4229, 12)
# (4229, 13)
# <ipython-input-481-0faed75baf67>:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
