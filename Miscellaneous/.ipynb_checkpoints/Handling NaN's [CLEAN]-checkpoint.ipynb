# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import re
import scipy.stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("ZCruit_Cleaned_Data.csv")
# Out:
# C:\Users\AlvinYu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (15,17,19,21,23,25,27,29,31,33) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
def height_str_to_val(height_str):
    match = re.match("^(\d)'\s*(\d*\.*\d*)", height_str)
    groups = match.groups()
    feet, inches = int(groups[0]), float(groups[1])
    return feet * 12 + inches

# %%
data['Height'] = data['Height'].apply(height_str_to_val)

# %%
def create_percentile(position, event):
    """Take in a position - CB, WR, QB, etc. and an event - Fourty Yard Dash, Weight, 3 Cone and return a list of percentile values of 0, 10th, ... 100th percentile. 
        Reverse for all speed events (lower is better) such as 40, 3 Cone, and Shuttle."""
    sorted_athletes = data[data['Position'] == position]     
    event_values = (sorted_athletes[event].astype(float)).dropna()
    percentile = []
    for i in np.arange(0, 1.01, 0.05):
        percentile.append(event_values.quantile(i))
    if (event == "Forty Yard Dash") or (event == "Shuttle") or (event == "3 Cone"):
        return percentile[::-1]
    return percentile

def value_to_percentile(event, value, metric_dict):
    if (event == "Forty Yard Dash") or (event == "Shuttle") or (event == "3 Cone"):
        return round((100 - scipy.stats.percentileofscore(metric_dict[event], value, kind='rank')), 2)
    else:
        return round((scipy.stats.percentileofscore(metric_dict[event], value, kind='rank')), 2)
    
def percentile_to_value(event, percentile, metric_dict):
    if (event == "Forty Yard Dash") or (event == "Shuttle") or (event == "3 Cone"):
        return scipy.stats.scoreatpercentile(metric_dict[event], 100 - percentile)
    else:
        return scipy.stats.scoreatpercentile(metric_dict[event], percentile)
        
def add_score(metric, data, metric_dict):
    # data = data.dropna()
    data[metric + " " + "Percentile"] = data.apply(lambda x: value_to_percentile(metric, x[metric], metric_dict), axis = 1)
    return data

def nan_counter(data, metrics):
    nan_dict, readable_dict = {}, {}
    for metric in metrics:
        nan_dict[metric] = data[metric].isna().sum() / data.shape[0]
        readable_dict[metric] = "There are {} NaNs out of {} players".format(data[metric].isna().sum(), data.shape[0])
    print(readable_dict)
    return nan_dict

def master_fillna(data, position, metrics):
    # Filtering data    
    data = data[data["Position"] == position]
    data_with_metrics = data[metrics]
    
    # Getting NaN information
    nan_info = nan_counter(data_with_metrics, metrics)
    
    # Classifying metrics into complete, incomplete, and drop
    complete_metric, incomplete_metric, drop_metric = [], [], []
    for metric in nan_info.keys():
        if nan_info[metric] == 0:
            complete_metric.append(metric)
        elif metric in ["Forty Yard Dash", "3 Cone", "Shuttle", "Vertical Jump", "Broad Jump", "Wingspan", "Arm Length","Hand Size", "Powerball Toss"]:
            incomplete_metric.append(metric)
        elif nan_info[metric] > 0.975:
            drop_metric.append(metric)
        else:
            incomplete_metric.append(metric)
    
    data_with_metrics = data_with_metrics.drop(columns = drop_metric)
    
    metric_dict = {}
    for metric in data_with_metrics.columns:
        metric_dict[metric] = create_percentile(position, metric)
    # We want to fill in the incomplete metrics
    completed_metrics = {}
    for metric in incomplete_metric:
        correlations = data_with_metrics.corr()[metric]
        correlations = correlations[correlations != 1].sort_values(ascending = False)
        metric_filter = correlations > 0.4 
        best_predictors = metric_filter[metric_filter].index.values

        print(metric, best_predictors)
    
    #IF there are no good predictors for linear regression (ie: no metrics with correlation > 0.4 with incomplete metric),
    #then we use the average approach. 
        if len(best_predictors) == 0:
            #For example, if we are predicting Hand Size with the average approach. We want the percentiles for Height, Weight, and Wingspan
            all_other_metrics = incomplete_metric + complete_metric
            all_other_metrics.remove(metric)
            
            all_other_percentiles = data_with_metrics.copy()
            for percentile_metrics in all_other_metrics:
                all_other_percentiles = add_score(percentile_metrics, all_other_percentiles, metric_dict)
                
            empty_metric = all_other_percentiles[all_other_percentiles[metric].isna()]
            full_metric = all_other_percentiles[all_other_percentiles[metric].notna()]
            
            metric_percentile_names =  [x + " " + "Percentile" for x in all_other_metrics]
            only_percentiles = empty_metric[metric_percentile_names]
            
            only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
            
            only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
            empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
            
            all_metric = empty_metric.append(full_metric).sort_index()
            
            completed_metrics[metric] = all_metric[metric].values
            #print(completed_metrics, len(completed_metrics[metric]), np.count_nonzero(~np.isnan(completed_metrics[metric])))

        else:
            full_metric = data_with_metrics[data_with_metrics[metric].notna()]
            empty_metric = data_with_metrics[data_with_metrics[metric].isna()]
            print("There are {} players with metric and {} NaNs.".format(full_metric.shape[0], empty_metric.shape[0]))
            labels = [best_predictors[0]] + [metric]
            predictor = best_predictors[0]
            print(labels)
            full_metric_with_no_predictor_nulls = full_metric[labels].dropna()
            X = full_metric_with_no_predictor_nulls[[predictor]]
            y = full_metric_with_no_predictor_nulls[metric]
            
            reg = LinearRegression(normalize = True).fit(X,y)
            metric_mean = np.median(y)
            
            empty_metric_with_no_predictor_nulls = empty_metric[[predictor]].dropna()
            if len(empty_metric_with_no_predictor_nulls) == 0:
                empty_metric_with_no_predictor_nulls[metric] = metric_mean
            else: 
                empty_metric_with_no_predictor_nulls[metric] = reg.predict(empty_metric_with_no_predictor_nulls)

            empty_metric_with_predictor_nulls = empty_metric[empty_metric[predictor].isna()]
            empty_metric_with_predictor_nulls[metric] = metric_mean
            
            print("There are {} players with a {} (predictor) value and {} players with NaNs for {}.".format(empty_metric_with_no_predictor_nulls.shape[0], best_predictors[0], empty_metric_with_predictor_nulls.shape[0], best_predictors[0]))
            print(empty_metric_with_no_predictor_nulls.shape[0] +  empty_metric_with_predictor_nulls.shape[0] == empty_metric.shape[0])

            empty_metric = empty_metric_with_no_predictor_nulls.append(empty_metric_with_predictor_nulls).sort_index()
            
            all_metric = empty_metric.append(full_metric).sort_index()
            
            completed_metrics[metric] = all_metric[metric].values
            
            train_y = reg.predict(X)
            train_error = mean_squared_error(y, train_y)
            print(reg.coef_)
            print("The RMSE of the model on the training data is {}. The average {} of the training data is {}. On average, predictions are {} from the actual values in the training data".format(np.sqrt(train_error), metric, np.mean(y), np.sqrt(train_error)/np.mean(y)))
            #print(completed_metrics, len(completed_metrics[metric]), np.count_nonzero(~np.isnan(completed_metrics[metric])))
    
    for metric in incomplete_metric:
        print(metric)
        print("There are {} NaN values for this metric".format(data[metric].isna().sum()))
        data[metric] = completed_metrics[metric]
        print("There are {} NaN values for this metric".format(data[metric].isna().sum()))
    
    all_metrics = ["Full Name", "Position"] + complete_metric + incomplete_metric
    cleaned_dataset = data[all_metrics]
    
    return cleaned_dataset

# %%
data[data['Position'] == 'RB']
# Out:
#                   Full Name     Last Name  Grad Year Position  Height  \
# 23            Camar Wheaton       Wheaton       2021       RB    71.0
# 28          Donovan Edwards       Edwards       2021       RB    70.5
# 41             Xavian Sorey         Sorey       2021       RB    74.0
# 45             Will Shipley       Shipley       2021       RB    71.0
# 48       TreVeyon Henderson     Henderson       2021       RB    69.5
# ...                     ...           ...        ...      ...     ...
# 71332        Cassius Sadler        Sadler       2021       RB    64.0
# 71339           Moses Perez         Perez       2023       RB    60.0
# 71346  Carmine D’Alessandro  D’Alessandro       2022       RB    65.0
# 71348        Al'jay Pipkins       Pipkins       2021       RB    61.0
# 71369         Eugene Thomas        Thomas       2022       RB    57.0
#
#         Height Source  Weight   Weight Source  Zcruit Rating Committed To  \
# 23     national_preps   190.0  national_preps        95.4848      Alabama
# 28       nike_opening   203.0    nike_opening        95.4242     Michigan
# 41        rivals_camp   207.0     rivals_camp        95.1212      Georgia
# 45       nike_opening   198.0    nike_opening        94.8182      Clemson
# 48        rivals_camp   177.5     rivals_camp        94.7273   Ohio State
# ...               ...     ...             ...            ...          ...
# 71332          rivals   107.0          rivals            NaN          NaN
# 71339          rivals   104.0          rivals            NaN          NaN
# 71346  national_preps   100.0  national_preps            NaN          NaN
# 71348          rivals   100.0          rivals            NaN          NaN
# 71369          rivals    71.0          rivals            NaN          NaN
#
#        ... Hand Size Source Powerball Toss Powerball Toss Source SPARQ Rating  \
# 23     ...              NaN            NaN                   NaN          NaN
# 28     ...              NaN            NaN                   NaN          NaN
# 41     ...      rivals_camp            NaN                   NaN          NaN
# 45     ...      rivals_camp            NaN                   NaN          NaN
# 48     ...      rivals_camp            NaN                   NaN          NaN
# ...    ...              ...            ...                   ...          ...
# 71332  ...              NaN            NaN                   NaN          NaN
# 71339  ...              NaN            NaN                   NaN          NaN
# 71346  ...              NaN            NaN                   NaN          NaN
# 71348  ...              NaN            NaN                   NaN          NaN
# 71369  ...              NaN            NaN                   NaN          NaN
#
#        SPARQ Rating Source   GPA  ACT SAT  Unnamed: 37 Unnamed: 38
# 23                     NaN  2.70  NaN NaN          NaN         NaN
# 28                     NaN  3.20  NaN NaN          NaN         NaN
# 41                     NaN  2.60  NaN NaN          NaN         NaN
# 45                     NaN  4.33  NaN NaN          NaN         NaN
# 48                     NaN  4.50  NaN NaN          NaN         NaN
# ...                    ...   ...  ...  ..          ...         ...
# 71332                  NaN   NaN  NaN NaN          NaN         NaN
# 71339                  NaN   NaN  NaN NaN          NaN         NaN
# 71346                  NaN   NaN  NaN NaN          NaN         NaN
# 71348                  NaN   NaN  NaN NaN          NaN         NaN
# 71369                  NaN   NaN  NaN NaN          NaN         NaN
#
# [9080 rows x 39 columns]

# %%
master_fillna(data, "RB", ["Forty Yard Dash", "Shuttle", "3 Cone"])
# Out:
# {'Forty Yard Dash': 'There are 4197 NaNs out of 9080 players', 'Shuttle': 'There are 6000 NaNs out of 9080 players', '3 Cone': 'There are 6916 NaNs out of 9080 players'}
# Forty Yard Dash ['3 Cone' 'Shuttle']
# There are 4883 players with metric and 4197 NaNs.
# ['3 Cone', 'Forty Yard Dash']
# There are 63 players with a 3 Cone (predictor) value and 4134 players with NaNs for 3 Cone.
# True
# [0.33403925]
# The RMSE of the model on the training data is 0.23836276682738344. The average Forty Yard Dash of the training data is 5.023432175154691. On average, predictions are 0.04745018117419756 from the actual values in the training data
# Shuttle ['3 Cone' 'Forty Yard Dash']
# There are 3080 players with metric and 6000 NaNs.
# ['3 Cone', 'Shuttle']
# There are 21 players with a 3 Cone (predictor) value and 5979 players with NaNs for 3 Cone.
# True
# [0.37746799]
# The RMSE of the model on the training data is 0.23545532572356265. The average Shuttle of the training data is 4.682819412039187. On average, predictions are 0.05028067602142081 from the actual values in the training data
# 3 Cone ['Shuttle' 'Forty Yard Dash']
# There are 2164 players with metric and 6916 NaNs.
# ['Shuttle', '3 Cone']
# There are 937 players with a Shuttle (predictor) value and 5979 players with NaNs for Shuttle.
# True
# [0.99125504]
# The RMSE of the model on the training data is 0.3815585200899391. The average 3 Cone of the training data is 7.778692487167526. On average, predictions are 0.04905175525570583 from the actual values in the training data
# Forty Yard Dash
# There are 4197 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 6000 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 6916 NaN values for this metric
# There are 0 NaN values for this metric
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
#                   Full Name Position  Forty Yard Dash  Shuttle    3 Cone
# 23            Camar Wheaton       RB            4.500    4.654  7.750000
# 28          Donovan Edwards       RB            4.740    4.500  7.597472
# 41             Xavian Sorey       RB            4.600    4.654  7.750000
# 45             Will Shipley       RB            4.460    4.210  6.940000
# 48       TreVeyon Henderson       RB            4.300    4.654  7.750000
# ...                     ...      ...              ...      ...       ...
# 71332        Cassius Sadler       RB            4.997    4.654  7.750000
# 71339           Moses Perez       RB            4.997    4.654  7.750000
# 71346  Carmine D’Alessandro       RB            4.997    4.654  7.750000
# 71348        Al'jay Pipkins       RB            4.997    4.654  7.750000
# 71369         Eugene Thomas       RB            4.997    4.654  7.750000
#
# [9080 rows x 5 columns]

# %%
data[data['Position'] == 'RB'][['Full Name', 'Position', 'Forty Yard Dash', 'Shuttle', '3 Cone']]
# Out:
#                   Full Name Position  Forty Yard Dash  Shuttle  3 Cone
# 23            Camar Wheaton       RB             4.50      NaN     NaN
# 28          Donovan Edwards       RB             4.74     4.50     NaN
# 41             Xavian Sorey       RB             4.60      NaN     NaN
# 45             Will Shipley       RB             4.46     4.21    6.94
# 48       TreVeyon Henderson       RB             4.30      NaN     NaN
# ...                     ...      ...              ...      ...     ...
# 71332        Cassius Sadler       RB              NaN      NaN     NaN
# 71339           Moses Perez       RB              NaN      NaN     NaN
# 71346  Carmine D’Alessandro       RB              NaN      NaN     NaN
# 71348        Al'jay Pipkins       RB              NaN      NaN     NaN
# 71369         Eugene Thomas       RB              NaN      NaN     NaN
#
# [9080 rows x 5 columns]

# %%
positions = ["WR",
"RB", 
"LB",
"QB", 
"DE", 
"CB", 
"OL",
"DT", 
"S", 
"OT",  
"OG",  
"TE",  
"ATH", 
"DB",  
"DL", 
"OC",  
"K", 
"FB",  
"LS", 
"P"]

combine_metrics = ["Height", "Weight", "Forty Yard Dash", "3 Cone", "Shuttle", "Vertical Jump", "Broad Jump"]
zcruit_metrics = ["Wingspan","Arm Length","Hand Size", "Powerball Toss"]

# %%
# %%time
cleaned_combine_metrics_position_dataframes = {}
for position in positions:
    cleaned_combine_metrics_position_dataframes[position] = master_fillna(data, position, combine_metrics + zcruit_metrics)
# Out:
# {'Height': 'There are 0 NaNs out of 12359 players', 'Weight': 'There are 0 NaNs out of 12359 players', 'Forty Yard Dash': 'There are 6235 NaNs out of 12359 players', '3 Cone': 'There are 9546 NaNs out of 12359 players', 'Shuttle': 'There are 8483 NaNs out of 12359 players', 'Vertical Jump': 'There are 8608 NaNs out of 12359 players', 'Broad Jump': 'There are 8801 NaNs out of 12359 players', 'Wingspan': 'There are 11947 NaNs out of 12359 players', 'Arm Length': 'There are 12082 NaNs out of 12359 players', 'Hand Size': 'There are 11963 NaNs out of 12359 players', 'Powerball Toss': 'There are 12340 NaNs out of 12359 players'}
# Forty Yard Dash []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# 3 Cone ['Powerball Toss' 'Shuttle']
# There are 2813 players with metric and 9546 NaNs.
# ['Powerball Toss', '3 Cone']
# There are 17 players with a Powerball Toss (predictor) value and 9529 players with NaNs for Powerball Toss.
# True
# [0.02733333]
# The RMSE of the model on the training data is 0.0. The average 3 Cone of the training data is 7.0215. On average, predictions are 0.0 from the actual values in the training data
# Shuttle ['3 Cone']
# There are 3876 players with metric and 8483 NaNs.
# ['3 Cone', 'Shuttle']
# There are 35 players with a 3 Cone (predictor) value and 8448 players with NaNs for 3 Cone.
# True
# [0.38332496]
# The RMSE of the model on the training data is 0.24604069736686787. The average Shuttle of the training data is 4.6740147588193075. On average, predictions are 0.05264011991032302 from the actual values in the training data
# Vertical Jump ['Powerball Toss']
# There are 3751 players with metric and 8608 NaNs.
# ['Powerball Toss', 'Vertical Jump']
# There are 1 players with a Powerball Toss (predictor) value and 8607 players with NaNs for Powerball Toss.
# True
# [0.47905169]
# The RMSE of the model on the training data is 2.2896714453272. The average Vertical Jump of the training data is 31.72222222222222. On average, predictions are 0.072178784616269 from the actual values in the training data
# Broad Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# Wingspan ['Height' 'Arm Length' 'Weight']
# There are 412 players with metric and 11947 NaNs.
# ['Height', 'Wingspan']
# There are 11947 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.95391507]
# The RMSE of the model on the training data is 2.3533220050715538. The average Wingspan of the training data is 73.49029126213593. On average, predictions are 0.03202221633164278 from the actual values in the training data
# Arm Length ['Wingspan' 'Height' 'Weight']
# There are 277 players with metric and 12082 NaNs.
# ['Wingspan', 'Arm Length']
# There are 135 players with a Wingspan (predictor) value and 11947 players with NaNs for Wingspan.
# True
# [0.3974528]
# The RMSE of the model on the training data is 1.4588901732158246. The average Arm Length of the training data is 31.645126353790616. On average, predictions are 0.04610157522853661 from the actual values in the training data
# Hand Size []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Powerball Toss ['3 Cone' 'Vertical Jump']
# There are 19 players with metric and 12340 NaNs.
# ['3 Cone', 'Powerball Toss']
# There are 2811 players with a 3 Cone (predictor) value and 9529 players with NaNs for 3 Cone.
# True
# [36.58536585]
# The RMSE of the model on the training data is 4.4938668397781776e-14. The average Powerball Toss of the training data is 38.75. On average, predictions are 1.1597075715556587e-15 from the actual values in the training data
# Forty Yard Dash
# There are 6235 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 9546 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 8483 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 8608 NaN values for this metric
# There are 0 NaN values for this metric
# Broad Jump
# There are 8801 NaN values for this metric
# There are 0 NaN values for this metric
# Wingspan
# There are 11947 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 12082 NaN values for this metric
# There are 0 NaN values for this metric
# Hand Size
# There are 11963 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 12340 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 9080 players', 'Weight': 'There are 0 NaNs out of 9080 players', 'Forty Yard Dash': 'There are 4197 NaNs out of 9080 players', '3 Cone': 'There are 6916 NaNs out of 9080 players', 'Shuttle': 'There are 6000 NaNs out of 9080 players', 'Vertical Jump': 'There are 6080 NaNs out of 9080 players', 'Broad Jump': 'There are 6206 NaNs out of 9080 players', 'Wingspan': 'There are 8810 NaNs out of 9080 players', 'Arm Length': 'There are 8923 NaNs out of 9080 players', 'Hand Size': 'There are 8822 NaNs out of 9080 players', 'Powerball Toss': 'There are 9063 NaNs out of 9080 players'}
# Forty Yard Dash ['3 Cone' 'Shuttle']
# There are 4883 players with metric and 4197 NaNs.
# ['3 Cone', 'Forty Yard Dash']
# There are 63 players with a 3 Cone (predictor) value and 4134 players with NaNs for 3 Cone.
# True
# [0.33403925]
# The RMSE of the model on the training data is 0.23836276682738344. The average Forty Yard Dash of the training data is 5.023432175154691. On average, predictions are 0.04745018117419756 from the actual values in the training data
# 3 Cone ['Shuttle' 'Forty Yard Dash']
# There are 2164 players with metric and 6916 NaNs.
# ['Shuttle', '3 Cone']
# There are 937 players with a Shuttle (predictor) value and 5979 players with NaNs for Shuttle.
# True
# [0.99125504]
# The RMSE of the model on the training data is 0.3815585200899391. The average 3 Cone of the training data is 7.778692487167526. On average, predictions are 0.04905175525570583 from the actual values in the training data
# Shuttle ['3 Cone' 'Forty Yard Dash']
# There are 3080 players with metric and 6000 NaNs.
# ['3 Cone', 'Shuttle']
# There are 21 players with a 3 Cone (predictor) value and 5979 players with NaNs for 3 Cone.
# True
# [0.37746799]
# The RMSE of the model on the training data is 0.23545532572356265. The average Shuttle of the training data is 4.682819412039187. On average, predictions are 0.05028067602142081 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Broad Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# Wingspan ['Height' 'Arm Length' 'Weight']
# There are 270 players with metric and 8810 NaNs.
# ['Height', 'Wingspan']
# There are 8810 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.97635539]
# The RMSE of the model on the training data is 2.3419878324285506. The average Wingspan of the training data is 71.59907407407407. On average, predictions are 0.03270975026863624 from the actual values in the training data
# Arm Length ['Wingspan' 'Height']
# There are 157 players with metric and 8923 NaNs.
# ['Wingspan', 'Arm Length']
# There are 113 players with a Wingspan (predictor) value and 8810 players with NaNs for Wingspan.
# True
# [0.34679]
# The RMSE of the model on the training data is 1.2674899811916. The average Arm Length of the training data is 30.94904458598726. On average, predictions are 0.04095409076910501 from the actual values in the training data
# Hand Size []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Powerball Toss []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Forty Yard Dash
# There are 4197 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 6916 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 6000 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 6080 NaN values for this metric
# There are 0 NaN values for this metric
# Broad Jump
# There are 6206 NaN values for this metric
# There are 0 NaN values for this metric
# Wingspan
# There are 8810 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 8923 NaN values for this metric
# There are 0 NaN values for this metric
# Hand Size
# There are 8822 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 9063 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 8832 players', 'Weight': 'There are 0 NaNs out of 8832 players', 'Forty Yard Dash': 'There are 4132 NaNs out of 8832 players', '3 Cone': 'There are 6776 NaNs out of 8832 players', 'Shuttle': 'There are 5721 NaNs out of 8832 players', 'Vertical Jump': 'There are 5899 NaNs out of 8832 players', 'Broad Jump': 'There are 6040 NaNs out of 8832 players', 'Wingspan': 'There are 8596 NaNs out of 8832 players', 'Arm Length': 'There are 8706 NaNs out of 8832 players', 'Hand Size': 'There are 8604 NaNs out of 8832 players', 'Powerball Toss': 'There are 8805 NaNs out of 8832 players'}
# Forty Yard Dash ['3 Cone' 'Hand Size']
# There are 4700 players with metric and 4132 NaNs.
# ['3 Cone', 'Forty Yard Dash']
# There are 75 players with a 3 Cone (predictor) value and 4057 players with NaNs for 3 Cone.
# True
# [0.36438056]
# The RMSE of the model on the training data is 0.2801563416478388. The average Forty Yard Dash of the training data is 5.216575466935888. On average, predictions are 0.053705029942257704 from the actual values in the training data
# 3 Cone ['Forty Yard Dash' 'Shuttle' 'Powerball Toss']
# There are 2056 players with metric and 6776 NaNs.
# ['Forty Yard Dash', '3 Cone']
# There are 2719 players with a Forty Yard Dash (predictor) value and 4057 players with NaNs for Forty Yard Dash.
# True
# [0.99285606]
# The RMSE of the model on the training data is 0.4624512995480497. The average 3 Cone of the training data is 7.951437657748613. On average, predictions are 0.05815945737779816 from the actual values in the training data
# Shuttle ['3 Cone']
# There are 3111 players with metric and 5721 NaNs.
# ['3 Cone', 'Shuttle']
# There are 26 players with a 3 Cone (predictor) value and 5695 players with NaNs for 3 Cone.
# True
# [0.38032846]
# The RMSE of the model on the training data is 0.2942247462739102. The average Shuttle of the training data is 4.792373399014775. On average, predictions are 0.061394370132844295 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Broad Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# Wingspan ['Height' 'Arm Length']
# There are 236 players with metric and 8596 NaNs.
# ['Height', 'Wingspan']
# There are 8596 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.79324485]
# The RMSE of the model on the training data is 2.3552396022791497. The average Wingspan of the training data is 74.41271186440679. On average, predictions are 0.031651038421645156 from the actual values in the training data
# Arm Length ['Wingspan']
# There are 126 players with metric and 8706 NaNs.
# ['Wingspan', 'Arm Length']
# There are 110 players with a Wingspan (predictor) value and 8596 players with NaNs for Wingspan.
# True
# [0.2739041]
# The RMSE of the model on the training data is 1.2760844311014996. The average Arm Length of the training data is 31.989682539682537. On average, predictions are 0.03989049999225667 from the actual values in the training data
# Hand Size ['Forty Yard Dash']
# There are 228 players with metric and 8604 NaNs.
# ['Forty Yard Dash', 'Hand Size']
# There are 4523 players with a Forty Yard Dash (predictor) value and 4081 players with NaNs for Forty Yard Dash.
# True
# [9.60058488]
# The RMSE of the model on the training data is 5.873787450068883. The average Hand Size of the training data is 13.8467231638418. On average, predictions are 0.4242005404865182 from the actual values in the training data
# Powerball Toss ['3 Cone']
# There are 27 players with metric and 8805 NaNs.
# ['3 Cone', 'Powerball Toss']
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# There are 2048 players with a 3 Cone (predictor) value and 6757 players with NaNs for 3 Cone.
# True
# [4.26783421]
# The RMSE of the model on the training data is 2.3722216512990872. The average Powerball Toss of the training data is 34.8125. On average, predictions are 0.06814281224557522 from the actual values in the training data
# Forty Yard Dash
# There are 4132 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 6776 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 5721 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 5899 NaN values for this metric
# There are 0 NaN values for this metric
# Broad Jump
# There are 6040 NaN values for this metric
# There are 0 NaN values for this metric
# Wingspan
# There are 8596 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 8706 NaN values for this metric
# There are 0 NaN values for this metric
# Hand Size
# There are 8604 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 8805 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 6345 players', 'Weight': 'There are 0 NaNs out of 6345 players', 'Forty Yard Dash': 'There are 3160 NaNs out of 6345 players', '3 Cone': 'There are 5056 NaNs out of 6345 players', 'Shuttle': 'There are 4329 NaNs out of 6345 players', 'Vertical Jump': 'There are 4447 NaNs out of 6345 players', 'Broad Jump': 'There are 4570 NaNs out of 6345 players', 'Wingspan': 'There are 6025 NaNs out of 6345 players', 'Arm Length': 'There are 6149 NaNs out of 6345 players', 'Hand Size': 'There are 6042 NaNs out of 6345 players', 'Powerball Toss': 'There are 6320 NaNs out of 6345 players'}
# Forty Yard Dash ['3 Cone' 'Shuttle']
# There are 3185 players with metric and 3160 NaNs.
# ['3 Cone', 'Forty Yard Dash']
# There are 41 players with a 3 Cone (predictor) value and 3119 players with NaNs for 3 Cone.
# True
# [0.31412836]
# The RMSE of the model on the training data is 0.2764445221229421. The average Forty Yard Dash of the training data is 5.166071314102567. On average, predictions are 0.05351155749017475 from the actual values in the training data
# 3 Cone ['Powerball Toss' 'Forty Yard Dash' 'Shuttle']
# There are 1289 players with metric and 5056 NaNs.
# ['Powerball Toss', '3 Cone']
# There are 18 players with a Powerball Toss (predictor) value and 5038 players with NaNs for Powerball Toss.
# True
# [0.03003951]
# The RMSE of the model on the training data is 0.11250733409765762. The average 3 Cone of the training data is 7.683428571428571. On average, predictions are 0.01464285547158269 from the actual values in the training data
# Shuttle ['3 Cone' 'Forty Yard Dash']
# There are 2016 players with metric and 4329 NaNs.
# ['3 Cone', 'Shuttle']
# There are 22 players with a 3 Cone (predictor) value and 4307 players with NaNs for 3 Cone.
# True
# [0.28761287]
# The RMSE of the model on the training data is 0.30375361308344234. The average Shuttle of the training data is 4.7240142067876825. On average, predictions are 0.06429989407038511 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Broad Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# Wingspan ['Arm Length' 'Height' 'Weight']
# There are 320 players with metric and 6025 NaNs.
# ['Arm Length', 'Wingspan']
# There are 0 players with a Arm Length (predictor) value and 6025 players with NaNs for Arm Length.
# True
# [1.15778665]
# The RMSE of the model on the training data is 2.2360715206828625. The average Wingspan of the training data is 74.26020408163265. On average, predictions are 0.030111303198477574 from the actual values in the training data
# Arm Length ['Wingspan' 'Height']
# There are 196 players with metric and 6149 NaNs.
# ['Wingspan', 'Arm Length']
# There are 124 players with a Wingspan (predictor) value and 6025 players with NaNs for Wingspan.
# True
# [0.39120008]
# The RMSE of the model on the training data is 1.2997831090287304. The average Arm Length of the training data is 31.7359693877551. On average, predictions are 0.04095614957109942 from the actual values in the training data
# Hand Size []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Powerball Toss ['3 Cone' 'Height' 'Weight']
# There are 25 players with metric and 6320 NaNs.
# ['3 Cone', 'Powerball Toss']
# There are 1282 players with a 3 Cone (predictor) value and 5038 players with NaNs for 3 Cone.
# True
# [15.0841432]
# The RMSE of the model on the training data is 2.5211271378479276. The average Powerball Toss of the training data is 32.357142857142854. On average, predictions are 0.07791562898426267 from the actual values in the training data
# Forty Yard Dash
# There are 3160 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 5056 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 4329 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 4447 NaN values for this metric
# There are 0 NaN values for this metric
# Broad Jump
# There are 4570 NaN values for this metric
# There are 0 NaN values for this metric
# Wingspan
# There are 6025 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 6149 NaN values for this metric
# There are 0 NaN values for this metric
# Hand Size
# There are 6042 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 6320 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 4229 players', 'Weight': 'There are 0 NaNs out of 4229 players', 'Forty Yard Dash': 'There are 1971 NaNs out of 4229 players', '3 Cone': 'There are 3086 NaNs out of 4229 players', 'Shuttle': 'There are 2536 NaNs out of 4229 players', 'Vertical Jump': 'There are 2634 NaNs out of 4229 players', 'Broad Jump': 'There are 2682 NaNs out of 4229 players', 'Wingspan': 'There are 4034 NaNs out of 4229 players', 'Arm Length': 'There are 4078 NaNs out of 4229 players', 'Hand Size': 'There are 4054 NaNs out of 4229 players', 'Powerball Toss': 'There are 4219 NaNs out of 4229 players'}
# Forty Yard Dash ['3 Cone' 'Hand Size']
# There are 2258 players with metric and 1971 NaNs.
# ['3 Cone', 'Forty Yard Dash']
# There are 29 players with a 3 Cone (predictor) value and 1942 players with NaNs for 3 Cone.
# True
# [0.39453952]
# The RMSE of the model on the training data is 0.3353444116966795. The average Forty Yard Dash of the training data is 5.441859964093352. On average, predictions are 0.0616231240622433 from the actual values in the training data
# 3 Cone ['Shuttle' 'Forty Yard Dash']
# There are 1143 players with metric and 3086 NaNs.
# ['Shuttle', '3 Cone']
# There are 565 players with a Shuttle (predictor) value and 2521 players with NaNs for Shuttle.
# True
# [1.03470336]
# The RMSE of the model on the training data is 0.529884146063132. The average 3 Cone of the training data is 8.230401595744668. On average, predictions are 0.06438132330469705 from the actual values in the training data
# Shuttle ['3 Cone']
# There are 1693 players with metric and 2536 NaNs.
# ['3 Cone', 'Shuttle']
# There are 15 players with a 3 Cone (predictor) value and 2521 players with NaNs for 3 Cone.
# True
# [0.38935601]
# The RMSE of the model on the training data is 0.325047208247369. The average Shuttle of the training data is 4.96897606382979. On average, predictions are 0.06541532985305669 from the actual values in the training data
# Vertical Jump ['Broad Jump' 'Powerball Toss']
# There are 1595 players with metric and 2634 NaNs.
# ['Broad Jump', 'Vertical Jump']
# There are 149 players with a Broad Jump (predictor) value and 2485 players with NaNs for Broad Jump.
# True
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# [0.25969432]
# The RMSE of the model on the training data is 5.225262105190281. The average Vertical Jump of the training data is 23.202470672389108. On average, predictions are 0.22520283201600302 from the actual values in the training data
# Broad Jump ['Vertical Jump']
# There are 1547 players with metric and 2682 NaNs.
# ['Vertical Jump', 'Broad Jump']
# There are 197 players with a Vertical Jump (predictor) value and 2485 players with NaNs for Vertical Jump.
# True
# [0.87198766]
# The RMSE of the model on the training data is 9.57485101358244. The average Broad Jump of the training data is 92.66634477825465. On average, predictions are 0.10332608927755292 from the actual values in the training data
# Wingspan ['Height' 'Arm Length']
# There are 195 players with metric and 4034 NaNs.
# ['Height', 'Wingspan']
# There are 4034 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.89054897]
# The RMSE of the model on the training data is 2.36857566879391. The average Wingspan of the training data is 77.52692307692308. On average, predictions are 0.030551653216570746 from the actual values in the training data
# Arm Length ['Wingspan' 'Height']
# There are 151 players with metric and 4078 NaNs.
# ['Wingspan', 'Arm Length']
# There are 44 players with a Wingspan (predictor) value and 4034 players with NaNs for Wingspan.
# True
# [0.28817542]
# The RMSE of the model on the training data is 1.4058696246950895. The average Arm Length of the training data is 33.370860927152314. On average, predictions are 0.042128659124619675 from the actual values in the training data
# Hand Size ['Forty Yard Dash']
# There are 175 players with metric and 4054 NaNs.
# ['Forty Yard Dash', 'Hand Size']
# There are 2131 players with a Forty Yard Dash (predictor) value and 1923 players with NaNs for Forty Yard Dash.
# True
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
# Wingspan []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# Arm Length []
# Hand Size []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# Powerball Toss []
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Forty Yard Dash
# There are 124 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 245 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 197 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 218 NaN values for this metric
# There are 0 NaN values for this metric
# Broad Jump
# There are 223 NaN values for this metric
# There are 0 NaN values for this metric
# Wingspan
# There are 276 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 277 NaN values for this metric
# There are 277 NaN values for this metric
# Hand Size
# There are 276 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 277 NaN values for this metric
# There are 277 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 165 players', 'Weight': 'There are 0 NaNs out of 165 players', 'Forty Yard Dash': 'There are 98 NaNs out of 165 players', '3 Cone': 'There are 160 NaNs out of 165 players', 'Shuttle': 'There are 140 NaNs out of 165 players', 'Vertical Jump': 'There are 150 NaNs out of 165 players', 'Broad Jump': 'There are 149 NaNs out of 165 players', 'Wingspan': 'There are 165 NaNs out of 165 players', 'Arm Length': 'There are 165 NaNs out of 165 players', 'Hand Size': 'There are 165 NaNs out of 165 players', 'Powerball Toss': 'There are 165 NaNs out of 165 players'}
# Forty Yard Dash ['Shuttle' '3 Cone']
# There are 67 players with metric and 98 NaNs.
# ['Shuttle', 'Forty Yard Dash']
# There are 0 players with a Shuttle (predictor) value and 98 players with NaNs for Shuttle.
# True
# [1.08110352]
# The RMSE of the model on the training data is 0.5386091734241818. The average Forty Yard Dash of the training data is 5.500440000000001. On average, predictions are 0.09792110693402377 from the actual values in the training data
# 3 Cone ['Forty Yard Dash']
# There are 5 players with metric and 160 NaNs.
# ['Forty Yard Dash', '3 Cone']
# There are 62 players with a Forty Yard Dash (predictor) value and 98 players with NaNs for Forty Yard Dash.
# True
# [0.73137473]
# The RMSE of the model on the training data is 0.4830818842683432. The average 3 Cone of the training data is 7.9136. On average, predictions are 0.061044516309687526 from the actual values in the training data
# Shuttle ['Forty Yard Dash']
# There are 25 players with metric and 140 NaNs.
# ['Forty Yard Dash', 'Shuttle']
# There are 42 players with a Forty Yard Dash (predictor) value and 98 players with NaNs for Forty Yard Dash.
# True
# [0.89255936]
# The RMSE of the model on the training data is 0.48939401999631454. The average Shuttle of the training data is 5.318079999999998. On average, predictions are 0.09202456901669676 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Broad Jump []
# Wingspan []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# Arm Length []
# Hand Size []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# Powerball Toss []
# Forty Yard Dash
# There are 98 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 160 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 140 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 150 NaN values for this metric
# There are 0 NaN values for this metric
# Broad Jump
# There are 149 NaN values for this metric
# There are 0 NaN values for this metric
# Wingspan
# There are 165 NaN values for this metric
# There are 165 NaN values for this metric
# Arm Length
# There are 165 NaN values for this metric
# There are 165 NaN values for this metric
# Hand Size
# There are 165 NaN values for this metric
# There are 165 NaN values for this metric
# Powerball Toss
# There are 165 NaN values for this metric
# There are 165 NaN values for this metric
# Wall time: 1min 55s
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]

# %%
cleaned_combine_metrics_position_dataframes['RB']
# Out:
#                   Full Name Position  Height  Weight  Forty Yard Dash  \
# 23            Camar Wheaton       RB    71.0   190.0            4.500
# 28          Donovan Edwards       RB    70.5   203.0            4.740
# 41             Xavian Sorey       RB    74.0   207.0            4.600
# 45             Will Shipley       RB    71.0   198.0            4.460
# 48       TreVeyon Henderson       RB    69.5   177.5            4.300
# ...                     ...      ...     ...     ...              ...
# 71332        Cassius Sadler       RB    64.0   107.0            4.997
# 71339           Moses Perez       RB    60.0   104.0            4.997
# 71346  Carmine D’Alessandro       RB    65.0   100.0            4.997
# 71348        Al'jay Pipkins       RB    61.0   100.0            4.997
# 71369         Eugene Thomas       RB    57.0    71.0            4.997
#
#          3 Cone  Shuttle  Vertical Jump  Broad Jump   Wingspan  Arm Length  \
# 23     7.750000    4.654       30.98400  109.968000  73.670213   31.000000
# 28     7.597472    4.500       33.10000  107.047600  73.182035   31.000000
# 41     7.750000    4.654       31.28608  110.476800  77.000000   32.787915
# 45     6.940000    4.210       36.30000  121.000000  73.000000   32.000000
# 48     7.750000    4.654       28.83292  105.982664  75.000000   32.094335
# ...         ...      ...            ...         ...        ...         ...
# 71332  7.750000    4.654       18.97952   79.496000  66.835725   31.000000
# 71339  7.750000    4.654       18.97952   79.496000  62.930304   31.000000
# 71346  7.750000    4.654       20.29920   85.140000  67.812081   31.000000
# 71348  7.750000    4.654       18.97952   79.496000  63.906659   31.000000
# 71369  7.750000    4.654       18.97952   79.496000  60.001238   31.000000
#
#        Hand Size  Powerball Toss
# 23     19.925888        37.17440
# 28      9.731697        34.07616
# 41      9.450000        37.39072
# 45      9.450000        37.35248
# 48      9.060000        34.00000
# ...          ...             ...
# 71332   7.813360        27.76160
# 71339   7.813360        27.76160
# 71346   7.870000        28.14240
# 71348   7.813360        27.76160
# 71369   7.813360        27.76160
#
# [9080 rows x 13 columns]

# %%
wr_metrics = ["Height", "Weight", "Wingspan", "Arm Length", "Hand Size", "Forty Yard Dash", "Shuttle", "3 Cone", "Vertical Jump", "Broad Jump"]
rb_metrics = ["Height", "Weight","Wingspan","Hand Size","Forty Yard Dash","Shuttle","3 Cone","Vertical Jump"]
lb_metrics = ["Height","Weight","Arm Length","Shuttle","3 Cone","Vertical Jump"]
qb_metrics = ["Height","Weight","Wingspan","Hand Size","Powerball Toss"]
de_metrics = ["Height","Weight","Wingspan","Arm Length","Forty Yard Dash","Shuttle","Vertical Jump","Powerball Toss"]
cb_metrics = ["Height","Weight","Wingspan","Arm Length","Forty Yard Dash","Shuttle","3 Cone","Vertical Jump","Broad Jump"]
ol_metrics = ["Height","Weight","Wingspan","Arm Length","Vertical Jump","Powerball Toss"]
dt_metrics = ["Height","Weight","Wingspan","Arm Length","Shuttle","3 Cone","Vertical Jump","Broad Jump","Powerball Toss"]
s_metrics = ["Height","Weight","Wingspan","Arm Length","Forty Yard Dash","Shuttle","3 Cone","Vertical Jump"]
ot_metrics = ["Height","Weight","Wingspan","Arm Length","Vertical Jump","Powerball Toss"]
og_metrics = ["Height","Weight","Powerball Toss"]
te_metrics = ["Height","Weight","Forty Yard Dash","Shuttle","3 Cone","Vertical Jump"]
ath_metrics = ["Height","Weight","Forty Yard Dash","Shuttle","3 Cone","Vertical Jump"]
db_metrics = ["Height","Weight","Forty Yard Dash","Vertical Jump"]
dl_metrics = ["Height","Weight","Vertical Jump","Powerball Toss"]
oc_metrics = ["Height","Weight","Wingspan","Arm Length","Hand Size","Forty Yard Dash","Powerball Toss"]
k_metrics = ["Height","Weight","Vertical Jump"]
fb_metrics = ["Height","Weight","Forty Yard Dash","Vertical Jump"]
ls_metrics = ["Height","Weight"]
p_metrics = ["Height","Weight","Vertical Jump"]

# %%
all_position_metrics = [wr_metrics, rb_metrics, lb_metrics, qb_metrics, 
                       de_metrics, cb_metrics, ol_metrics, dt_metrics, 
                       s_metrics, ot_metrics, og_metrics, te_metrics, 
                       ath_metrics, db_metrics, dl_metrics, oc_metrics, 
                       k_metrics, fb_metrics, ls_metrics, p_metrics]

# %%
# %%time
cleaned_chosen_metrics_position_dataframes = {}
for position, position_metrics in zip(positions, all_position_metrics):
    cleaned_chosen_metrics_position_dataframes[position] = master_fillna(data, position, position_metrics)
# Out:
# {'Height': 'There are 0 NaNs out of 12359 players', 'Weight': 'There are 0 NaNs out of 12359 players', 'Wingspan': 'There are 11947 NaNs out of 12359 players', 'Arm Length': 'There are 12082 NaNs out of 12359 players', 'Hand Size': 'There are 11963 NaNs out of 12359 players', 'Forty Yard Dash': 'There are 6235 NaNs out of 12359 players', 'Shuttle': 'There are 8483 NaNs out of 12359 players', '3 Cone': 'There are 9546 NaNs out of 12359 players', 'Vertical Jump': 'There are 8608 NaNs out of 12359 players', 'Broad Jump': 'There are 8801 NaNs out of 12359 players'}
# Wingspan ['Height' 'Arm Length' 'Weight']
# There are 412 players with metric and 11947 NaNs.
# ['Height', 'Wingspan']
# There are 11947 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.95391507]
# The RMSE of the model on the training data is 2.3533220050715538. The average Wingspan of the training data is 73.49029126213593. On average, predictions are 0.03202221633164278 from the actual values in the training data
# Arm Length ['Wingspan' 'Height' 'Weight']
# There are 277 players with metric and 12082 NaNs.
# ['Wingspan', 'Arm Length']
# There are 135 players with a Wingspan (predictor) value and 11947 players with NaNs for Wingspan.
# True
# [0.3974528]
# The RMSE of the model on the training data is 1.4588901732158246. The average Arm Length of the training data is 31.645126353790616. On average, predictions are 0.04610157522853661 from the actual values in the training data
# Hand Size []
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Forty Yard Dash []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# Shuttle ['3 Cone']
# There are 3876 players with metric and 8483 NaNs.
# ['3 Cone', 'Shuttle']
# There are 35 players with a 3 Cone (predictor) value and 8448 players with NaNs for 3 Cone.
# True
# [0.38332496]
# The RMSE of the model on the training data is 0.24604069736686787. The average Shuttle of the training data is 4.6740147588193075. On average, predictions are 0.05264011991032302 from the actual values in the training data
# 3 Cone ['Shuttle']
# There are 2813 players with metric and 9546 NaNs.
# ['Shuttle', '3 Cone']
# There are 1098 players with a Shuttle (predictor) value and 8448 players with NaNs for Shuttle.
# True
# [0.9804151]
# The RMSE of the model on the training data is 0.3934851927182003. The average 3 Cone of the training data is 7.735904607631389. On average, predictions are 0.05086479379929676 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Broad Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Wingspan
# There are 11947 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 12082 NaN values for this metric
# There are 0 NaN values for this metric
# Hand Size
# There are 11963 NaN values for this metric
# There are 0 NaN values for this metric
# Forty Yard Dash
# There are 6235 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 8483 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 9546 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 8608 NaN values for this metric
# There are 0 NaN values for this metric
# Broad Jump
# There are 8801 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 9080 players', 'Weight': 'There are 0 NaNs out of 9080 players', 'Wingspan': 'There are 8810 NaNs out of 9080 players', 'Hand Size': 'There are 8822 NaNs out of 9080 players', 'Forty Yard Dash': 'There are 4197 NaNs out of 9080 players', 'Shuttle': 'There are 6000 NaNs out of 9080 players', '3 Cone': 'There are 6916 NaNs out of 9080 players', 'Vertical Jump': 'There are 6080 NaNs out of 9080 players'}
# Wingspan ['Height' 'Weight']
# There are 270 players with metric and 8810 NaNs.
# ['Height', 'Wingspan']
# There are 8810 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.97635539]
# The RMSE of the model on the training data is 2.3419878324285506. The average Wingspan of the training data is 71.59907407407407. On average, predictions are 0.03270975026863624 from the actual values in the training data
# Hand Size []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# Forty Yard Dash ['3 Cone' 'Shuttle']
# There are 4883 players with metric and 4197 NaNs.
# ['3 Cone', 'Forty Yard Dash']
# There are 63 players with a 3 Cone (predictor) value and 4134 players with NaNs for 3 Cone.
# True
# [0.33403925]
# The RMSE of the model on the training data is 0.23836276682738344. The average Forty Yard Dash of the training data is 5.023432175154691. On average, predictions are 0.04745018117419756 from the actual values in the training data
# Shuttle ['3 Cone' 'Forty Yard Dash']
# There are 3080 players with metric and 6000 NaNs.
# ['3 Cone', 'Shuttle']
# There are 21 players with a 3 Cone (predictor) value and 5979 players with NaNs for 3 Cone.
# True
# [0.37746799]
# The RMSE of the model on the training data is 0.23545532572356265. The average Shuttle of the training data is 4.682819412039187. On average, predictions are 0.05028067602142081 from the actual values in the training data
# 3 Cone ['Shuttle' 'Forty Yard Dash']
# There are 2164 players with metric and 6916 NaNs.
# ['Shuttle', '3 Cone']
# There are 937 players with a Shuttle (predictor) value and 5979 players with NaNs for Shuttle.
# True
# [0.99125504]
# The RMSE of the model on the training data is 0.3815585200899391. The average 3 Cone of the training data is 7.778692487167526. On average, predictions are 0.04905175525570583 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Wingspan
# There are 8810 NaN values for this metric
# There are 0 NaN values for this metric
# Hand Size
# There are 8822 NaN values for this metric
# There are 0 NaN values for this metric
# Forty Yard Dash
# There are 4197 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 6000 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 6916 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 6080 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 8832 players', 'Weight': 'There are 0 NaNs out of 8832 players', 'Arm Length': 'There are 8706 NaNs out of 8832 players', 'Shuttle': 'There are 5721 NaNs out of 8832 players', '3 Cone': 'There are 6776 NaNs out of 8832 players', 'Vertical Jump': 'There are 5899 NaNs out of 8832 players'}
# Arm Length []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# Shuttle ['3 Cone']
# There are 3111 players with metric and 5721 NaNs.
# ['3 Cone', 'Shuttle']
# There are 26 players with a 3 Cone (predictor) value and 5695 players with NaNs for 3 Cone.
# True
# [0.38032846]
# The RMSE of the model on the training data is 0.2942247462739102. The average Shuttle of the training data is 4.792373399014775. On average, predictions are 0.061394370132844295 from the actual values in the training data
# 3 Cone ['Shuttle']
# There are 2056 players with metric and 6776 NaNs.
# ['Shuttle', '3 Cone']
# There are 1081 players with a Shuttle (predictor) value and 5695 players with NaNs for Shuttle.
# True
# [0.922145]
# The RMSE of the model on the training data is 0.45814124532771583. The average 3 Cone of the training data is 7.950379802955665. On average, predictions are 0.05762507662305584 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Arm Length
# There are 8706 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 5721 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 6776 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 5899 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 6345 players', 'Weight': 'There are 0 NaNs out of 6345 players', 'Wingspan': 'There are 6025 NaNs out of 6345 players', 'Hand Size': 'There are 6042 NaNs out of 6345 players', 'Powerball Toss': 'There are 6320 NaNs out of 6345 players'}
# Wingspan ['Height' 'Weight']
# There are 320 players with metric and 6025 NaNs.
# ['Height', 'Wingspan']
# There are 6025 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.81524717]
# The RMSE of the model on the training data is 2.2123412499009905. The average Wingspan of the training data is 74.00703125. On average, predictions are 0.02989366297409735 from the actual values in the training data
# Hand Size []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Powerball Toss ['Height' 'Weight']
# There are 25 players with metric and 6320 NaNs.
# ['Height', 'Powerball Toss']
# There are 6320 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.93695806]
# The RMSE of the model on the training data is 2.892647722403424. The average Powerball Toss of the training data is 33.128. On average, predictions are 0.08731730627878 from the actual values in the training data
# Wingspan
# There are 6025 NaN values for this metric
# There are 0 NaN values for this metric
# Hand Size
# There are 6042 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 6320 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 4229 players', 'Weight': 'There are 0 NaNs out of 4229 players', 'Wingspan': 'There are 4034 NaNs out of 4229 players', 'Arm Length': 'There are 4078 NaNs out of 4229 players', 'Forty Yard Dash': 'There are 1971 NaNs out of 4229 players', 'Shuttle': 'There are 2536 NaNs out of 4229 players', 'Vertical Jump': 'There are 2634 NaNs out of 4229 players', 'Powerball Toss': 'There are 4219 NaNs out of 4229 players'}
# Wingspan ['Height' 'Arm Length']
# There are 195 players with metric and 4034 NaNs.
# ['Height', 'Wingspan']
# There are 4034 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.89054897]
# The RMSE of the model on the training data is 2.36857566879391. The average Wingspan of the training data is 77.52692307692308. On average, predictions are 0.030551653216570746 from the actual values in the training data
# Arm Length ['Wingspan' 'Height']
# There are 151 players with metric and 4078 NaNs.
# ['Wingspan', 'Arm Length']
# There are 44 players with a Wingspan (predictor) value and 4034 players with NaNs for Wingspan.
# True
# [0.28817542]
# The RMSE of the model on the training data is 1.4058696246950895. The average Arm Length of the training data is 33.370860927152314. On average, predictions are 0.042128659124619675 from the actual values in the training data
# Forty Yard Dash []
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Shuttle []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Vertical Jump ['Powerball Toss']
# There are 1595 players with metric and 2634 NaNs.
# ['Powerball Toss', 'Vertical Jump']
# There are 1 players with a Powerball Toss (predictor) value and 2633 players with NaNs for Powerball Toss.
# True
# [0.40733008]
# The RMSE of the model on the training data is 2.872344778981971. The average Vertical Jump of the training data is 26.744444444444444. On average, predictions are 0.1073996801447351 from the actual values in the training data
# Powerball Toss ['Vertical Jump']
# There are 10 players with metric and 4219 NaNs.
# ['Vertical Jump', 'Powerball Toss']
# There are 1586 players with a Vertical Jump (predictor) value and 2633 players with NaNs for Vertical Jump.
# True
# [0.53618629]
# The RMSE of the model on the training data is 3.2954989810234254. The average Powerball Toss of the training data is 38.77777777777778. On average, predictions are 0.08498421441034622 from the actual values in the training data
# Wingspan
# There are 4034 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 4078 NaN values for this metric
# There are 0 NaN values for this metric
# Forty Yard Dash
# There are 1971 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 2536 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 2634 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 4219 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 3976 players', 'Weight': 'There are 0 NaNs out of 3976 players', 'Wingspan': 'There are 3690 NaNs out of 3976 players', 'Arm Length': 'There are 3782 NaNs out of 3976 players', 'Forty Yard Dash': 'There are 1743 NaNs out of 3976 players', 'Shuttle': 'There are 2229 NaNs out of 3976 players', '3 Cone': 'There are 2645 NaNs out of 3976 players', 'Vertical Jump': 'There are 2229 NaNs out of 3976 players', 'Broad Jump': 'There are 2305 NaNs out of 3976 players'}
# Wingspan ['Height' 'Arm Length' 'Weight']
# There are 286 players with metric and 3690 NaNs.
# ['Height', 'Wingspan']
# There are 3690 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.89487783]
# The RMSE of the model on the training data is 2.2169774236918944. The average Wingspan of the training data is 72.64982517482517. On average, predictions are 0.030515936113499804 from the actual values in the training data
# Arm Length ['Wingspan' 'Height']
# There are 194 players with metric and 3782 NaNs.
# ['Wingspan', 'Arm Length']
# There are 92 players with a Wingspan (predictor) value and 3690 players with NaNs for Wingspan.
# True
# [0.33647196]
# The RMSE of the model on the training data is 1.3359766373674677. The average Arm Length of the training data is 31.323453608247423. On average, predictions are 0.04265100055939256 from the actual values in the training data
# Forty Yard Dash ['Shuttle' '3 Cone']
# There are 2233 players with metric and 1743 NaNs.
# ['Shuttle', 'Forty Yard Dash']
# There are 81 players with a Shuttle (predictor) value and 1662 players with NaNs for Shuttle.
# True
# [0.72924326]
# The RMSE of the model on the training data is 0.3043254448264179. The average Forty Yard Dash of the training data is 4.993793517406971. On average, predictions are 0.060940734486843375 from the actual values in the training data
# Shuttle ['Forty Yard Dash' '3 Cone']
# There are 1747 players with metric and 2229 NaNs.
# ['Forty Yard Dash', 'Shuttle']
# There are 567 players with a Forty Yard Dash (predictor) value and 1662 players with NaNs for Forty Yard Dash.
# True
# [0.72947825]
# The RMSE of the model on the training data is 0.30437447401069945. The average Shuttle of the training data is 4.647936374549824. On average, predictions are 0.06548593816329504 from the actual values in the training data
# 3 Cone ['Shuttle' 'Forty Yard Dash']
# There are 1331 players with metric and 2645 NaNs.
# ['Shuttle', '3 Cone']
# There are 426 players with a Shuttle (predictor) value and 2219 players with NaNs for Shuttle.
# True
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# [0.96738252]
# The RMSE of the model on the training data is 0.3879621482020245. The average 3 Cone of the training data is 7.768277819833468. On average, predictions are 0.049941847755689744 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Broad Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Wingspan
# There are 3690 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 3782 NaN values for this metric
# There are 0 NaN values for this metric
# Forty Yard Dash
# There are 1743 NaN values for this metric
# There are 0 NaN values for this metric
# Shuttle
# There are 2229 NaN values for this metric
# There are 0 NaN values for this metric
# 3 Cone
# There are 2645 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 2229 NaN values for this metric
# There are 0 NaN values for this metric
# Broad Jump
# There are 2305 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 3781 players', 'Weight': 'There are 0 NaNs out of 3781 players', 'Wingspan': 'There are 3773 NaNs out of 3781 players', 'Arm Length': 'There are 3781 NaNs out of 3781 players', 'Vertical Jump': 'There are 3573 NaNs out of 3781 players', 'Powerball Toss': 'There are 3781 NaNs out of 3781 players'}
# Wingspan ['Height']
# There are 8 players with metric and 3773 NaNs.
# ['Height', 'Wingspan']
# There are 3773 players with a Height (predictor) value and 0 players with NaNs for Height.
# True
# [0.95225806]
# The RMSE of the model on the training data is 1.4460457762798422. The average Wingspan of the training data is 78.4375. On average, predictions are 0.01843564336293026 from the actual values in the training data
# Arm Length []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Powerball Toss []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Wingspan
# There are 3773 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 3781 NaN values for this metric
# There are 3781 NaN values for this metric
# Vertical Jump
# There are 3573 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 3781 NaN values for this metric
# There are 3781 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 2994 players', 'Weight': 'There are 0 NaNs out of 2994 players', 'Wingspan': 'There are 2869 NaNs out of 2994 players', 'Arm Length': 'There are 2915 NaNs out of 2994 players', 'Shuttle': 'There are 1785 NaNs out of 2994 players', '3 Cone': 'There are 2220 NaNs out of 2994 players', 'Vertical Jump': 'There are 1933 NaNs out of 2994 players', 'Broad Jump': 'There are 1958 NaNs out of 2994 players', 'Powerball Toss': 'There are 2987 NaNs out of 2994 players'}
# Wingspan ['Powerball Toss' 'Height' 'Arm Length']
# There are 125 players with metric and 2869 NaNs.
# ['Powerball Toss', 'Wingspan']
# There are 1 players with a Powerball Toss (predictor) value and 2868 players with NaNs for Powerball Toss.
# True
# [0.47816781]
# The RMSE of the model on the training data is 2.3020771994174374. The average Wingspan of the training data is 76.29166666666667. On average, predictions are 0.030174687485537133 from the actual values in the training data
# Arm Length ['Wingspan' 'Height']
# There are 79 players with metric and 2915 NaNs.
# ['Wingspan', 'Arm Length']
# There are 46 players with a Wingspan (predictor) value and 2869 players with NaNs for Wingspan.
# True
# [0.37559427]
# The RMSE of the model on the training data is 1.4186239566353043. The average Arm Length of the training data is 32.92088607594937. On average, predictions are 0.04309191293826359 from the actual values in the training data
# Shuttle ['3 Cone' 'Powerball Toss']
# There are 1209 players with metric and 1785 NaNs.
# ['3 Cone', 'Shuttle']
# There are 10 players with a 3 Cone (predictor) value and 1775 players with NaNs for 3 Cone.
# True
# [0.38455698]
# The RMSE of the model on the training data is 0.36377088882282294. The average Shuttle of the training data is 5.261951570680625. On average, predictions are 0.0691323141113155 from the actual values in the training data
# 3 Cone ['Shuttle']
# There are 774 players with metric and 2220 NaNs.
# ['Shuttle', '3 Cone']
# There are 445 players with a Shuttle (predictor) value and 1775 players with NaNs for Shuttle.
# True
# [1.15963168]
# The RMSE of the model on the training data is 0.6316952706388548. The average 3 Cone of the training data is 8.71701178010472. On average, predictions are 0.07246695158547395 from the actual values in the training data
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Powerball Toss []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# Vertical Jump
# There are 1862 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 2060 NaN values for this metric
# There are 2060 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 1304 players', 'Weight': 'There are 0 NaNs out of 1304 players', 'Wingspan': 'There are 1276 NaNs out of 1304 players', 'Arm Length': 'There are 1282 NaNs out of 1304 players', 'Hand Size': 'There are 1277 NaNs out of 1304 players', 'Forty Yard Dash': 'There are 555 NaNs out of 1304 players', 'Powerball Toss': 'There are 1303 NaNs out of 1304 players'}
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Wingspan ['Arm Length']
# There are 28 players with metric and 1276 NaNs.
# ['Arm Length', 'Wingspan']
# There are 0 players with a Arm Length (predictor) value and 1276 players with NaNs for Arm Length.
# True
# [1.34850954]
# The RMSE of the model on the training data is 2.28312197464914. The average Wingspan of the training data is 76.5909090909091. On average, predictions are 0.02980930768087898 from the actual values in the training data
# Arm Length ['Wingspan' 'Height']
# There are 22 players with metric and 1282 NaNs.
# ['Wingspan', 'Arm Length']
# There are 6 players with a Wingspan (predictor) value and 1276 players with NaNs for Wingspan.
# True
# [0.34220076]
# The RMSE of the model on the training data is 1.1501184902910302. The average Arm Length of the training data is 32.28409090909091. On average, predictions are 0.035624930357483514 from the actual values in the training data
# Hand Size []
# <ipython-input-206-07c4780c7300>:121: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Forty Yard Dash []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Powerball Toss []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Wingspan
# There are 1276 NaN values for this metric
# There are 0 NaN values for this metric
# Arm Length
# There are 1282 NaN values for this metric
# There are 0 NaN values for this metric
# Hand Size
# There are 1277 NaN values for this metric
# There are 0 NaN values for this metric
# Forty Yard Dash
# There are 555 NaN values for this metric
# There are 0 NaN values for this metric
# Powerball Toss
# There are 1303 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 783 players', 'Weight': 'There are 0 NaNs out of 783 players', 'Vertical Jump': 'There are 702 NaNs out of 783 players'}
# Vertical Jump []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Vertical Jump
# There are 702 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 326 players', 'Weight': 'There are 0 NaNs out of 326 players', 'Forty Yard Dash': 'There are 124 NaNs out of 326 players', 'Vertical Jump': 'There are 188 NaNs out of 326 players'}
# Forty Yard Dash []
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]
# Vertical Jump []
# Forty Yard Dash
# There are 124 NaN values for this metric
# There are 0 NaN values for this metric
# Vertical Jump
# There are 188 NaN values for this metric
# There are 0 NaN values for this metric
# {'Height': 'There are 0 NaNs out of 277 players', 'Weight': 'There are 0 NaNs out of 277 players'}
# {'Height': 'There are 0 NaNs out of 165 players', 'Weight': 'There are 0 NaNs out of 165 players', 'Vertical Jump': 'There are 150 NaNs out of 165 players'}
# Vertical Jump []
# Vertical Jump
# There are 150 NaN values for this metric
# There are 0 NaN values for this metric
# Wall time: 1min 4s
# <ipython-input-206-07c4780c7300>:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-206-07c4780c7300>:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-206-07c4780c7300>:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-206-07c4780c7300>:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[metric] = completed_metrics[metric]

# %%
cleaned_chosen_metrics_position_dataframes['WR']
# Out:
#               Full Name Position  Height  Weight   Wingspan  Arm Length  \
# 3          Emeka Egbuka       WR   72.50   190.0  75.000000   32.193956
# 20            Sage Ryan       WR   70.75   197.0  73.000000   35.000000
# 27       Jacorey Brooks       WR   74.00   180.0  76.000000   32.591408
# 33        Kevin Coleman       WR   70.00   157.0  72.818846   31.500000
# 37        Luther Burden       WR   74.00   195.0  76.634506   31.500000
# ...                 ...      ...     ...     ...        ...         ...
# 71363       Tyler Grake       WR   61.00    91.0  64.233611   31.500000
# 71365  Carl Collins III       WR   56.00    86.0  59.464035   31.500000
# 71366  Antrone\t Coston       WR   61.00    85.0  64.233611   31.500000
# 71367  Gerald\t Lampkin       WR   59.00    84.0  62.325780   31.500000
# 71368     Jaeden\t Hamm       WR   58.00    80.0  61.371865   31.500000
#
#        Hand Size  Forty Yard Dash  Shuttle    3 Cone  Vertical Jump  \
# 3        9.00000          4.85900    4.200  7.083000        35.1000
# 20      20.00000          4.79400    4.133  7.348000        31.5000
# 27       8.66000          4.83000    4.340  7.408431        32.8000
# 33       9.39296          4.61000    4.160  7.231957        32.9000
# 37      22.33400          4.52664    4.650  7.710000        33.1680
# ...          ...              ...      ...       ...            ...
# 71363    7.81336          6.34040    4.650  7.710000        19.2688
# 71365    7.81336          6.34040    4.650  7.710000        19.2688
# 71366    7.81336          6.34040    4.650  7.710000        19.2688
# 71367    7.81336          6.34040    4.650  7.710000        19.2688
# 71368    7.81336          6.34040    4.650  7.710000        19.2688
#
#        Broad Jump
# 3        112.0000
# 20       117.0000
# 27       106.7080
# 33       105.7148
# 37       114.3360
# ...           ...
# 71363     81.2572
# 71365     81.2572
# 71366     81.2572
# 71367     81.2572
# 71368     81.2572
#
# [12359 rows x 12 columns]

# %%
column_names = cleaned_combine_metrics_position_dataframes['DE'].columns
df = pd.DataFrame(columns = column_names)

# %%
for position in positions:
    df = df.append(cleaned_combine_metrics_position_dataframes[position])

# %%
df = df.sort_index()

# %%
df.to_csv("zcruit_and_combine.csv")

# %%
still_nan_events_for_positions_zcruit = {}
for position in positions:
    series = df[df['Position'] == position].isna().sum() > 0
    still_nan_events_for_positions_zcruit[position] = series[series].index.values

# %%
still_nan_events_for_positions_zcruit
# Out:
# {'WR': array([], dtype=object),
#  'RB': array([], dtype=object),
#  'LB': array([], dtype=object),
#  'QB': array([], dtype=object),
#  'DE': array([], dtype=object),
#  'CB': array([], dtype=object),
#  'OL': array(['Arm Length', 'Powerball Toss'], dtype=object),
#  'DT': array([], dtype=object),
#  'S': array([], dtype=object),
#  'OT': array([], dtype=object),
#  'OG': array([], dtype=object),
#  'TE': array([], dtype=object),
#  'ATH': array(['Arm Length'], dtype=object),
#  'DB': array(['Arm Length', 'Powerball Toss'], dtype=object),
#  'DL': array(['Arm Length', 'Powerball Toss'], dtype=object),
#  'OC': array([], dtype=object),
#  'K': array(['Wingspan', 'Arm Length', 'Hand Size', 'Powerball Toss'],
#        dtype=object),
#  'FB': array(['Powerball Toss'], dtype=object),
#  'LS': array(['Arm Length', 'Powerball Toss'], dtype=object),
#  'P': array(['Wingspan', 'Arm Length', 'Hand Size', 'Powerball Toss'],
#        dtype=object)}

# %%
data.isna().sum()
# Out:
# Full Name                     0
# Last Name                     0
# Grad Year                     0
# Position                    248
# Height                        0
# Height Source                 0
# Weight                        0
# Weight Source                 0
# Zcruit Rating             49474
# Committed To              66941
# Commitment Date           66941
# Signed To                 68217
# Offers                    57754
# Visits                    69586
# Forty Yard Dash           35994
# Forty Yard Dash Source    35994
# Shuttle                   48741
# Shuttle Source            48741
# Vertical Jump             50106
# Vertical Jump Source      50106
# Broad Jump                51022
# Broad Jump Source         51022
# 3 Cone                    56172
# 3 Cone Source             56172
# Wingspan                  69035
# Wingspan Source           69035
# Arm Length                69927
# Arm Length Source         69927
# Hand Size                 69140
# Hand Size Source          69140
# Powerball Toss            71221
# Powerball Toss Source     71221
# SPARQ Rating              71271
# SPARQ Rating Source       71271
# GPA                       19898
# ACT                       66565
# SAT                       67717
# Unnamed: 37               71370
# Unnamed: 38               71356
# dtype: int64

# %% [markdown]
# ### Handling NaNs - Track and Field Data

# %%
zcruit_data = pd.read_csv("zcruit_and_combine.csv")

# %%
zcruit_data = zcruit_data.drop(columns = 'Unnamed: 0')

# %%
original_data = pd.read_csv("ZCruit_Data.csv", error_bad_lines=False)
# Out:
# b'Skipping line 1845: expected 70 fields, saw 72\nSkipping line 3345: expected 70 fields, saw 72\n'
# b'Skipping line 11921: expected 70 fields, saw 72\nSkipping line 12609: expected 70 fields, saw 72\nSkipping line 13420: expected 70 fields, saw 72\nSkipping line 14108: expected 70 fields, saw 72\nSkipping line 14512: expected 70 fields, saw 72\n'
# b'Skipping line 16512: expected 70 fields, saw 72\nSkipping line 21242: expected 70 fields, saw 72\nSkipping line 23743: expected 70 fields, saw 72\n'
# b'Skipping line 58041: expected 70 fields, saw 72\nSkipping line 60541: expected 70 fields, saw 72\n'
# b'Skipping line 70025: expected 70 fields, saw 72\nSkipping line 72525: expected 70 fields, saw 72\n'
# C:\Users\AlvinYu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,8,40,48,57,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
original_data.head(5)
# Out:
#                               Zcruit ID       Full Name First Name  Last Name  \
# 0  c4fcba47-0337-4047-bc4d-0187da6f698e  J.T. Tuimoloau       J.T.  Tuimoloau
# 1  1db04d99-cca6-4bfc-8a5a-3d40ae1795e0       JC Latham         JC     Latham
# 2  2481c4e2-f105-4e9f-b85d-0925a343910b   Korey Foreman      Korey    Foreman
# 3  90d817c7-b0d4-40c7-92d5-585d2bb09425  Caleb Williams      Caleb   Williams
# 4  7351f453-1854-48ba-aa2c-e6eb9f4b9859   Dallas Turner     Dallas     Turner
#
#   Grad Year Position   Height   Height Source Weight   Weight Source  ...  \
# 0      2021       DE    6' 4"  national_preps  275.0  national_preps  ...
# 1      2021       OT    6' 6"  national_preps  279.0    nike_opening  ...
# 2      2021       DE    6' 4"    nike_opening  248.0    nike_opening  ...
# 3      2021       QB    6' 1"  national_preps  209.0    nike_opening  ...
# 4      2021       DE  6' 2.5"     rivals_camp  223.0     rivals_camp  ...
#
#     GPA  ACT SAT         Twitter        Instagram   Snapchat  \
# 0  3.00  NaN NaN    JT_tuimoloau              NaN        NaN
# 1  2.35  NaN NaN         TKJaayy              NaN        NaN
# 2  3.03  NaN NaN  koreyforeman54  Koreyforeman_54  Korey4Man
# 3   NaN  NaN NaN        CALEBcsw              NaN        NaN
# 4  3.70  NaN NaN         UnoErra              NaN        NaN
#
#                                 247Sports  \
# 0  https://247sports.com/player/46048440/
# 1  https://247sports.com/player/46049894/
# 2  https://247sports.com/player/46056100/
# 3  https://247sports.com/player/46040610/
# 4  https://247sports.com/player/46051516/
#
#                                            Rivals  \
# 0  https://n.rivals.com/content/prospects/208999/
# 1  https://n.rivals.com/content/prospects/209086/
# 2  https://n.rivals.com/content/prospects/216686/
# 3  https://n.rivals.com/content/prospects/210175/
# 4  https://n.rivals.com/content/prospects/211051/
#
#                                          Hudl  \
# 0                                         NaN
# 1   www.hudl.com/profiles/feed-user/3-9698914
# 2  www.hudl.com/profiles/feed-user/3-10337933
# 3   www.hudl.com/profiles/feed-user/3-6269274
# 4   www.hudl.com/profiles/feed-user/3-6475053
#
#                                               Zcruit
# 0  https://zcruit.com/prospects/c4fcba47-0337-404...
# 1  https://zcruit.com/prospects/1db04d99-cca6-4bf...
# 2  https://zcruit.com/prospects/2481c4e2-f105-4e9...
# 3  https://zcruit.com/prospects/90d817c7-b0d4-40c...
# 4  https://zcruit.com/prospects/7351f453-1854-48b...
#
# [5 rows x 70 columns]

# %%
data.head(5)
# Out:
#         Full Name  Last Name  Grad Year Position  Height   Height Source  \
# 0   Korey Foreman    Foreman       2021       DE    76.0    nike_opening
# 1  J.T. Tuimoloau  Tuimoloau       2021       DE    76.0  national_preps
# 2       JC Latham     Latham       2021       OT    78.0  national_preps
# 3    Emeka Egbuka     Egbuka       2021       WR    72.5    nike_opening
# 4   Dallas Turner     Turner       2021       DE    74.5     rivals_camp
#
#    Weight   Weight Source  Zcruit Rating Committed To  ...  Hand Size Source  \
# 0   248.0    nike_opening        96.6970          USC  ...               NaN
# 1   275.0  national_preps        96.6970          NaN  ...               NaN
# 2   279.0    nike_opening        96.6970      Alabama  ...               NaN
# 3   190.0    nike_opening        96.3939   Ohio State  ...  national_combine
# 4   223.0     rivals_camp        96.3939      Alabama  ...       rivals_camp
#
#   Powerball Toss Powerball Toss Source SPARQ Rating  SPARQ Rating Source  \
# 0           44.5          nike_opening        98.76         nike_opening
# 1            NaN                   NaN          NaN                  NaN
# 2            NaN                   NaN          NaN                  NaN
# 3           41.0          nike_opening          NaN                  NaN
# 4            NaN                   NaN          NaN                  NaN
#
#     GPA  ACT SAT  Unnamed: 37 Unnamed: 38
# 0  3.03  NaN NaN          NaN         NaN
# 1  3.00  NaN NaN          NaN         NaN
# 2  2.35  NaN NaN          NaN         NaN
# 3  4.00  NaN NaN          NaN         NaN
# 4  3.70  NaN NaN          NaN         NaN
#
# [5 rows x 39 columns]

# %%
data['Grad Year'].value_counts()
# Out:
# 2021    36641
# 2022    22121
# 2023     9684
# 2024     2924
# Name: Grad Year, dtype: int64

# %%
data
# Out:
#               Full Name    Last Name  Grad Year Position  Height  \
# 0         Korey Foreman      Foreman       2021       DE    76.0
# 1        J.T. Tuimoloau    Tuimoloau       2021       DE    76.0
# 2             JC Latham       Latham       2021       OT    78.0
# 3          Emeka Egbuka       Egbuka       2021       WR    72.5
# 4         Dallas Turner       Turner       2021       DE    74.5
# ...                 ...          ...        ...      ...     ...
# 71365  Carl Collins III  Collins III       2022       WR    56.0
# 71366  Antrone\t Coston       Coston       2024       WR    61.0
# 71367  Gerald\t Lampkin      Lampkin       2024       WR    59.0
# 71368     Jaeden\t Hamm         Hamm       2024       WR    58.0
# 71369     Eugene Thomas       Thomas       2022       RB    57.0
#
#         Height Source  Weight   Weight Source  Zcruit Rating Committed To  \
# 0        nike_opening   248.0    nike_opening        96.6970          USC
# 1      national_preps   275.0  national_preps        96.6970          NaN
# 2      national_preps   279.0    nike_opening        96.6970      Alabama
# 3        nike_opening   190.0    nike_opening        96.3939   Ohio State
# 4         rivals_camp   223.0     rivals_camp        96.3939      Alabama
# ...               ...     ...             ...            ...          ...
# 71365          rivals    86.0          rivals            NaN          NaN
# 71366          rivals    85.0          rivals            NaN          NaN
# 71367          rivals    84.0          rivals            NaN          NaN
# 71368          rivals    80.0          rivals            NaN          NaN
# 71369          rivals    71.0          rivals            NaN          NaN
#
#        ...  Hand Size Source Powerball Toss Powerball Toss Source  \
# 0      ...               NaN           44.5          nike_opening
# 1      ...               NaN            NaN                   NaN
# 2      ...               NaN            NaN                   NaN
# 3      ...  national_combine           41.0          nike_opening
# 4      ...       rivals_camp            NaN                   NaN
# ...    ...               ...            ...                   ...
# 71365  ...               NaN            NaN                   NaN
# 71366  ...               NaN            NaN                   NaN
# 71367  ...               NaN            NaN                   NaN
# 71368  ...               NaN            NaN                   NaN
# 71369  ...               NaN            NaN                   NaN
#
#       SPARQ Rating  SPARQ Rating Source   GPA  ACT SAT  Unnamed: 37  \
# 0            98.76         nike_opening  3.03  NaN NaN          NaN
# 1              NaN                  NaN  3.00  NaN NaN          NaN
# 2              NaN                  NaN  2.35  NaN NaN          NaN
# 3              NaN                  NaN  4.00  NaN NaN          NaN
# 4              NaN                  NaN  3.70  NaN NaN          NaN
# ...            ...                  ...   ...  ...  ..          ...
# 71365          NaN                  NaN   NaN  NaN NaN          NaN
# 71366          NaN                  NaN   NaN  NaN NaN          NaN
# 71367          NaN                  NaN   NaN  NaN NaN          NaN
# 71368          NaN                  NaN   NaN  NaN NaN          NaN
# 71369          NaN                  NaN   NaN  NaN NaN          NaN
#
#       Unnamed: 38
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 71365         NaN
# 71366         NaN
# 71367         NaN
# 71368         NaN
# 71369         NaN
#
# [71370 rows x 39 columns]

# %%
original_data
# Out:
#                                    Zcruit ID           Full Name First Name  \
# 0       c4fcba47-0337-4047-bc4d-0187da6f698e      J.T. Tuimoloau       J.T.
# 1       1db04d99-cca6-4bfc-8a5a-3d40ae1795e0           JC Latham         JC
# 2       2481c4e2-f105-4e9f-b85d-0925a343910b       Korey Foreman      Korey
# 3       90d817c7-b0d4-40c7-92d5-585d2bb09425      Caleb Williams      Caleb
# 4       7351f453-1854-48ba-aa2c-e6eb9f4b9859       Dallas Turner     Dallas
# ...                                      ...                 ...        ...
# 110485  555493d1-4238-4a54-b006-eb4022a22807       Zyreon Rogers     Zyreon
# 110486  e0c678c7-8ef9-4d95-a988-456b45811eff     Zyshawn Witcher    Zyshawn
# 110487  5c88da3d-0953-4a48-beb3-3f8f398c31b2      Zyterius Watts   Zyterius
# 110488  82a03440-f03d-4d70-89f4-d378fc21a401      Zytwan Kitchen     Zytwan
# 110489  3a5f43a5-74c0-487b-8916-5566e7d0c305  Z’mari\t Arrington   Z’mari\t
#
#         Last Name Grad Year Position   Height   Height Source Weight  \
# 0       Tuimoloau      2021       DE    6' 4"  national_preps  275.0
# 1          Latham      2021       OT    6' 6"  national_preps  279.0
# 2         Foreman      2021       DE    6' 4"    nike_opening  248.0
# 3        Williams      2021       QB    6' 1"  national_preps  209.0
# 4          Turner      2021       DE  6' 2.5"     rivals_camp  223.0
# ...           ...       ...      ...      ...             ...    ...
# 110485     Rogers      2022       DL   5' 11"  national_preps  280.0
# 110486    Witcher      2022       QB    6' 0"            ncsa  156.0
# 110487      Watts      2022       RB    5' 8"  national_preps  175.0
# 110488    Kitchen      2021       RB    5' 6"  rivals_combine  157.0
# 110489  Arrington      2022       OG   5' 10"          rivals  270.0
#
#          Weight Source  ...   GPA  ACT SAT         Twitter        Instagram  \
# 0       national_preps  ...  3.00  NaN NaN    JT_tuimoloau              NaN
# 1         nike_opening  ...  2.35  NaN NaN         TKJaayy              NaN
# 2         nike_opening  ...  3.03  NaN NaN  koreyforeman54  Koreyforeman_54
# 3         nike_opening  ...   NaN  NaN NaN        CALEBcsw              NaN
# 4          rivals_camp  ...  3.70  NaN NaN         UnoErra              NaN
# ...                ...  ...   ...  ...  ..             ...              ...
# 110485  national_preps  ...  1.70  NaN NaN             NaN              NaN
# 110486            ncsa  ...  3.00  NaN NaN             NaN              NaN
# 110487  national_preps  ...  2.00  NaN NaN         atkwavy              NaN
# 110488  rivals_combine  ...  3.30  NaN NaN             NaN              NaN
# 110489          rivals  ...   NaN  NaN NaN             NaN              NaN
#
#          Snapchat                               247Sports  \
# 0             NaN  https://247sports.com/player/46048440/
# 1             NaN  https://247sports.com/player/46049894/
# 2       Korey4Man  https://247sports.com/player/46056100/
# 3             NaN  https://247sports.com/player/46040610/
# 4             NaN  https://247sports.com/player/46051516/
# ...           ...                                     ...
# 110485        NaN                                     NaN
# 110486        NaN                                     NaN
# 110487        NaN                                     NaN
# 110488        NaN                                     NaN
# 110489        NaN                                     NaN
#
#                                                 Rivals  \
# 0       https://n.rivals.com/content/prospects/208999/
# 1       https://n.rivals.com/content/prospects/209086/
# 2       https://n.rivals.com/content/prospects/216686/
# 3       https://n.rivals.com/content/prospects/210175/
# 4       https://n.rivals.com/content/prospects/211051/
# ...                                                ...
# 110485                                             NaN
# 110486                                             NaN
# 110487                                             NaN
# 110488  https://n.rivals.com/content/prospects/260969/
# 110489  https://n.rivals.com/content/prospects/265439/
#
#                                               Hudl  \
# 0                                              NaN
# 1        www.hudl.com/profiles/feed-user/3-9698914
# 2       www.hudl.com/profiles/feed-user/3-10337933
# 3        www.hudl.com/profiles/feed-user/3-6269274
# 4        www.hudl.com/profiles/feed-user/3-6475053
# ...                                            ...
# 110485                                         NaN
# 110486                                         NaN
# 110487                                         NaN
# 110488                                         NaN
# 110489                                         NaN
#
#                                                    Zcruit
# 0       https://zcruit.com/prospects/c4fcba47-0337-404...
# 1       https://zcruit.com/prospects/1db04d99-cca6-4bf...
# 2       https://zcruit.com/prospects/2481c4e2-f105-4e9...
# 3       https://zcruit.com/prospects/90d817c7-b0d4-40c...
# 4       https://zcruit.com/prospects/7351f453-1854-48b...
# ...                                                   ...
# 110485  https://zcruit.com/prospects/555493d1-4238-4a5...
# 110486  https://zcruit.com/prospects/e0c678c7-8ef9-4d9...
# 110487  https://zcruit.com/prospects/5c88da3d-0953-4a4...
# 110488  https://zcruit.com/prospects/82a03440-f03d-4d7...
# 110489  https://zcruit.com/prospects/3a5f43a5-74c0-487...
#
# [110490 rows x 70 columns]

# %%
idk = data.merge(original_data, how = "left", on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"], copy = False)

# %%
data_ryan_fill = data.fillna(-1000)
original_data_ryan_fill = original_data.fillna(-1000)

# %%
data_ryan_fill.shape[0]
# Out:
# 71370

# %%
data_ryan_fill.drop_duplicates().shape[0]
# Out:
# 71362

# %%
original_data.columns
# Out:
# Index(['Zcruit ID', 'Full Name', 'First Name', 'Last Name', 'Grad Year',
#        'Position', 'Height', 'Height Source', 'Weight', 'Weight Source',
#        'Zcruit Rating', 'Status', 'Committed To', 'Commitment Date',
#        'Signed To', 'Offers', 'Visits', 'Athlete Address', 'Athlete City',
#        'Athlete State', 'Athlete Zip Code', 'Athlete Cell Phone',
#        'Athlete Home Phone', 'DOB', 'Jersey Number', 'Parent Name',
#        'Parent Phone', 'Parent Email', 'HS/JuCo', 'School Name',
#        'School County', 'School Address', 'School City', 'School State',
#        'School Zip', 'ETS #', 'Coach Name', 'Coach Cell Phone',
#        'Coach Home Phone', 'Coach Email', 'Forty Yard Dash',
#        'Forty Yard Dash Source', 'Shuttle', 'Shuttle Source', 'Vertical Jump',
#        'Vertical Jump Source', 'Broad Jump', 'Broad Jump Source', '3 Cone',
#        '3 Cone Source', 'Wingspan', 'Wingspan Source', 'Arm Length',
#        'Arm Length Source', 'Hand Size', 'Hand Size Source', 'Powerball Toss',
#        'Powerball Toss Source', 'SPARQ Rating', 'SPARQ Rating Source', 'GPA',
#        'ACT', 'SAT', 'Twitter', 'Instagram', 'Snapchat', '247Sports', 'Rivals',
#        'Hudl', 'Zcruit'],
#       dtype='object')

# %%
good_columns = ["Zcruit ID", "Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"]
original_data = original_data[good_columns]

# %%
data.shape[0]
# Out:
# 71370

# %%
original_data["Full Name"].value_counts()
# Out:
# Connor Smith        20
# Jordan Smith        16
# Donovan Williams    16
# Jalen Johnson       15
# Elijah Smith        14
#                     ..
# Micheal Graham       1
# Luke Morley          1
# Ryan Harden          1
# John Alcalar         1
# Lee Thompson         1
# Name: Full Name, Length: 67747, dtype: int64

# %%
connor_smith_original_data = original_data[original_data["Full Name"] == "Connor Smith"]
connor_smith_data = data[data["Full Name"] == "Connor Smith"]

# %%
connor_smith_merge = connor_smith_data.merge(connor_smith_original_data, how = "left", on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"]).drop_duplicates()

# %%
connor_smith_merge['Grad Year'].values == connor_smith_data['Grad Year'].values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
connor_smith_data
# Out:
#           Full Name Last Name  Grad Year Position  Height   Height Source  \
# 7562   Connor Smith     Smith       2021       OT    77.0    twoFourSeven
# 14278  Connor Smith     Smith       2021       OC    72.0          rivals
# 25947  Connor Smith     Smith       2022       QB    72.0  rivals_combine
# 45936  Connor Smith     Smith       2021       TE    72.0  rivals_combine
# 51845  Connor Smith     Smith       2022       OT    71.0            ncsa
# 51970  Connor Smith     Smith       2023       QB    72.0            ncsa
# 52767  Connor Smith     Smith       2023       WR    67.0  rivals_combine
# 54601  Connor Smith     Smith       2021       RB    70.0  national_preps
# 67430  Connor Smith     Smith       2022       QB    74.0          rivals
# 70777  Connor Smith     Smith       2024       WR    68.0          rivals
#
#        Weight   Weight Source  Zcruit Rating    Committed To Commitment Date  \
# 7562    275.0    twoFourSeven          54.25            Yale        7/2/2020
# 14278   246.0          rivals          20.00             NaN             NaN
# 25947   163.0  rivals_combine            NaN             NaN             NaN
# 45936   187.0  rivals_combine            NaN  Morehead State      12/16/2020
# 51845   235.0            ncsa            NaN             NaN             NaN
# 51970   210.0            ncsa            NaN             NaN             NaN
# 52767   123.0  rivals_combine            NaN             NaN             NaN
# 54601   206.0  national_preps            NaN             NaN             NaN
# 67430   169.0          rivals            NaN             NaN             NaN
# 70777   133.0          rivals            NaN             NaN             NaN
#
#       Signed To                       Offers Visits  Forty Yard Dash  \
# 7562        NaN  Massachusetts; Bryant; Yale    NaN              NaN
# 14278       NaN                          NaN    NaN            5.100
# 25947       NaN                          NaN    NaN            5.597
# 45936       NaN                          NaN    NaN              NaN
# 51845       NaN                          NaN    NaN              NaN
# 51970       NaN                          NaN    NaN              NaN
# 52767       NaN                          NaN    NaN              NaN
# 54601       NaN                          NaN    NaN              NaN
# 67430       NaN                          NaN    NaN              NaN
# 70777       NaN                          NaN    NaN              NaN
#
#       Forty Yard Dash Source  Shuttle  Shuttle Source  Vertical Jump  \
# 7562                     NaN      NaN             NaN            NaN
# 14278                   ncsa      NaN             NaN            NaN
# 25947         rivals_combine    4.537  rivals_combine           19.3
# 45936                    NaN      NaN             NaN           27.9
# 51845                    NaN      NaN             NaN            NaN
# 51970                    NaN      NaN             NaN            NaN
# 52767                    NaN      NaN             NaN            NaN
# 54601                    NaN      NaN             NaN            NaN
# 67430                    NaN      NaN             NaN            NaN
# 70777                    NaN      NaN             NaN            NaN
#
#       Vertical Jump Source  Broad Jump Broad Jump Source  3 Cone  \
# 7562                   NaN         NaN               NaN     NaN
# 14278                  NaN         NaN               NaN     NaN
# 25947       rivals_combine        98.0    rivals_combine   7.734
# 45936       rivals_combine       104.0    rivals_combine     NaN
# 51845                  NaN         NaN               NaN     NaN
# 51970                  NaN         NaN               NaN     NaN
# 52767                  NaN         NaN               NaN     NaN
# 54601                  NaN         NaN               NaN     NaN
# 67430                  NaN         NaN               NaN     NaN
# 70777                  NaN         NaN               NaN     NaN
#
#         3 Cone Source  Wingspan Wingspan Source  Arm Length Arm Length Source  \
# 7562              NaN       NaN             NaN         NaN               NaN
# 14278             NaN       NaN             NaN         NaN               NaN
# 25947  rivals_combine       NaN             NaN         NaN               NaN
# 45936             NaN       NaN             NaN         NaN               NaN
# 51845             NaN       NaN             NaN         NaN               NaN
# 51970             NaN       NaN             NaN         NaN               NaN
# 52767             NaN       NaN             NaN         NaN               NaN
# 54601             NaN       NaN             NaN         NaN               NaN
# 67430             NaN       NaN             NaN         NaN               NaN
# 70777             NaN       NaN             NaN         NaN               NaN
#
#        Hand Size Hand Size Source  Powerball Toss Powerball Toss Source  \
# 7562         NaN              NaN             NaN                   NaN
# 14278        NaN              NaN             NaN                   NaN
# 25947        NaN              NaN             NaN                   NaN
# 45936        NaN              NaN             NaN                   NaN
# 51845        NaN              NaN             NaN                   NaN
# 51970        NaN              NaN             NaN                   NaN
# 52767        NaN              NaN             NaN                   NaN
# 54601        NaN              NaN             NaN                   NaN
# 67430        NaN              NaN             NaN                   NaN
# 70777        NaN              NaN             NaN                   NaN
#
#        SPARQ Rating SPARQ Rating Source  GPA  ACT  SAT  Unnamed: 37  \
# 7562            NaN                 NaN  NaN  NaN  NaN          NaN
# 14278           NaN                 NaN  3.3  NaN  NaN          NaN
# 25947           NaN                 NaN  3.5  NaN  NaN          NaN
# 45936           NaN                 NaN  3.4  NaN  NaN          NaN
# 51845           NaN                 NaN  3.0  NaN  NaN          NaN
# 51970           NaN                 NaN  3.0  NaN  NaN          NaN
# 52767           NaN                 NaN  3.0  NaN  NaN          NaN
# 54601           NaN                 NaN  2.7  NaN  NaN          NaN
# 67430           NaN                 NaN  NaN  NaN  NaN          NaN
# 70777           NaN                 NaN  NaN  NaN  NaN          NaN
#
#       Unnamed: 38
# 7562          NaN
# 14278         NaN
# 25947         NaN
# 45936         NaN
# 51845         NaN
# 51970         NaN
# 52767         NaN
# 54601         NaN
# 67430         NaN
# 70777         NaN

# %%
data["Full Name"].value_counts()
# Out:
# Jordan Smith       14
# Connor Smith       10
# Jayden Williams     9
# Jacob Smith         9
# Jordan Johnson      9
#                    ..
# Ashton Stroman      1
# Johnny Lindsay      1
# Tanner Cassell      1
# Jarred PArks        1
# Simeon Smith        1
# Name: Full Name, Length: 67648, dtype: int64

# %%
idk_2 = data.merge(original_data, how = "left", on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"])

# %%
idk_2 = idk_2.drop_duplicates()
idk_2
# Out:
#                Full Name    Last Name Grad Year Position  Height  \
# 0          Korey Foreman      Foreman      2021       DE    76.0
# 2         J.T. Tuimoloau    Tuimoloau      2021       DE    76.0
# 4              JC Latham       Latham      2021       OT    78.0
# 6           Emeka Egbuka       Egbuka      2021       WR    72.5
# 8          Dallas Turner       Turner      2021       DE    74.5
# ...                  ...          ...       ...      ...     ...
# 105124  Carl Collins III  Collins III      2022       WR    56.0
# 105126  Antrone\t Coston       Coston      2024       WR    61.0
# 105128  Gerald\t Lampkin      Lampkin      2024       WR    59.0
# 105129     Jaeden\t Hamm         Hamm      2024       WR    58.0
# 105130     Eugene Thomas       Thomas      2022       RB    57.0
#
#          Height Source  Weight   Weight Source  Zcruit Rating Committed To  \
# 0         nike_opening   248.0    nike_opening        96.6970          USC
# 2       national_preps   275.0  national_preps        96.6970          NaN
# 4       national_preps   279.0    nike_opening        96.6970      Alabama
# 6         nike_opening   190.0    nike_opening        96.3939   Ohio State
# 8          rivals_camp   223.0     rivals_camp        96.3939      Alabama
# ...                ...     ...             ...            ...          ...
# 105124          rivals    86.0          rivals            NaN          NaN
# 105126          rivals    85.0          rivals            NaN          NaN
# 105128          rivals    84.0          rivals            NaN          NaN
# 105129          rivals    80.0          rivals            NaN          NaN
# 105130          rivals    71.0          rivals            NaN          NaN
#
#        Commitment Date   Signed To  \
# 0             1/2/2021         USC
# 2                  NaN         NaN
# 4            6/12/2020     Alabama
# 6           12/11/2020  Ohio State
# 8             7/1/2020     Alabama
# ...                ...         ...
# 105124             NaN         NaN
# 105126             NaN         NaN
# 105128             NaN         NaN
# 105129             NaN         NaN
# 105130             NaN         NaN
#
#                                                    Offers  \
# 0       Sam Houston State; USC; Utah; Arizona; Oregon;...
# 2       Alabama; Texas A&M; Penn State; Ohio State; US...
# 4       Iowa; Minnesota; Michigan; Penn State; Oklahom...
# 6       Washington; Florida; Oklahoma; Washington Stat...
# 8       LSU; Kentucky; Baylor; Tennessee; Syracuse; Ma...
# ...                                                   ...
# 105124                                                NaN
# 105126                                                NaN
# 105128                                                NaN
# 105129                                                NaN
# 105130                                                NaN
#
#                                                    Visits  Forty Yard Dash  \
# 0                                                 Alabama            4.880
# 2                         Alabama; Washington; Washington            4.750
# 4                 Minnesota; Iowa; Ohio State; Ohio State            5.460
# 6       Florida State; Ohio State; Notre Dame; Michiga...            4.859
# 8       Miami (FL); Miami (FL); Florida State; Ohio St...            4.991
# ...                                                   ...              ...
# 105124                                                NaN              NaN
# 105126                                                NaN              NaN
# 105128                                                NaN              NaN
# 105129                                                NaN              NaN
# 105130                                                NaN              NaN
#
#        Forty Yard Dash Source  Shuttle    Shuttle Source  Vertical Jump  \
# 0                nike_opening    4.700      nike_opening           30.4
# 2              national_preps      NaN               NaN            NaN
# 4                nike_opening    4.870      nike_opening           26.8
# 6            national_combine    4.200      nike_opening           35.1
# 8            national_combine    4.487  national_combine           26.0
# ...                       ...      ...               ...            ...
# 105124                    NaN      NaN               NaN            NaN
# 105126                    NaN      NaN               NaN            NaN
# 105128                    NaN      NaN               NaN            NaN
# 105129                    NaN      NaN               NaN            NaN
# 105130                    NaN      NaN               NaN            NaN
#
#        Vertical Jump Source  Broad Jump Broad Jump Source  3 Cone  \
# 0              nike_opening       104.0    rivals_combine   7.758
# 2                       NaN         NaN               NaN     NaN
# 4              nike_opening         NaN               NaN     NaN
# 6              nike_opening       112.0  national_combine   7.083
# 8          national_combine       115.0  national_combine   7.752
# ...                     ...         ...               ...     ...
# 105124                  NaN         NaN               NaN     NaN
# 105126                  NaN         NaN               NaN     NaN
# 105128                  NaN         NaN               NaN     NaN
# 105129                  NaN         NaN               NaN     NaN
# 105130                  NaN         NaN               NaN     NaN
#
#            3 Cone Source  Wingspan   Wingspan Source  Arm Length  \
# 0         rivals_combine       NaN               NaN         NaN
# 2                    NaN       NaN               NaN         NaN
# 4                    NaN       NaN               NaN         NaN
# 6       national_combine      75.0  national_combine         NaN
# 8       national_combine      83.5       rivals_camp       34.25
# ...                  ...       ...               ...         ...
# 105124               NaN       NaN               NaN         NaN
# 105126               NaN       NaN               NaN         NaN
# 105128               NaN       NaN               NaN         NaN
# 105129               NaN       NaN               NaN         NaN
# 105130               NaN       NaN               NaN         NaN
#
#        Arm Length Source  Hand Size  Hand Size Source  Powerball Toss  \
# 0                    NaN        NaN               NaN            44.5
# 2                    NaN        NaN               NaN             NaN
# 4                    NaN        NaN               NaN             NaN
# 6                    NaN       9.00  national_combine            41.0
# 8            rivals_camp       9.84       rivals_camp             NaN
# ...                  ...        ...               ...             ...
# 105124               NaN        NaN               NaN             NaN
# 105126               NaN        NaN               NaN             NaN
# 105128               NaN        NaN               NaN             NaN
# 105129               NaN        NaN               NaN             NaN
# 105130               NaN        NaN               NaN             NaN
#
#        Powerball Toss Source  SPARQ Rating SPARQ Rating Source   GPA  ACT  \
# 0               nike_opening         98.76        nike_opening  3.03  NaN
# 2                        NaN           NaN                 NaN  3.00  NaN
# 4                        NaN           NaN                 NaN  2.35  NaN
# 6               nike_opening           NaN                 NaN  4.00  NaN
# 8                        NaN           NaN                 NaN  3.70  NaN
# ...                      ...           ...                 ...   ...  ...
# 105124                   NaN           NaN                 NaN   NaN  NaN
# 105126                   NaN           NaN                 NaN   NaN  NaN
# 105128                   NaN           NaN                 NaN   NaN  NaN
# 105129                   NaN           NaN                 NaN   NaN  NaN
# 105130                   NaN           NaN                 NaN   NaN  NaN
#
#         SAT  Unnamed: 37 Unnamed: 38                             Zcruit ID
# 0       NaN          NaN         NaN  2481c4e2-f105-4e9f-b85d-0925a343910b
# 2       NaN          NaN         NaN  c4fcba47-0337-4047-bc4d-0187da6f698e
# 4       NaN          NaN         NaN  1db04d99-cca6-4bfc-8a5a-3d40ae1795e0
# 6       NaN          NaN         NaN  abda246f-bb45-4b10-baf1-a9e5d508cc84
# 8       NaN          NaN         NaN  7351f453-1854-48ba-aa2c-e6eb9f4b9859
# ...     ...          ...         ...                                   ...
# 105124  NaN          NaN         NaN  1a456275-5dc4-49dd-a0dc-be45d36f0653
# 105126  NaN          NaN         NaN  cb489357-272f-49cd-99a4-903bcbd6ed86
# 105128  NaN          NaN         NaN  f5cbe094-2e5a-42b4-9917-d0a5121a0a33
# 105129  NaN          NaN         NaN  2d1ba563-d8b0-42de-aca2-38702763aa64
# 105130  NaN          NaN         NaN  7d27d80b-1156-45ec-afe0-6f638d45fea6
#
# [71518 rows x 40 columns]

# %%
full_names = data["Full Name"].values

# %%
len(full_names)
# Out:
# 71370

# %%
idk_2[idk_2['Full Name'].isin(full_names) == False]
# Out:
# Empty DataFrame
# Columns: [Full Name, Last Name, Grad Year, Position, Height, Height Source, Weight, Weight Source, Zcruit Rating, Committed To, Commitment Date, Signed To, Offers, Visits, Forty Yard Dash, Forty Yard Dash Source, Shuttle, Shuttle Source, Vertical Jump, Vertical Jump Source, Broad Jump, Broad Jump Source, 3 Cone, 3 Cone Source, Wingspan, Wingspan Source, Arm Length, Arm Length Source, Hand Size, Hand Size Source, Powerball Toss, Powerball Toss Source, SPARQ Rating, SPARQ Rating Source, GPA, ACT, SAT, Unnamed: 37, Unnamed: 38, Zcruit ID]
# Index: []

# %%
idk_ryan = data_ryan_fill.merge(original_data_ryan_fill, how = "left", on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"])

# %%
idk_ryan.drop_duplicates().shape[0]
# Out:
# 73415

# %%
s = idk_ryan.iloc[0] == idk_ryan.iloc[1]
s.values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
pd.set_option('display.max_columns', None)
idk
# Out:
#                Full Name Last Name_x Grad Year Position  Height_x  \
# 0          Korey Foreman     Foreman      2021       DE      76.0
# 1          Korey Foreman     Foreman      2021       DE      76.0
# 2         J.T. Tuimoloau   Tuimoloau      2021       DE      76.0
# 3         J.T. Tuimoloau   Tuimoloau      2021       DE      76.0
# 4              JC Latham      Latham      2021       OT      78.0
# ...                  ...         ...       ...      ...       ...
# 105127  Antrone\t Coston      Coston      2024       WR      61.0
# 105128  Gerald\t Lampkin     Lampkin      2024       WR      59.0
# 105129     Jaeden\t Hamm        Hamm      2024       WR      58.0
# 105130     Eugene Thomas      Thomas      2022       RB      57.0
# 105131     Eugene Thomas      Thomas      2022       RB      57.0
#
#          Height Source  Weight_x   Weight Source  Zcruit Rating_x  \
# 0         nike_opening     248.0    nike_opening           96.697
# 1         nike_opening     248.0    nike_opening           96.697
# 2       national_preps     275.0  national_preps           96.697
# 3       national_preps     275.0  national_preps           96.697
# 4       national_preps     279.0    nike_opening           96.697
# ...                ...       ...             ...              ...
# 105127          rivals      85.0          rivals              NaN
# 105128          rivals      84.0          rivals              NaN
# 105129          rivals      80.0          rivals              NaN
# 105130          rivals      71.0          rivals              NaN
# 105131          rivals      71.0          rivals              NaN
#
#        Committed To Commitment Date_x Signed To_x  \
# 0               USC          1/2/2021         USC
# 1               USC          1/2/2021         USC
# 2               NaN               NaN         NaN
# 3               NaN               NaN         NaN
# 4           Alabama         6/12/2020     Alabama
# ...             ...               ...         ...
# 105127          NaN               NaN         NaN
# 105128          NaN               NaN         NaN
# 105129          NaN               NaN         NaN
# 105130          NaN               NaN         NaN
# 105131          NaN               NaN         NaN
#
#                                                  Offers_x  \
# 0       Sam Houston State; USC; Utah; Arizona; Oregon;...
# 1       Sam Houston State; USC; Utah; Arizona; Oregon;...
# 2       Alabama; Texas A&M; Penn State; Ohio State; US...
# 3       Alabama; Texas A&M; Penn State; Ohio State; US...
# 4       Iowa; Minnesota; Michigan; Penn State; Oklahom...
# ...                                                   ...
# 105127                                                NaN
# 105128                                                NaN
# 105129                                                NaN
# 105130                                                NaN
# 105131                                                NaN
#
#                                        Visits_x  Forty Yard Dash_x  \
# 0                                       Alabama               4.88
# 1                                       Alabama               4.88
# 2               Alabama; Washington; Washington               4.75
# 3               Alabama; Washington; Washington               4.75
# 4       Minnesota; Iowa; Ohio State; Ohio State               5.46
# ...                                         ...                ...
# 105127                                      NaN                NaN
# 105128                                      NaN                NaN
# 105129                                      NaN                NaN
# 105130                                      NaN                NaN
# 105131                                      NaN                NaN
#
#        Forty Yard Dash Source_x  Shuttle_x Shuttle Source_x  Vertical Jump_x  \
# 0                  nike_opening       4.70     nike_opening             30.4
# 1                  nike_opening       4.70     nike_opening             30.4
# 2                national_preps        NaN              NaN              NaN
# 3                national_preps        NaN              NaN              NaN
# 4                  nike_opening       4.87     nike_opening             26.8
# ...                         ...        ...              ...              ...
# 105127                      NaN        NaN              NaN              NaN
# 105128                      NaN        NaN              NaN              NaN
# 105129                      NaN        NaN              NaN              NaN
# 105130                      NaN        NaN              NaN              NaN
# 105131                      NaN        NaN              NaN              NaN
#
#        Vertical Jump Source_x  Broad Jump_x Broad Jump Source_x  3 Cone_x  \
# 0                nike_opening         104.0      rivals_combine     7.758
# 1                nike_opening         104.0      rivals_combine     7.758
# 2                         NaN           NaN                 NaN       NaN
# 3                         NaN           NaN                 NaN       NaN
# 4                nike_opening           NaN                 NaN       NaN
# ...                       ...           ...                 ...       ...
# 105127                    NaN           NaN                 NaN       NaN
# 105128                    NaN           NaN                 NaN       NaN
# 105129                    NaN           NaN                 NaN       NaN
# 105130                    NaN           NaN                 NaN       NaN
# 105131                    NaN           NaN                 NaN       NaN
#
#        3 Cone Source_x  Wingspan_x Wingspan Source_x  Arm Length_x  \
# 0       rivals_combine         NaN               NaN           NaN
# 1       rivals_combine         NaN               NaN           NaN
# 2                  NaN         NaN               NaN           NaN
# 3                  NaN         NaN               NaN           NaN
# 4                  NaN         NaN               NaN           NaN
# ...                ...         ...               ...           ...
# 105127             NaN         NaN               NaN           NaN
# 105128             NaN         NaN               NaN           NaN
# 105129             NaN         NaN               NaN           NaN
# 105130             NaN         NaN               NaN           NaN
# 105131             NaN         NaN               NaN           NaN
#
#        Arm Length Source_x  Hand Size_x Hand Size Source_x  Powerball Toss_x  \
# 0                      NaN          NaN                NaN              44.5
# 1                      NaN          NaN                NaN              44.5
# 2                      NaN          NaN                NaN               NaN
# 3                      NaN          NaN                NaN               NaN
# 4                      NaN          NaN                NaN               NaN
# ...                    ...          ...                ...               ...
# 105127                 NaN          NaN                NaN               NaN
# 105128                 NaN          NaN                NaN               NaN
# 105129                 NaN          NaN                NaN               NaN
# 105130                 NaN          NaN                NaN               NaN
# 105131                 NaN          NaN                NaN               NaN
#
#        Powerball Toss Source_x  SPARQ Rating_x SPARQ Rating Source_x  GPA_x  \
# 0                 nike_opening           98.76          nike_opening   3.03
# 1                 nike_opening           98.76          nike_opening   3.03
# 2                          NaN             NaN                   NaN   3.00
# 3                          NaN             NaN                   NaN   3.00
# 4                          NaN             NaN                   NaN   2.35
# ...                        ...             ...                   ...    ...
# 105127                     NaN             NaN                   NaN    NaN
# 105128                     NaN             NaN                   NaN    NaN
# 105129                     NaN             NaN                   NaN    NaN
# 105130                     NaN             NaN                   NaN    NaN
# 105131                     NaN             NaN                   NaN    NaN
#
#         ACT_x  SAT_x  Unnamed: 37 Unnamed: 38  \
# 0         NaN    NaN          NaN         NaN
# 1         NaN    NaN          NaN         NaN
# 2         NaN    NaN          NaN         NaN
# 3         NaN    NaN          NaN         NaN
# 4         NaN    NaN          NaN         NaN
# ...       ...    ...          ...         ...
# 105127    NaN    NaN          NaN         NaN
# 105128    NaN    NaN          NaN         NaN
# 105129    NaN    NaN          NaN         NaN
# 105130    NaN    NaN          NaN         NaN
# 105131    NaN    NaN          NaN         NaN
#
#                                    Zcruit ID First Name Last Name_y Height_y  \
# 0       2481c4e2-f105-4e9f-b85d-0925a343910b      Korey     Foreman    6' 4"
# 1       2481c4e2-f105-4e9f-b85d-0925a343910b      Korey     Foreman    6' 4"
# 2       c4fcba47-0337-4047-bc4d-0187da6f698e       J.T.   Tuimoloau    6' 4"
# 3       c4fcba47-0337-4047-bc4d-0187da6f698e       J.T.   Tuimoloau    6' 4"
# 4       1db04d99-cca6-4bfc-8a5a-3d40ae1795e0         JC      Latham    6' 6"
# ...                                      ...        ...         ...      ...
# 105127  cb489357-272f-49cd-99a4-903bcbd6ed86  Antrone\t      Coston    5' 1"
# 105128  f5cbe094-2e5a-42b4-9917-d0a5121a0a33   Gerald\t     Lampkin   4' 11"
# 105129  2d1ba563-d8b0-42de-aca2-38702763aa64   Jaeden\t        Hamm   4' 10"
# 105130  7d27d80b-1156-45ec-afe0-6f638d45fea6     Eugene      Thomas    4' 9"
# 105131  7d27d80b-1156-45ec-afe0-6f638d45fea6     Eugene      Thomas    4' 9"
#
#        Weight_y  Zcruit Rating_y  Status Commitment Date_y Signed To_y  \
# 0         248.0           96.697     NaN          2021-1-2         USC
# 1         248.0           96.697     NaN          2021-1-2         USC
# 2         275.0           96.697     NaN               NaN         NaN
# 3         275.0           96.697     NaN               NaN         NaN
# 4         279.0           96.697     NaN         2020-6-12     Alabama
# ...         ...              ...     ...               ...         ...
# 105127     85.0              NaN     NaN               NaN         NaN
# 105128     84.0              NaN     NaN               NaN         NaN
# 105129     80.0              NaN     NaN               NaN         NaN
# 105130     71.0              NaN     NaN               NaN         NaN
# 105131     71.0              NaN     NaN               NaN         NaN
#
#                                                  Offers_y  \
# 0       Sam Houston State; USC; Utah; Arizona; Oregon;...
# 1       Sam Houston State; USC; Utah; Arizona; Oregon;...
# 2       Alabama; Texas A&M; Penn State; Ohio State; US...
# 3       Alabama; Texas A&M; Penn State; Ohio State; US...
# 4       Iowa; Minnesota; Michigan; Penn State; Oklahom...
# ...                                                   ...
# 105127                                                NaN
# 105128                                                NaN
# 105129                                                NaN
# 105130                                                NaN
# 105131                                                NaN
#
#                                        Visits_y           Athlete Address  \
# 0                                       Alabama  1880 Baywood Dr, Apt 201
# 1                                       Alabama  1880 Baywood Dr, Apt 201
# 2               Alabama; Washington; Washington                       NaN
# 3               Alabama; Washington; Washington                       NaN
# 4       Minnesota; Iowa; Ohio State; Ohio State         8323 S. Verdev Dr
# ...                                         ...                       ...
# 105127                                      NaN                       NaN
# 105128                                      NaN                       NaN
# 105129                                      NaN                       NaN
# 105130                                      NaN                       NaN
# 105131                                      NaN                       NaN
#
#        Athlete City Athlete State  Athlete Zip Code Athlete Cell Phone  \
# 0            Corona            CA           92881.0     (323) 316-3855
# 1            Corona            CA           92881.0     (323) 316-3855
# 2         Sammamish            WA           98074.0     (253) 431-8348
# 3         Sammamish            WA           98074.0     (253) 431-8348
# 4         Oak Creek            WI           53154.0     (262) 617-8925
# ...             ...           ...               ...                ...
# 105127          NaN           NaN               NaN                NaN
# 105128          NaN           NaN               NaN                NaN
# 105129          NaN           NaN               NaN                NaN
# 105130          NaN           NaN               NaN                NaN
# 105131          NaN           NaN               NaN                NaN
#
#        Athlete Home Phone  DOB Jersey Number             Parent Name  \
# 0          (323) 316-3855  NaN             2  Kevin/Mariessa Foreman
# 1          (323) 316-3855  NaN             2  Kevin/Mariessa Foreman
# 2                     NaN  NaN            33                     NaN
# 3                     NaN  NaN            33                     NaN
# 4          (262) 930-0593  NaN            55                     NaN
# ...                   ...  ...           ...                     ...
# 105127                NaN  NaN           NaN                     NaN
# 105128                NaN  NaN           NaN                     NaN
# 105129                NaN  NaN           NaN                     NaN
# 105130                NaN  NaN           NaN                     NaN
# 105131                NaN  NaN           NaN                     NaN
#
#           Parent Phone               Parent Email HS/JuCo  \
# 0       (323) 316-3855  Mariessaforeman@Gmail.Com      HS
# 1       (323) 316-3855  Mariessaforeman@Gmail.Com      HS
# 2                  NaN                        NaN      HS
# 3                  NaN                        NaN      HS
# 4                  NaN                        NaN      HS
# ...                ...                        ...     ...
# 105127             NaN                        NaN      HS
# 105128             NaN                        NaN      HS
# 105129             NaN                        NaN      HS
# 105130             NaN                        NaN      HS
# 105131             NaN                        NaN      HS
#
#                           School Name School County         School Address  \
# 0              Centennial High School     Riverside        1820 RIMPAU AVE
# 1              Centennial High School     Riverside        1820 RIMPAU AVE
# 2       Eastside Catholic High School          King       232 228TH AVE SE
# 3       Eastside Catholic High School          King       232 228TH AVE SE
# 4                         IMG Academy       Manatee         5500 34TH ST W
# ...                               ...           ...                    ...
# 105127      Saint Brendan High School    Miami-Dade       2950 SW 87TH AVE
# 105128         John Ehret High School     Jefferson        4300 PATRIOT ST
# 105129                  Middle School           NaN                    NaN
# 105130   Arlington Country Day School         Duval  5725 FORT CAROLINE RD
# 105131   Arlington Country Day School         Duval  5725 FORT CAROLINE RD
#
#          School City School State  School Zip     ETS #     Coach Name  \
# 0             Corona           CA     92881.0   50676.0     Matt Logan
# 1             Corona           CA     92881.0   50676.0     Matt Logan
# 2          Sammamish           WA     98074.0  480067.0  Dominic Daste
# 3          Sammamish           WA     98074.0  480067.0  Dominic Daste
# 4          Bradenton           FL     34210.0  100179.0   Bobby Acosta
# ...              ...          ...         ...       ...            ...
# 105127         Miami           FL     33165.0  101097.0            NaN
# 105128       Marrero           LA     70072.0  191724.0            NaN
# 105129           NaN          NaN         NaN       NaN            NaN
# 105130  Jacksonville           FL     32277.0  100731.0            NaN
# 105131  Jacksonville           FL     32277.0  100731.0            NaN
#
#        Coach Cell Phone Coach Home Phone                  Coach Email  \
# 0        (951) 532-9105   (951) 739-5670     huskycoach@sbcglobal.net
# 1        (951) 532-9105   (951) 739-5670     huskycoach@sbcglobal.net
# 2        (425) 681-1965   (425) 295-3148  ddaste@eastsidecatholic.org
# 3        (425) 681-1965   (425) 295-3148  ddaste@eastsidecatholic.org
# 4                   NaN   (941) 739-7399                          NaN
# ...                 ...              ...                          ...
# 105127              NaN              NaN                          NaN
# 105128              NaN              NaN                          NaN
# 105129              NaN              NaN                          NaN
# 105130              NaN              NaN                          NaN
# 105131              NaN              NaN                          NaN
#
#        Forty Yard Dash_y Forty Yard Dash Source_y  Shuttle_y Shuttle Source_y  \
# 0                   4.88             nike_opening       4.70     nike_opening
# 1                   4.88             nike_opening       4.70     nike_opening
# 2                   4.75           national_preps        NaN              NaN
# 3                   4.75           national_preps        NaN              NaN
# 4                   5.46             nike_opening       4.87     nike_opening
# ...                  ...                      ...        ...              ...
# 105127               NaN                      NaN        NaN              NaN
# 105128               NaN                      NaN        NaN              NaN
# 105129               NaN                      NaN        NaN              NaN
# 105130               NaN                      NaN        NaN              NaN
# 105131               NaN                      NaN        NaN              NaN
#
#         Vertical Jump_y Vertical Jump Source_y  Broad Jump_y  \
# 0                  30.4           nike_opening         104.0
# 1                  30.4           nike_opening         104.0
# 2                   NaN                    NaN           NaN
# 3                   NaN                    NaN           NaN
# 4                  26.8           nike_opening           NaN
# ...                 ...                    ...           ...
# 105127              NaN                    NaN           NaN
# 105128              NaN                    NaN           NaN
# 105129              NaN                    NaN           NaN
# 105130              NaN                    NaN           NaN
# 105131              NaN                    NaN           NaN
#
#        Broad Jump Source_y 3 Cone_y 3 Cone Source_y  Wingspan_y  \
# 0           rivals_combine    7.758  rivals_combine         NaN
# 1           rivals_combine    7.758  rivals_combine         NaN
# 2                      NaN      NaN             NaN         NaN
# 3                      NaN      NaN             NaN         NaN
# 4                      NaN      NaN             NaN         NaN
# ...                    ...      ...             ...         ...
# 105127                 NaN      NaN             NaN         NaN
# 105128                 NaN      NaN             NaN         NaN
# 105129                 NaN      NaN             NaN         NaN
# 105130                 NaN      NaN             NaN         NaN
# 105131                 NaN      NaN             NaN         NaN
#
#        Wingspan Source_y  Arm Length_y Arm Length Source_y  Hand Size_y  \
# 0                    NaN           NaN                 NaN          NaN
# 1                    NaN           NaN                 NaN          NaN
# 2                    NaN           NaN                 NaN          NaN
# 3                    NaN           NaN                 NaN          NaN
# 4                    NaN           NaN                 NaN          NaN
# ...                  ...           ...                 ...          ...
# 105127               NaN           NaN                 NaN          NaN
# 105128               NaN           NaN                 NaN          NaN
# 105129               NaN           NaN                 NaN          NaN
# 105130               NaN           NaN                 NaN          NaN
# 105131               NaN           NaN                 NaN          NaN
#
#        Hand Size Source_y  Powerball Toss_y Powerball Toss Source_y  \
# 0                     NaN              44.5            nike_opening
# 1                     NaN              44.5            nike_opening
# 2                     NaN               NaN                     NaN
# 3                     NaN               NaN                     NaN
# 4                     NaN               NaN                     NaN
# ...                   ...               ...                     ...
# 105127                NaN               NaN                     NaN
# 105128                NaN               NaN                     NaN
# 105129                NaN               NaN                     NaN
# 105130                NaN               NaN                     NaN
# 105131                NaN               NaN                     NaN
#
#         SPARQ Rating_y SPARQ Rating Source_y  GPA_y  ACT_y  SAT_y  \
# 0                98.76          nike_opening   3.03    NaN    NaN
# 1                98.76          nike_opening   3.03    NaN    NaN
# 2                  NaN                   NaN   3.00    NaN    NaN
# 3                  NaN                   NaN   3.00    NaN    NaN
# 4                  NaN                   NaN   2.35    NaN    NaN
# ...                ...                   ...    ...    ...    ...
# 105127             NaN                   NaN    NaN    NaN    NaN
# 105128             NaN                   NaN    NaN    NaN    NaN
# 105129             NaN                   NaN    NaN    NaN    NaN
# 105130             NaN                   NaN    NaN    NaN    NaN
# 105131             NaN                   NaN    NaN    NaN    NaN
#
#                 Twitter        Instagram   Snapchat  \
# 0        koreyforeman54  Koreyforeman_54  Korey4Man
# 1        koreyforeman54  Koreyforeman_54  Korey4Man
# 2          JT_tuimoloau              NaN        NaN
# 3          JT_tuimoloau              NaN        NaN
# 4               TKJaayy              NaN        NaN
# ...                 ...              ...        ...
# 105127              NaN              NaN        NaN
# 105128              NaN              NaN        NaN
# 105129              NaN              NaN        NaN
# 105130  eugene_thomas45              NaN        NaN
# 105131  eugene_thomas45              NaN        NaN
#
#                                      247Sports  \
# 0       https://247sports.com/player/46056100/
# 1       https://247sports.com/player/46056100/
# 2       https://247sports.com/player/46048440/
# 3       https://247sports.com/player/46048440/
# 4       https://247sports.com/player/46049894/
# ...                                        ...
# 105127                                     NaN
# 105128                                     NaN
# 105129                                     NaN
# 105130                                     NaN
# 105131                                     NaN
#
#                                                 Rivals  \
# 0       https://n.rivals.com/content/prospects/216686/
# 1       https://n.rivals.com/content/prospects/216686/
# 2       https://n.rivals.com/content/prospects/208999/
# 3       https://n.rivals.com/content/prospects/208999/
# 4       https://n.rivals.com/content/prospects/209086/
# ...                                                ...
# 105127  https://n.rivals.com/content/prospects/266438/
# 105128  https://n.rivals.com/content/prospects/266052/
# 105129  https://n.rivals.com/content/prospects/262899/
# 105130  https://n.rivals.com/content/prospects/213073/
# 105131  https://n.rivals.com/content/prospects/213073/
#
#                                               Hudl  \
# 0       www.hudl.com/profiles/feed-user/3-10337933
# 1       www.hudl.com/profiles/feed-user/3-10337933
# 2                                              NaN
# 3                                              NaN
# 4        www.hudl.com/profiles/feed-user/3-9698914
# ...                                            ...
# 105127                                         NaN
# 105128                                         NaN
# 105129                                         NaN
# 105130                                         NaN
# 105131                                         NaN
#
#                                                    Zcruit
# 0       https://zcruit.com/prospects/2481c4e2-f105-4e9...
# 1       https://zcruit.com/prospects/2481c4e2-f105-4e9...
# 2       https://zcruit.com/prospects/c4fcba47-0337-404...
# 3       https://zcruit.com/prospects/c4fcba47-0337-404...
# 4       https://zcruit.com/prospects/1db04d99-cca6-4bf...
# ...                                                   ...
# 105127  https://zcruit.com/prospects/cb489357-272f-49c...
# 105128  https://zcruit.com/prospects/f5cbe094-2e5a-42b...
# 105129  https://zcruit.com/prospects/2d1ba563-d8b0-42d...
# 105130  https://zcruit.com/prospects/7d27d80b-1156-45e...
# 105131  https://zcruit.com/prospects/7d27d80b-1156-45e...
#
# [105132 rows x 103 columns]

# %%
data.join(original_data, how = "left",  on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-3be24cef38ca> in <module>
# ----> 1 data.join(original_data, how = "left",  on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    8108         5  K5  A5  NaN
#    8109         """
# -> 8110         return self._join_compat(
#    8111             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8133                     sort=sort,
#    8134                 )
# -> 8135             return merge(
#    8136                 self,
#    8137                 other,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_specification(self)
#    1316             if self.right_index:
#    1317                 if len(self.left_on) != self.right.index.nlevels:
# -> 1318                     raise ValueError(
#    1319                         "len(left_on) must equal the number "
#    1320                         'of levels in the index of "right"'
#
# ValueError: len(left_on) must equal the number of levels in the index of "right"

# %%
idk.iloc[1]
# Out:
# Full Name                                          Korey Foreman
# Last Name_x                                              Foreman
# Grad Year                                                   2021
# Position                                                      DE
# Height_x                                                    76.0
#                                      ...
# Snapchat                                               Korey4Man
# 247Sports                 https://247sports.com/player/46056100/
# Rivals            https://n.rivals.com/content/prospects/216686/
# Hudl                  www.hudl.com/profiles/feed-user/3-10337933
# Zcruit         https://zcruit.com/prospects/2481c4e2-f105-4e9...
# Name: 1, Length: 103, dtype: object

# %%
zcruit_data
# Out:
#               Full Name Position  Height  Weight  Forty Yard Dash  3 Cone  \
# 0         Korey Foreman       DE    76.0   248.0           4.8800  7.7580
# 1        J.T. Tuimoloau       DE    76.0   275.0           4.7500  8.1930
# 2             JC Latham       OT    78.0   279.0           5.4600  8.2187
# 3          Emeka Egbuka       WR    72.5   190.0           4.8590  7.0830
# 4         Dallas Turner       DE    74.5   223.0           4.9910  7.7520
# ...                 ...      ...     ...     ...              ...     ...
# 71117  Carl Collins III       WR    56.0    86.0           6.3404  7.0215
# 71118  Antrone\t Coston       WR    61.0    85.0           6.3404  7.0215
# 71119  Gerald\t Lampkin       WR    59.0    84.0           6.3404  7.0215
# 71120     Jaeden\t Hamm       WR    58.0    80.0           6.3404  7.0215
# 71121     Eugene Thomas       RB    57.0    71.0           4.9970  7.7500
#
#        Shuttle  Vertical Jump  Broad Jump   Wingspan  Arm Length  Hand Size  \
# 0       4.7000       30.40000    104.0000  79.386800   33.250000   9.691052
# 1       4.9085       22.82900     93.0000  79.386800   33.250000   8.753886
# 2       4.8700       26.80000     90.9524  79.500000   34.000000  10.220960
# 3       4.2000       35.10000    112.0000  75.000000   32.193956   9.000000
# 4       4.4870       26.00000    115.0000  83.500000   34.250000   9.840000
# ...        ...            ...         ...        ...         ...        ...
# 71117   4.6500       31.90000     81.2572  59.464035   31.500000   7.813360
# 71118   4.6500       31.90000     81.2572  64.233611   31.500000   7.813360
# 71119   4.6500       31.90000     81.2572  62.325780   31.500000   7.813360
# 71120   4.6500       31.90000     81.2572  61.371865   31.500000   7.813360
# 71121   4.6540       18.97952     79.4960  60.001238   31.000000   7.813360
#
#        Powerball Toss
# 0           44.500000
# 1           39.000000
# 2           29.176265
# 3           41.000000
# 4           38.378617
# ...               ...
# 71117       38.750000
# 71118       38.750000
# 71119       38.750000
# 71120       38.750000
# 71121       27.761600
#
# [71122 rows x 13 columns]

# %%
tf_data = pd.read_csv("clean_tf_data.csv", sep=",")

# %%
tf_data = tf_data.drop(columns = 'Unnamed: 0')

# %%
tf_data
# Out:
#                                  Zcruit ID         Player Name  100 Meter  \
# 0     7b8c6df6-b548-4ed4-ae9b-4a741d7746c6    Bryson Lightfoot      11.25
# 1     45be7538-29ad-4e4a-9d2e-be05b0d3f595         Jalik Lewis        NaN
# 2     ae1749c5-a0f1-4fbc-852b-1ac51f5b1404        Jaiden Brown        NaN
# 3     eb32fcc6-a8f5-41df-b524-a4fc824a14f3         Mark Phifer      12.51
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737      Gerimiah Brown      11.74
# ...                                    ...                 ...        ...
# 7667  f1873c0b-a931-4604-a33c-4439e32789eb        Jerod Thomas      12.26
# 7668  1f7b327a-510e-4070-a3cd-bc0d2433010f       Tyler Bradley      11.51
# 7669  6bcf9f7b-4c2d-4db2-a19e-bdea9c358d04  Jesse James Garcia      12.23
# 7670  fb194f5e-bc21-4852-838b-443eebac9aaf     Isaiah Robinson      11.53
# 7671  167feedc-df71-41cd-a151-d34f8b20decf       Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 0           NaN                NaN                NaN        NaN        NaN
# 1         24.95                NaN                NaN       66.0     217.00
# 2         25.90                NaN                NaN        NaN        NaN
# 3         24.94                NaN                NaN        NaN        NaN
# 4         25.77                NaN              47.84        NaN     207.50
# ...         ...                ...                ...        ...        ...
# 7667        NaN                NaN                NaN       64.0        NaN
# 7668      23.05                NaN                NaN        NaN     199.25
# 7669      24.16                NaN                NaN        NaN     176.50
# 7670      24.10                NaN                NaN        NaN     234.00
# 7671      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus
# 0             NaN      NaN     NaN
# 1             NaN      NaN     NaN
# 2             NaN    490.5     NaN
# 3             NaN      NaN     NaN
# 4             NaN      NaN     NaN
# ...           ...      ...     ...
# 7667          NaN      NaN     NaN
# 7668        433.5      NaN     NaN
# 7669          NaN      NaN     NaN
# 7670          NaN      NaN     NaN
# 7671          NaN      NaN     NaN
#
# [7672 rows x 11 columns]

# %%
original_data_grouped = original_data.groupby(by = "Zcruit ID").to_frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-147-b4638ffd927f> in <module>
# ----> 1 original_data_grouped = original_data.groupby(by = "Zcruit ID").to_frame
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_frame'

# %%
original_data_grouped
# Out:
#                                                        Full Name Position  \
# Zcruit ID
# 0000a62d-eb96-4913-8be4-f4b2e168f2f8                   Jd Horton       RB
# 000132c6-192b-410b-bd61-6522eb17a4e0      Aiden GreenAiden Green     CBCB
# 0001b513-8d0f-4687-9357-d40fd1d4700a      Haseem KhanHaseem Khan     LBLB
# 0001c4f3-c4ca-4391-b818-d2db22771bf2        Yusef LeakYusef Leak     WRWR
# 0002dad6-4d51-4674-86c3-3ca21bfe1c04            Kendrick Bradley       RB
# ...                                                          ...      ...
# fffc21a9-aa87-4e06-bc5d-0258e43ad0c1  Landon EaglerLandon Eagler     OLOL
# fffcd947-1cdc-4ff6-b7a7-15c705ecfc17              Jadon\t Haynes       DL
# fffdcf58-94a6-4407-b82f-7c7ef0459499               Taylor Savage       WR
# fffebbbd-88d6-4721-a22a-5c4165a162c3                  Owen Plane       LB
# ffffa89e-ada2-4e9d-9c95-6c81cbfaddad  Ryland ChaneyRyland Chaney     OCOC
#
#                                                          Height Source  \
# Zcruit ID
# 0000a62d-eb96-4913-8be4-f4b2e168f2f8                              ncsa
# 000132c6-192b-410b-bd61-6522eb17a4e0  national_combinenational_combine
# 0001b513-8d0f-4687-9357-d40fd1d4700a      national_prepsnational_preps
# 0001c4f3-c4ca-4391-b818-d2db22771bf2      national_prepsnational_preps
# 0002dad6-4d51-4674-86c3-3ca21bfe1c04                      twoFourSeven
# ...                                                                ...
# fffc21a9-aa87-4e06-bc5d-0258e43ad0c1      national_prepsnational_preps
# fffcd947-1cdc-4ff6-b7a7-15c705ecfc17                    national_preps
# fffdcf58-94a6-4407-b82f-7c7ef0459499                              ncsa
# fffebbbd-88d6-4721-a22a-5c4165a162c3                    national_preps
# ffffa89e-ada2-4e9d-9c95-6c81cbfaddad                          ncsancsa
#
#                                                          Weight Source  \
# Zcruit ID
# 0000a62d-eb96-4913-8be4-f4b2e168f2f8                              ncsa
# 000132c6-192b-410b-bd61-6522eb17a4e0  national_combinenational_combine
# 0001b513-8d0f-4687-9357-d40fd1d4700a      national_prepsnational_preps
# 0001c4f3-c4ca-4391-b818-d2db22771bf2      national_prepsnational_preps
# 0002dad6-4d51-4674-86c3-3ca21bfe1c04                      twoFourSeven
# ...                                                                ...
# fffc21a9-aa87-4e06-bc5d-0258e43ad0c1      national_prepsnational_preps
# fffcd947-1cdc-4ff6-b7a7-15c705ecfc17                    national_preps
# fffdcf58-94a6-4407-b82f-7c7ef0459499                              ncsa
# fffebbbd-88d6-4721-a22a-5c4165a162c3                    national_preps
# ffffa89e-ada2-4e9d-9c95-6c81cbfaddad                          ncsancsa
#
#                                               Committed To
# Zcruit ID
# 0000a62d-eb96-4913-8be4-f4b2e168f2f8                     0
# 000132c6-192b-410b-bd61-6522eb17a4e0                     0
# 0001b513-8d0f-4687-9357-d40fd1d4700a                     0
# 0001c4f3-c4ca-4391-b818-d2db22771bf2  St. ThomasSt. Thomas
# 0002dad6-4d51-4674-86c3-3ca21bfe1c04                     0
# ...                                                    ...
# fffc21a9-aa87-4e06-bc5d-0258e43ad0c1                     0
# fffcd947-1cdc-4ff6-b7a7-15c705ecfc17                     0
# fffdcf58-94a6-4407-b82f-7c7ef0459499                     0
# fffebbbd-88d6-4721-a22a-5c4165a162c3                     0
# ffffa89e-ada2-4e9d-9c95-6c81cbfaddad                     0
#
# [71481 rows x 5 columns]

# %%
data.merge(original_data_grouped, how = "left", on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-8091fc34c77c> in <module>
# ----> 1 data.merge(original_data_grouped, how = "left", on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    8193         from pandas.core.reshape.merge import merge
#    8194
# -> 8195         return merge(
#    8196             self,
#    8197             right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     597     ):
#     598         _left = _validate_operand(left)
# --> 599         _right = _validate_operand(right)
#     600         self.left = self.orig_left = _left
#     601         self.right = self.orig_right = _right
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _validate_operand(obj)
#    2146             return obj.to_frame()
#    2147     else:
# -> 2148         raise TypeError(
#    2149             f"Can only merge Series or DataFrame objects, a {type(obj)} was passed"
#    2150         )
#
# TypeError: Can only merge Series or DataFrame objects, a <class 'pandas.core.groupby.generic.DataFrameGroupBy'> was passed

# %% [markdown]
# #### Merge and Handle Duplicates

# %%
original_data = pd.read_csv("ZCruit_Data.csv", error_bad_lines=False)
good_columns = ["Zcruit ID", "Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"]
original_data = original_data[good_columns]
# Out:
# b'Skipping line 1845: expected 70 fields, saw 72\nSkipping line 3345: expected 70 fields, saw 72\n'
# b'Skipping line 11921: expected 70 fields, saw 72\nSkipping line 12609: expected 70 fields, saw 72\nSkipping line 13420: expected 70 fields, saw 72\nSkipping line 14108: expected 70 fields, saw 72\nSkipping line 14512: expected 70 fields, saw 72\n'
# b'Skipping line 16512: expected 70 fields, saw 72\nSkipping line 21242: expected 70 fields, saw 72\nSkipping line 23743: expected 70 fields, saw 72\n'
# b'Skipping line 58041: expected 70 fields, saw 72\nSkipping line 60541: expected 70 fields, saw 72\n'
# b'Skipping line 70025: expected 70 fields, saw 72\nSkipping line 72525: expected 70 fields, saw 72\n'
# C:\Users\AlvinYu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,8,40,48,57,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data_with_zcruitid = data.merge(original_data, how = "left", on = ["Full Name", "Grad Year", "Position", "Height Source", "Weight Source", "Committed To"])
data_with_zcruitid = data_with_zcruitid.drop_duplicates()

# %%
data_with_zcruitid
# Out:
#                Full Name    Last Name Grad Year Position  Height  \
# 0          Korey Foreman      Foreman      2021       DE    76.0
# 2         J.T. Tuimoloau    Tuimoloau      2021       DE    76.0
# 4              JC Latham       Latham      2021       OT    78.0
# 6           Emeka Egbuka       Egbuka      2021       WR    72.5
# 8          Dallas Turner       Turner      2021       DE    74.5
# ...                  ...          ...       ...      ...     ...
# 105124  Carl Collins III  Collins III      2022       WR    56.0
# 105126  Antrone\t Coston       Coston      2024       WR    61.0
# 105128  Gerald\t Lampkin      Lampkin      2024       WR    59.0
# 105129     Jaeden\t Hamm         Hamm      2024       WR    58.0
# 105130     Eugene Thomas       Thomas      2022       RB    57.0
#
#          Height Source  Weight   Weight Source  Zcruit Rating Committed To  \
# 0         nike_opening   248.0    nike_opening        96.6970          USC
# 2       national_preps   275.0  national_preps        96.6970          NaN
# 4       national_preps   279.0    nike_opening        96.6970      Alabama
# 6         nike_opening   190.0    nike_opening        96.3939   Ohio State
# 8          rivals_camp   223.0     rivals_camp        96.3939      Alabama
# ...                ...     ...             ...            ...          ...
# 105124          rivals    86.0          rivals            NaN          NaN
# 105126          rivals    85.0          rivals            NaN          NaN
# 105128          rivals    84.0          rivals            NaN          NaN
# 105129          rivals    80.0          rivals            NaN          NaN
# 105130          rivals    71.0          rivals            NaN          NaN
#
#         ... Powerball Toss Powerball Toss Source SPARQ Rating  \
# 0       ...           44.5          nike_opening        98.76
# 2       ...            NaN                   NaN          NaN
# 4       ...            NaN                   NaN          NaN
# 6       ...           41.0          nike_opening          NaN
# 8       ...            NaN                   NaN          NaN
# ...     ...            ...                   ...          ...
# 105124  ...            NaN                   NaN          NaN
# 105126  ...            NaN                   NaN          NaN
# 105128  ...            NaN                   NaN          NaN
# 105129  ...            NaN                   NaN          NaN
# 105130  ...            NaN                   NaN          NaN
#
#        SPARQ Rating Source   GPA ACT  SAT Unnamed: 37  Unnamed: 38  \
# 0             nike_opening  3.03 NaN  NaN         NaN          NaN
# 2                      NaN  3.00 NaN  NaN         NaN          NaN
# 4                      NaN  2.35 NaN  NaN         NaN          NaN
# 6                      NaN  4.00 NaN  NaN         NaN          NaN
# 8                      NaN  3.70 NaN  NaN         NaN          NaN
# ...                    ...   ...  ..  ...         ...          ...
# 105124                 NaN   NaN NaN  NaN         NaN          NaN
# 105126                 NaN   NaN NaN  NaN         NaN          NaN
# 105128                 NaN   NaN NaN  NaN         NaN          NaN
# 105129                 NaN   NaN NaN  NaN         NaN          NaN
# 105130                 NaN   NaN NaN  NaN         NaN          NaN
#
#                                    Zcruit ID
# 0       2481c4e2-f105-4e9f-b85d-0925a343910b
# 2       c4fcba47-0337-4047-bc4d-0187da6f698e
# 4       1db04d99-cca6-4bfc-8a5a-3d40ae1795e0
# 6       abda246f-bb45-4b10-baf1-a9e5d508cc84
# 8       7351f453-1854-48ba-aa2c-e6eb9f4b9859
# ...                                      ...
# 105124  1a456275-5dc4-49dd-a0dc-be45d36f0653
# 105126  cb489357-272f-49cd-99a4-903bcbd6ed86
# 105128  f5cbe094-2e5a-42b4-9917-d0a5121a0a33
# 105129  2d1ba563-d8b0-42de-aca2-38702763aa64
# 105130  7d27d80b-1156-45ec-afe0-6f638d45fea6
#
# [71518 rows x 40 columns]

# %%
merge_with_tf = data_with_zcruitid[["Zcruit ID", "Position"]]

# %%
merge_with_tf
# Out:
#                                    Zcruit ID Position
# 0       2481c4e2-f105-4e9f-b85d-0925a343910b       DE
# 2       c4fcba47-0337-4047-bc4d-0187da6f698e       DE
# 4       1db04d99-cca6-4bfc-8a5a-3d40ae1795e0       OT
# 6       abda246f-bb45-4b10-baf1-a9e5d508cc84       WR
# 8       7351f453-1854-48ba-aa2c-e6eb9f4b9859       DE
# ...                                      ...      ...
# 105124  1a456275-5dc4-49dd-a0dc-be45d36f0653       WR
# 105126  cb489357-272f-49cd-99a4-903bcbd6ed86       WR
# 105128  f5cbe094-2e5a-42b4-9917-d0a5121a0a33       WR
# 105129  2d1ba563-d8b0-42de-aca2-38702763aa64       WR
# 105130  7d27d80b-1156-45ec-afe0-6f638d45fea6       RB
#
# [71518 rows x 2 columns]

# %%
tf_data_with_pos = tf_data.merge(merge_with_tf, how = "left", on = "Zcruit ID")

# %%
bryson = tf_data_with_pos.iloc[0]['Zcruit ID']

# %%
original_data[original_data['Zcruit ID'] == bryson]
# Out:
# Empty DataFrame
# Columns: [Zcruit ID, Full Name, Grad Year, Position, Height Source, Weight Source, Committed To]
# Index: []

# %%
tf_data_with_pos['Position'].isna().sum()
# Out:
# 575

# %%
tf_data_with_pos
# Out:
#                                  Zcruit ID         Player Name  100 Meter  \
# 0     7b8c6df6-b548-4ed4-ae9b-4a741d7746c6    Bryson Lightfoot      11.25
# 1     45be7538-29ad-4e4a-9d2e-be05b0d3f595         Jalik Lewis        NaN
# 2     ae1749c5-a0f1-4fbc-852b-1ac51f5b1404        Jaiden Brown        NaN
# 3     eb32fcc6-a8f5-41df-b524-a4fc824a14f3         Mark Phifer      12.51
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737      Gerimiah Brown      11.74
# ...                                    ...                 ...        ...
# 7681  f1873c0b-a931-4604-a33c-4439e32789eb        Jerod Thomas      12.26
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f       Tyler Bradley      11.51
# 7683  6bcf9f7b-4c2d-4db2-a19e-bdea9c358d04  Jesse James Garcia      12.23
# 7684  fb194f5e-bc21-4852-838b-443eebac9aaf     Isaiah Robinson      11.53
# 7685  167feedc-df71-41cd-a151-d34f8b20decf       Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 0           NaN                NaN                NaN        NaN        NaN
# 1         24.95                NaN                NaN       66.0     217.00
# 2         25.90                NaN                NaN        NaN        NaN
# 3         24.94                NaN                NaN        NaN        NaN
# 4         25.77                NaN              47.84        NaN     207.50
# ...         ...                ...                ...        ...        ...
# 7681        NaN                NaN                NaN       64.0        NaN
# 7682      23.05                NaN                NaN        NaN     199.25
# 7683      24.16                NaN                NaN        NaN     176.50
# 7684      24.10                NaN                NaN        NaN     234.00
# 7685      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus Position
# 0             NaN      NaN     NaN      NaN
# 1             NaN      NaN     NaN      NaN
# 2             NaN    490.5     NaN      NaN
# 3             NaN      NaN     NaN       CB
# 4             NaN      NaN     NaN       RB
# ...           ...      ...     ...      ...
# 7681          NaN      NaN     NaN       QB
# 7682        433.5      NaN     NaN       RB
# 7683          NaN      NaN     NaN      NaN
# 7684          NaN      NaN     NaN       WR
# 7685          NaN      NaN     NaN       RB
#
# [7686 rows x 12 columns]

# %%
tf_data_with_pos = tf_data_with_pos.rename(columns = {'Player Name': 'Full Name'})

# %%
tf_data_with_pos
# Out:
#                                  Zcruit ID           Full Name  100 Meter  \
# 0     7b8c6df6-b548-4ed4-ae9b-4a741d7746c6    Bryson Lightfoot      11.25
# 1     45be7538-29ad-4e4a-9d2e-be05b0d3f595         Jalik Lewis        NaN
# 2     ae1749c5-a0f1-4fbc-852b-1ac51f5b1404        Jaiden Brown        NaN
# 3     eb32fcc6-a8f5-41df-b524-a4fc824a14f3         Mark Phifer      12.51
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737      Gerimiah Brown      11.74
# ...                                    ...                 ...        ...
# 7681  f1873c0b-a931-4604-a33c-4439e32789eb        Jerod Thomas      12.26
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f       Tyler Bradley      11.51
# 7683  6bcf9f7b-4c2d-4db2-a19e-bdea9c358d04  Jesse James Garcia      12.23
# 7684  fb194f5e-bc21-4852-838b-443eebac9aaf     Isaiah Robinson      11.53
# 7685  167feedc-df71-41cd-a151-d34f8b20decf       Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 0           NaN                NaN                NaN        NaN        NaN
# 1         24.95                NaN                NaN       66.0     217.00
# 2         25.90                NaN                NaN        NaN        NaN
# 3         24.94                NaN                NaN        NaN        NaN
# 4         25.77                NaN              47.84        NaN     207.50
# ...         ...                ...                ...        ...        ...
# 7681        NaN                NaN                NaN       64.0        NaN
# 7682      23.05                NaN                NaN        NaN     199.25
# 7683      24.16                NaN                NaN        NaN     176.50
# 7684      24.10                NaN                NaN        NaN     234.00
# 7685      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus Position
# 0             NaN      NaN     NaN      NaN
# 1             NaN      NaN     NaN      NaN
# 2             NaN    490.5     NaN      NaN
# 3             NaN      NaN     NaN       CB
# 4             NaN      NaN     NaN       RB
# ...           ...      ...     ...      ...
# 7681          NaN      NaN     NaN       QB
# 7682        433.5      NaN     NaN       RB
# 7683          NaN      NaN     NaN      NaN
# 7684          NaN      NaN     NaN       WR
# 7685          NaN      NaN     NaN       RB
#
# [7686 rows x 12 columns]

# %%
master_fillna(tf_data_with_pos, "RB", ["100 Meter", "110 Meter Hurdles", "Long Jump"])
# Out:
# {'100 Meter': 'There are 245 NaNs out of 1251 players', '110 Meter Hurdles': 'There are 1176 NaNs out of 1251 players', 'Long Jump': 'There are 777 NaNs out of 1251 players'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '100 Meter'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-186-1daeb44dc763> in <module>
# ----> 1 master_fillna(tf_data_with_pos, "RB", ["100 Meter", "110 Meter Hurdles", "Long Jump"])
#
# <ipython-input-5-07c4780c7300> in master_fillna(data, position, metrics)
#      60     metric_dict = {}
#      61     for metric in data_with_metrics.columns:
# ---> 62         metric_dict[metric] = create_percentile(position, metric)
#      63     # We want to fill in the incomplete metrics
#      64     completed_metrics = {}
#
# <ipython-input-5-07c4780c7300> in create_percentile(position, event)
#       3         Reverse for all speed events (lower is better) such as 40, 3 Cone, and Shuttle."""
#       4     sorted_athletes = data[data['Position'] == position]
# ----> 5     event_values = (sorted_athletes[event].astype(float)).dropna()
#       6     percentile = []
#       7     for i in np.arange(0, 1.01, 0.05):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '100 Meter'

# %%
combine_speed_events = ["Forty Yard Dash", "Shuttle", "3 Cone"]
"Shuttle" in combine_speed_events
# Out:
# True

# %%
combine_speed_events = ["Forty Yard Dash", "Shuttle", "3 Cone"]
track_events = ["100 Meter", "200 Meter", "110 Meter Hurdles", "300 Meter Hurdles"]
field_events = ['High Jump', 'Long Jump', 'Triple Jump', 'Shotput', 'Discus']
combine_metrics = ["Height", "Weight", "Forty Yard Dash", "3 Cone", "Shuttle", "Vertical Jump", "Broad Jump"]
zcruit_metrics = ["Wingspan","Arm Length","Hand Size", "Powerball Toss"]

def create_percentile(position, event, data):
    """Take in a position - CB, WR, QB, etc. and an event - Fourty Yard Dash, Weight, 3 Cone and return a list of percentile values of 0, 10th, ... 100th percentile. 
        Reverse for all speed events (lower is better) such as 40, 3 Cone, and Shuttle."""
    sorted_athletes = data[data['Position'] == position]     
    event_values = (sorted_athletes[event].astype(float)).dropna()
    percentile = []
    for i in np.arange(0, 1.01, 0.05):
        percentile.append(event_values.quantile(i))
    if event in combine_speed_events or event in track_events:
        return percentile[::-1]
    return percentile

def value_to_percentile(event, value, metric_dict):
    if event in combine_speed_events or event in track_events:
        return round((100 - scipy.stats.percentileofscore(metric_dict[event], value, kind='rank')), 2)
    else:
        return round((scipy.stats.percentileofscore(metric_dict[event], value, kind='rank')), 2)
    
def percentile_to_value(event, percentile, metric_dict):
    if event in combine_speed_events or event in track_events:
        return scipy.stats.scoreatpercentile(metric_dict[event], 100 - percentile)
    else:
        return scipy.stats.scoreatpercentile(metric_dict[event], percentile)
        
def add_score(metric, data, metric_dict):
    # data = data.dropna()
    data[metric + " " + "Percentile"] = data.apply(lambda x: value_to_percentile(metric, x[metric], metric_dict), axis = 1)
    return data

def nan_counter(data, metrics):
    nan_dict, readable_dict = {}, {}
    for metric in metrics:
        nan_dict[metric] = data[metric].isna().sum() / data.shape[0]
        readable_dict[metric] = "There are {} NaNs out of {} players".format(data[metric].isna().sum(), data.shape[0])
    print(readable_dict)
    return nan_dict

def master_fillna(data, position, metrics):
    # Filtering data    
    print(position)
    data1 = data[data["Position"] == position]
    data_with_metrics = data1[metrics]
    
    # Getting NaN information
    nan_info = nan_counter(data_with_metrics, metrics)
    
    # Classifying metrics into complete, incomplete, and drop
    complete_metric, incomplete_metric, drop_metric = [], [], []
    for metric in nan_info.keys():
        if nan_info[metric] == 0:
            complete_metric.append(metric)
        elif metric in combine_metrics or metric in zcruit_metrics:
            incomplete_metric.append(metric)
        elif nan_info[metric] > 1:
            drop_metric.append(metric)
        else:
            incomplete_metric.append(metric)
    
    data_with_metrics = data_with_metrics.drop(columns = drop_metric)
    
    metric_dict = {}
    for metric in data_with_metrics.columns:
        metric_dict[metric] = create_percentile(position, metric, data)
    # We want to fill in the incomplete metrics
    completed_metrics = {}
    for metric in incomplete_metric:
        correlations = data_with_metrics.corr()[metric]
        correlations = correlations[correlations != 1].sort_values(ascending = False)
        metric_filter = correlations > 0.4 
        best_predictors = metric_filter[metric_filter].index.values

        print(metric, best_predictors)
    
    #IF there are no good predictors for linear regression (ie: no metrics with correlation > 0.4 with incomplete metric),
    #then we use the average approach. 
    
    #For T&F data, percentile method is a little tricky because some players will have NaNs for everything! No ht, wt guarantee like in ZCruit data. 
        if len(best_predictors) == 0:
            #For example, if we are predicting Hand Size with the average approach. We want the percentiles for Height, Weight, and Wingspan
            all_other_metrics = incomplete_metric + complete_metric
            all_other_metrics.remove(metric)
            
            all_other_percentiles = data_with_metrics.copy()
            for percentile_metrics in all_other_metrics:
                all_other_percentiles = add_score(percentile_metrics, all_other_percentiles, metric_dict)
                
            empty_metric = all_other_percentiles[all_other_percentiles[metric].isna()]
            full_metric = all_other_percentiles[all_other_percentiles[metric].notna()]
            
            metric_percentile_names =  [x + " " + "Percentile" for x in all_other_metrics]
            only_percentiles = empty_metric[metric_percentile_names]
            only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)

            only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
            empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
            
            all_metric = empty_metric.append(full_metric).sort_index()
            
            completed_metrics[metric] = all_metric[metric].values
            #print(completed_metrics, len(completed_metrics[metric]), np.count_nonzero(~np.isnan(completed_metrics[metric])))

        else:
            full_metric = data_with_metrics[data_with_metrics[metric].notna()]
            empty_metric = data_with_metrics[data_with_metrics[metric].isna()]
            print("There are {} players with metric and {} NaNs.".format(full_metric.shape[0], empty_metric.shape[0]))
            labels = [best_predictors[0]] + [metric]
            predictor = best_predictors[0]
            print(labels)
            full_metric_with_no_predictor_nulls = full_metric[labels].dropna()
            X = full_metric_with_no_predictor_nulls[[predictor]]
            y = full_metric_with_no_predictor_nulls[metric]
            
            reg = LinearRegression(normalize = True).fit(X,y)
            metric_mean = np.median(y)
            
            empty_metric_with_no_predictor_nulls = empty_metric[[predictor]].dropna()
            if len(empty_metric_with_no_predictor_nulls) == 0:
                empty_metric_with_no_predictor_nulls[metric] = metric_mean
            else: 
                empty_metric_with_no_predictor_nulls[metric] = reg.predict(empty_metric_with_no_predictor_nulls)

            empty_metric_with_predictor_nulls = empty_metric[empty_metric[predictor].isna()]
            empty_metric_with_predictor_nulls[metric] = metric_mean
            
            print("There are {} players with a {} (predictor) value and {} players with NaNs for {}.".format(empty_metric_with_no_predictor_nulls.shape[0], best_predictors[0], empty_metric_with_predictor_nulls.shape[0], best_predictors[0]))
            print(empty_metric_with_no_predictor_nulls.shape[0] +  empty_metric_with_predictor_nulls.shape[0] == empty_metric.shape[0])

            empty_metric = empty_metric_with_no_predictor_nulls.append(empty_metric_with_predictor_nulls).sort_index()
            
            all_metric = empty_metric.append(full_metric).sort_index()
            
            completed_metrics[metric] = all_metric[metric].values
            
            train_y = reg.predict(X)
            train_error = mean_squared_error(y, train_y)
            print(reg.coef_)
            print("The RMSE of the model on the training data is {}. The average {} of the training data is {}. On average, predictions are {} from the actual values in the training data".format(np.sqrt(train_error), metric, np.mean(y), np.sqrt(train_error)/np.mean(y)))
            #print(completed_metrics, len(completed_metrics[metric]), np.count_nonzero(~np.isnan(completed_metrics[metric])))
    
    for metric in incomplete_metric:
        print(metric)
        print("There are {} NaN values for this metric".format(data1[metric].isna().sum()))
        data1[metric] = completed_metrics[metric]
        print("There are {} NaN values for this metric".format(data1[metric].isna().sum()))
    
    if 'Zcruit ID' in tf_data_with_pos.columns:
        all_metrics = ["Zcruit ID", "Full Name", "Position"] + complete_metric + incomplete_metric
        cleaned_dataset = data1[all_metrics]
        return cleaned_dataset
    
    else:
        all_metrics = ["Full Name", "Position"] + complete_metric + incomplete_metric
        cleaned_dataset = data1[all_metrics]
        return cleaned_dataset

# %%
ex_rb = master_fillna(tf_data_with_pos, "RB", ["100 Meter", "200 Meter"])
# Out:
# {'100 Meter': 'There are 230 NaNs out of 1236 players', '200 Meter': 'There are 351 NaNs out of 1236 players'}
# 100 Meter ['200 Meter']
# There are 1006 players with metric and 230 NaNs.
# ['200 Meter', '100 Meter']
# There are 118 players with a 200 Meter (predictor) value and 112 players with NaNs for 200 Meter.
# True
# [0.25227193]
# The RMSE of the model on the training data is 0.6484463647379628. The average 100 Meter of the training data is 12.095449804432844. On average, predictions are 0.05361076894389778 from the actual values in the training data
# 200 Meter ['100 Meter']
# There are 885 players with metric and 351 NaNs.
# ['100 Meter', '200 Meter']
# There are 239 players with a 100 Meter (predictor) value and 112 players with NaNs for 100 Meter.
# True
# [0.95915796]
# The RMSE of the model on the training data is 1.2644005056006562. The average 200 Meter of the training data is 24.94474576271188. On average, predictions are 0.050688049404404766 from the actual values in the training data
# 100 Meter
# There are 230 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 351 NaN values for this metric
# There are 0 NaN values for this metric
# <ipython-input-94-375f417941f6>:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-94-375f417941f6>:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-94-375f417941f6>:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[metric] = completed_metrics[metric]

# %%
ex_rb.tail(15)
# Out:
#                                  Zcruit ID          Full Name Position  \
# 7550  55083d91-ace6-4b6d-9224-63bb9ec745c7    Jaylen Caldwell       RB
# 7559  3670f8c4-c836-4899-a1c8-5c399c1a926c     Brysen Barrios       RB
# 7571  18cd6c7c-5dfc-4a02-94db-0c5dec353100      Logan Parsons       RB
# 7577  d3537297-dfda-45cf-8541-6eaa110e7282        Divon Woods       RB
# 7610  046d5dd9-73c3-4485-9717-620a958f0479      Dylan Lesesne       RB
# 7623  2006b927-4a7d-4937-9466-a0c63d534ecd      Charles Ennis       RB
# 7628  130c872a-fcda-419d-8e86-8528aaf7ba9c    Kenadie Stinson       RB
# 7647  f5c88916-cb42-4667-8b5d-b014d3ebf8b3     Kazarius Adams       RB
# 7650  f80125f5-f899-49d3-9220-8b27ce97a3f0  Scheider\t Joseph       RB
# 7657  f86dfd47-fbe9-4ccf-8c8b-843e1e76c20f    Garrhet Manning       RB
# 7662  cba269e2-1a78-4b76-a3db-512740123e11     Eric Weatherly       RB
# 7675  0e019e7e-8b32-4a87-9bcd-9d3996128e34        Aaron Jones       RB
# 7676  0f2ae21e-54a1-497e-846e-2b1d6f64e234       Zaquan Bryan       RB
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f      Tyler Bradley       RB
# 7685  167feedc-df71-41cd-a151-d34f8b20decf      Jordan Garcia       RB
#
#       100 Meter  200 Meter
# 7550  11.947935  24.360000
# 7559  12.240000  24.480000
# 7571  12.990000  25.910000
# 7577  12.840000  25.658887
# 7610  12.750000  25.572563
# 7623  11.970000  24.740000
# 7628  12.120000  24.968293
# 7647  12.020000  24.640000
# 7650  12.340000  25.360000
# 7657  12.220000  25.950000
# 7662  11.280000  23.830000
# 7675  11.220000  24.105051
# 7676  11.760000  23.210000
# 7682  11.510000  23.050000
# 7685  12.150000  26.050000

# %%
rb =tf_data_with_pos[tf_data_with_pos['Position'] == 'RB']
rb = rb[['Zcruit ID', 'Full Name', 'Position', '100 Meter', '200 Meter']]

# %%
rb.tail(15)
# Out:
#                                  Zcruit ID          Full Name Position  \
# 7550  55083d91-ace6-4b6d-9224-63bb9ec745c7    Jaylen Caldwell       RB
# 7559  3670f8c4-c836-4899-a1c8-5c399c1a926c     Brysen Barrios       RB
# 7571  18cd6c7c-5dfc-4a02-94db-0c5dec353100      Logan Parsons       RB
# 7577  d3537297-dfda-45cf-8541-6eaa110e7282        Divon Woods       RB
# 7610  046d5dd9-73c3-4485-9717-620a958f0479      Dylan Lesesne       RB
# 7623  2006b927-4a7d-4937-9466-a0c63d534ecd      Charles Ennis       RB
# 7628  130c872a-fcda-419d-8e86-8528aaf7ba9c    Kenadie Stinson       RB
# 7647  f5c88916-cb42-4667-8b5d-b014d3ebf8b3     Kazarius Adams       RB
# 7650  f80125f5-f899-49d3-9220-8b27ce97a3f0  Scheider\t Joseph       RB
# 7657  f86dfd47-fbe9-4ccf-8c8b-843e1e76c20f    Garrhet Manning       RB
# 7662  cba269e2-1a78-4b76-a3db-512740123e11     Eric Weatherly       RB
# 7675  0e019e7e-8b32-4a87-9bcd-9d3996128e34        Aaron Jones       RB
# 7676  0f2ae21e-54a1-497e-846e-2b1d6f64e234       Zaquan Bryan       RB
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f      Tyler Bradley       RB
# 7685  167feedc-df71-41cd-a151-d34f8b20decf      Jordan Garcia       RB
#
#       100 Meter  200 Meter
# 7550        NaN      24.36
# 7559      12.24      24.48
# 7571      12.99      25.91
# 7577      12.84        NaN
# 7610      12.75        NaN
# 7623        NaN        NaN
# 7628      12.12        NaN
# 7647      12.02      24.64
# 7650      12.34      25.36
# 7657      12.22      25.95
# 7662      11.28      23.83
# 7675      11.22        NaN
# 7676      11.76      23.21
# 7682      11.51      23.05
# 7685      12.15      26.05

# %% [markdown]
# Can impute NaNs for Zcruit data -> can do percentile method bc have ht/wt for every player or lin reg method if there's a strongly correlated attribute.
#
# Not sure if we can do the same for T&F data. how to do percentile method for RB - 100M, 110M hurdle, LJ. Try to impute for 100M, But player has no 110M hurdle or LJ. Why would a player have no T&F data? It's not that they have no T&F data, they may just not have anything for the 3 metrics we provided.

# %%
rb1 = tf_data_with_pos[tf_data_with_pos['Position'] == 'RB']
rb1
# Out:
#                                  Zcruit ID        Full Name  100 Meter  \
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737   Gerimiah Brown      11.74
# 5     c98e0321-f3a4-4b85-ab2a-bbd16d46ea86      Isaac Jones      11.73
# 8     a6b7e3c4-832d-4f6d-a039-e2af26012e82   Jahbez Hawkins      11.24
# 13    e2936003-f909-4d01-9f48-836d664aaf7a  Alshadee Salaam      11.29
# 14    52031735-d3cc-48cd-ae8f-92c0b4659ba1     Jemel Carter      11.12
# ...                                    ...              ...        ...
# 7662  cba269e2-1a78-4b76-a3db-512740123e11   Eric Weatherly      11.28
# 7675  0e019e7e-8b32-4a87-9bcd-9d3996128e34      Aaron Jones      11.22
# 7676  0f2ae21e-54a1-497e-846e-2b1d6f64e234     Zaquan Bryan      11.76
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f    Tyler Bradley      11.51
# 7685  167feedc-df71-41cd-a151-d34f8b20decf    Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 4         25.77                NaN              47.84        NaN     207.50
# 5         23.28                NaN                NaN        NaN     194.50
# 8         23.86                NaN                NaN       68.0        NaN
# 13        22.26                NaN                NaN        NaN        NaN
# 14        24.14                NaN                NaN        NaN     206.50
# ...         ...                ...                ...        ...        ...
# 7662      23.83                NaN                NaN        NaN        NaN
# 7675        NaN                NaN                NaN        NaN        NaN
# 7676      23.21                NaN                NaN        NaN        NaN
# 7682      23.05                NaN                NaN        NaN     199.25
# 7685      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus Position
# 4             NaN      NaN     NaN       RB
# 5             NaN      NaN     NaN       RB
# 8             NaN      NaN     NaN       RB
# 13            NaN      NaN     NaN       RB
# 14            NaN      NaN     NaN       RB
# ...           ...      ...     ...      ...
# 7662          NaN      NaN     NaN       RB
# 7675          NaN      NaN     NaN       RB
# 7676        469.5      NaN     NaN       RB
# 7682        433.5      NaN     NaN       RB
# 7685          NaN      NaN     NaN       RB
#
# [1251 rows x 12 columns]

# %%
rb1[rb1['100 Meter'].isna() & rb1['200 Meter'].isna()]
# Out:
#                                  Zcruit ID        Full Name  100 Meter  \
# 393   708beb5c-057f-45c6-a85a-0e1fe63931c6  Bryant Callahan        NaN
# 647   8cc096f5-9221-495c-a7d0-8f58e3d35fd4    LeQuint Allen        NaN
# 937   d5ec6b73-96e2-4bfa-a3f6-93f0acab0b05  Lajadan Tolbert        NaN
# 953   f9a1b8c6-2fd1-4743-9135-55e0d7b7f411      Alex Tejada        NaN
# 954   6360a3a6-a30c-4d27-9908-154435f648ae    Carroll Jones        NaN
# ...                                    ...              ...        ...
# 7089  dae59625-8aac-4ef7-ae09-2b66ad1a42ce      Louie Adams        NaN
# 7251  93698517-e487-44c7-aee4-cadb89c6703d  Nehemiah Tarble        NaN
# 7284  2f3399aa-1973-4ce3-924d-ca8085c6f7b4     Elijah Uribe        NaN
# 7455  9d711813-74eb-4f74-b194-0c8196ccdd98  Kenneth Burgess        NaN
# 7623  2006b927-4a7d-4937-9466-a0c63d534ecd    Charles Ennis        NaN
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 393         NaN                NaN                NaN        NaN        NaN
# 647         NaN                NaN                NaN        NaN        NaN
# 937         NaN                NaN                NaN        NaN        NaN
# 953         NaN                NaN                NaN        NaN        NaN
# 954         NaN                NaN                NaN        NaN        NaN
# ...         ...                ...                ...        ...        ...
# 7089        NaN              17.82              45.15        NaN        NaN
# 7251        NaN                NaN              47.74        NaN     196.75
# 7284        NaN                NaN                NaN        NaN        NaN
# 7455        NaN                NaN                NaN        NaN        NaN
# 7623        NaN                NaN                NaN        NaN     206.50
#
#       Triple Jump  Shotput  Discus Position
# 393           NaN      NaN     NaN       RB
# 647           NaN   391.25     NaN       RB
# 937           NaN   530.00  1272.0       RB
# 953           NaN   534.50     NaN       RB
# 954           NaN   427.00   827.0       RB
# ...           ...      ...     ...      ...
# 7089          NaN      NaN     NaN       RB
# 7251          NaN      NaN     NaN       RB
# 7284          NaN      NaN  1539.0       RB
# 7455          NaN   567.50  1538.0       RB
# 7623        442.0      NaN     NaN       RB
#
# [127 rows x 12 columns]

# %%
desired = track_events + field_events

# %%
rb1.dropna(subset = desired)
# Out:
# Empty DataFrame
# Columns: [Zcruit ID, Full Name, 100 Meter, 200 Meter, 110 Meter Hurdles, 300 Meter Hurdles, High Jump, Long Jump, Triple Jump, Shotput, Discus, Position]
# Index: []

# %% [markdown]
# Drop position-filtered athletes with NO track or field metrics. Threshold is 4 because should have 3 vars (ID, Name, Pos) and nothing else if completely NaN.

# %%
no_nan_rb = rb1.dropna(thresh = 4)

# %%
no_nan_rb[no_nan_rb["Zcruit ID"] == 'f9a1b8c6-2fd1-4743-9135-55e0d7b7f411']
# Out:
#                                 Zcruit ID    Full Name  100 Meter  200 Meter  \
# 953  f9a1b8c6-2fd1-4743-9135-55e0d7b7f411  Alex Tejada        NaN        NaN
#
#      110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  Triple Jump  \
# 953                NaN                NaN        NaN        NaN          NaN
#
#      Shotput  Discus Position
# 953    534.5     NaN       RB

# %% [markdown]
# For example, some RBs only throw Shot and Discus! Should we use ANY events to fill in NaNs. Or should we not fill in NaNs and use flexible weights for each position depending on what values a player has.
#
# For example -- if position calls for 100M, 110M Hurdles, and LJ. Should we just use 100% 100M if they only have 100M. What if they have shot and discus but nothing else?

# %%
rb1[rb1['100 Meter'].isna() & rb1['200 Meter'].isna()].head(25)
# Out:
#                                  Zcruit ID          Full Name  100 Meter  \
# 393   708beb5c-057f-45c6-a85a-0e1fe63931c6    Bryant Callahan        NaN
# 647   8cc096f5-9221-495c-a7d0-8f58e3d35fd4      LeQuint Allen        NaN
# 937   d5ec6b73-96e2-4bfa-a3f6-93f0acab0b05    Lajadan Tolbert        NaN
# 953   f9a1b8c6-2fd1-4743-9135-55e0d7b7f411        Alex Tejada        NaN
# 954   6360a3a6-a30c-4d27-9908-154435f648ae      Carroll Jones        NaN
# 965   f2a57823-b2ef-4a2b-ae72-7a78e42ea236        Ty Fuselier        NaN
# 1021  6947283d-4907-4002-ace2-82cd4a0dafbe      Carter Miller        NaN
# 1112  49b6ddc5-7d84-4435-b6d5-acc9ed8f267a   Lewis Richardson        NaN
# 1145  867c4106-129a-49bc-81f5-20a4647ccbd4        Austin Love        NaN
# 1284  36b46004-f31b-4c05-86fc-c552231f09b7   LaVaughn Luellen        NaN
# 1288  bd16bb5c-cf41-4fba-a924-b0db92ff0d05     Kevin Adams Ii        NaN
# 1375  6b072e5b-8bc3-4277-97f6-70bcc9c0cd00   Jean Paul Morale        NaN
# 1425  8e106a04-7f47-40d1-96fd-08b1b7697980       Kaden Krouse        NaN
# 1438  02b6c35a-dceb-4a65-8db9-1d6a48af3dbc          Jose Ruiz        NaN
# 1455  5199d940-52aa-42ad-8566-3c20984704c3      Trevion Sneed        NaN
# 1518  165d20ff-3575-4122-a798-ce56d179e9c3        Kamran Ward        NaN
# 1525  020f845b-10e1-4d41-a76d-f15ce5976e53  Tristian Fletcher        NaN
# 1567  7f81d688-4aae-4757-bd6a-f68374bc7f46        Jason Boyle        NaN
# 1572  3b35893c-a91d-4b4b-b9f6-ad55991a824b      Jalynn Wilson        NaN
# 1579  803df092-56fb-4762-b799-aae0d2e26b87    Russell Frasier        NaN
# 1603  0beb490b-27a4-4b66-b3f6-b9b46edcfb79     Malachi Silmon        NaN
# 1610  e0cc6933-3342-438b-ac83-bd82390af28c        Isaac Bonam        NaN
# 1718  91037b5a-2bb8-4d55-a7bc-d5899dc53714     Coby Cornelius        NaN
# 1727  43c0786e-c7eb-4c6d-a2da-3fdc60fc12cc         Nate Cohen        NaN
# 1780  85f67a48-00c0-4355-93b7-cf7d6dafb055    Anthony Meadows        NaN
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 393         NaN                NaN                NaN        NaN        NaN
# 647         NaN                NaN                NaN        NaN        NaN
# 937         NaN                NaN                NaN        NaN        NaN
# 953         NaN                NaN                NaN        NaN        NaN
# 954         NaN                NaN                NaN        NaN        NaN
# 965         NaN                NaN                NaN        NaN        NaN
# 1021        NaN                NaN                NaN        NaN        NaN
# 1112        NaN                NaN                NaN        NaN        NaN
# 1145        NaN                NaN                NaN        NaN        NaN
# 1284        NaN                NaN                NaN        NaN        NaN
# 1288        NaN                NaN                NaN        NaN        NaN
# 1375        NaN                NaN                NaN        NaN        NaN
# 1425        NaN                NaN              45.97        NaN        NaN
# 1438        NaN                NaN                NaN        NaN        NaN
# 1455        NaN                NaN                NaN        NaN        NaN
# 1518        NaN                NaN                NaN        NaN        NaN
# 1525        NaN                NaN                NaN        NaN        NaN
# 1567        NaN                NaN                NaN        NaN        NaN
# 1572        NaN                NaN                NaN        NaN        NaN
# 1579        NaN                NaN                NaN        NaN        NaN
# 1603        NaN                NaN                NaN        NaN        NaN
# 1610        NaN                NaN                NaN        NaN        NaN
# 1718        NaN                NaN                NaN        NaN        NaN
# 1727        NaN                NaN                NaN        NaN        NaN
# 1780        NaN                NaN                NaN        NaN        NaN
#
#       Triple Jump  Shotput   Discus Position
# 393           NaN      NaN      NaN       RB
# 647           NaN   391.25      NaN       RB
# 937           NaN   530.00  1272.00       RB
# 953           NaN   534.50      NaN       RB
# 954           NaN   427.00   827.00       RB
# 965           NaN   495.00      NaN       RB
# 1021          NaN   510.00  1411.00       RB
# 1112          NaN   479.00      NaN       RB
# 1145          NaN   421.00  1416.00       RB
# 1284          NaN   472.00   830.00       RB
# 1288          NaN   644.50  1822.00       RB
# 1375          NaN   531.00  1430.00       RB
# 1425       406.25   463.00  1327.00       RB
# 1438          NaN   393.50   940.00       RB
# 1455          NaN   496.25      NaN       RB
# 1518          NaN   492.00  1231.00       RB
# 1525          NaN   492.50  1577.00       RB
# 1567          NaN   458.00      NaN       RB
# 1572          NaN   457.00      NaN       RB
# 1579          NaN   457.00   999.00       RB
# 1603          NaN   431.75      NaN       RB
# 1610          NaN   478.75  1195.75       RB
# 1718          NaN   360.00      NaN       RB
# 1727          NaN   448.00  1231.00       RB
# 1780          NaN   447.50  1033.00       RB

# %%
no_nan_rb
# Out:
#                                  Zcruit ID        Full Name  100 Meter  \
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737   Gerimiah Brown      11.74
# 5     c98e0321-f3a4-4b85-ab2a-bbd16d46ea86      Isaac Jones      11.73
# 8     a6b7e3c4-832d-4f6d-a039-e2af26012e82   Jahbez Hawkins      11.24
# 13    e2936003-f909-4d01-9f48-836d664aaf7a  Alshadee Salaam      11.29
# 14    52031735-d3cc-48cd-ae8f-92c0b4659ba1     Jemel Carter      11.12
# ...                                    ...              ...        ...
# 7662  cba269e2-1a78-4b76-a3db-512740123e11   Eric Weatherly      11.28
# 7675  0e019e7e-8b32-4a87-9bcd-9d3996128e34      Aaron Jones      11.22
# 7676  0f2ae21e-54a1-497e-846e-2b1d6f64e234     Zaquan Bryan      11.76
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f    Tyler Bradley      11.51
# 7685  167feedc-df71-41cd-a151-d34f8b20decf    Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 4         25.77                NaN              47.84        NaN     207.50
# 5         23.28                NaN                NaN        NaN     194.50
# 8         23.86                NaN                NaN       68.0        NaN
# 13        22.26                NaN                NaN        NaN        NaN
# 14        24.14                NaN                NaN        NaN     206.50
# ...         ...                ...                ...        ...        ...
# 7662      23.83                NaN                NaN        NaN        NaN
# 7675        NaN                NaN                NaN        NaN        NaN
# 7676      23.21                NaN                NaN        NaN        NaN
# 7682      23.05                NaN                NaN        NaN     199.25
# 7685      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus Position
# 4             NaN      NaN     NaN       RB
# 5             NaN      NaN     NaN       RB
# 8             NaN      NaN     NaN       RB
# 13            NaN      NaN     NaN       RB
# 14            NaN      NaN     NaN       RB
# ...           ...      ...     ...      ...
# 7662          NaN      NaN     NaN       RB
# 7675          NaN      NaN     NaN       RB
# 7676        469.5      NaN     NaN       RB
# 7682        433.5      NaN     NaN       RB
# 7685          NaN      NaN     NaN       RB
#
# [1236 rows x 12 columns]

# %% [markdown]
# Metrics argument is kinda not needed for master fillna function. We will use ALL T&F metrics to fill because that guarantees our methods will work (percentile or lin reg). This will be the same for all positions. Filtering for chosen metrics will be done AFTER filling not DURING filling for the sake of data imputing. This is also a source for improvement -> can handle different cases with more nuance (only throws RB, dash RBs, jumps RBs, etc.)

# %%
ex_rb_FILLED = master_fillna(no_nan_rb, "RB", track_events + field_events)
# Out:
# {'100 Meter': 'There are 230 NaNs out of 1236 players', '200 Meter': 'There are 351 NaNs out of 1236 players', '110 Meter Hurdles': 'There are 1161 NaNs out of 1236 players', '300 Meter Hurdles': 'There are 1165 NaNs out of 1236 players', 'High Jump': 'There are 1119 NaNs out of 1236 players', 'Long Jump': 'There are 762 NaNs out of 1236 players', 'Triple Jump': 'There are 1090 NaNs out of 1236 players', 'Shotput': 'There are 1079 NaNs out of 1236 players', 'Discus': 'There are 1130 NaNs out of 1236 players'}
# 100 Meter ['200 Meter']
# There are 1006 players with metric and 230 NaNs.
# ['200 Meter', '100 Meter']
# There are 118 players with a 200 Meter (predictor) value and 112 players with NaNs for 200 Meter.
# True
# [0.25227193]
# The RMSE of the model on the training data is 0.6484463647379628. The average 100 Meter of the training data is 12.095449804432844. On average, predictions are 0.05361076894389778 from the actual values in the training data
# 200 Meter ['300 Meter Hurdles' '100 Meter']
# There are 885 players with metric and 351 NaNs.
# ['300 Meter Hurdles', '200 Meter']
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# There are 32 players with a 300 Meter Hurdles (predictor) value and 319 players with NaNs for 300 Meter Hurdles.
# True
# [0.28429891]
# The RMSE of the model on the training data is 1.6264207462721445. The average 200 Meter of the training data is 25.518205128205125. On average, predictions are 0.06373570312257076 from the actual values in the training data
# 110 Meter Hurdles ['Discus' '300 Meter Hurdles']
# There are 75 players with metric and 1161 NaNs.
# ['Discus', '110 Meter Hurdles']
# There are 103 players with a Discus (predictor) value and 1058 players with NaNs for Discus.
# True
# [0.00391856]
# The RMSE of the model on the training data is 0.01585359919964183. The average 110 Meter Hurdles of the training data is 17.61. On average, predictions are 0.0009002611697695531 from the actual values in the training data
# 300 Meter Hurdles ['110 Meter Hurdles' 'Discus' '200 Meter']
# There are 71 players with metric and 1165 NaNs.
# ['110 Meter Hurdles', '300 Meter Hurdles']
# There are 31 players with a 110 Meter Hurdles (predictor) value and 1134 players with NaNs for 110 Meter Hurdles.
# True
# [1.40579733]
# The RMSE of the model on the training data is 2.5453924447680345. The average 300 Meter Hurdles of the training data is 45.7565909090909. On average, predictions are 0.0556289792179932 from the actual values in the training data
# High Jump ['Shotput' 'Long Jump']
# There are 117 players with metric and 1119 NaNs.
# ['Shotput', 'High Jump']
# There are 147 players with a Shotput (predictor) value and 972 players with NaNs for Shotput.
# True
# [0.04761492]
# The RMSE of the model on the training data is 4.184827739251241. The average High Jump of the training data is 61.8716572. On average, predictions are 0.06763723372923072 from the actual values in the training data
# Long Jump ['Triple Jump' 'High Jump']
# There are 474 players with metric and 762 NaNs.
# ['Triple Jump', 'Long Jump']
# There are 33 players with a Triple Jump (predictor) value and 729 players with NaNs for Triple Jump.
# True
# [0.37025793]
# The RMSE of the model on the training data is 17.88873358609338. The average Long Jump of the training data is 216.0287610619469. On average, predictions are 0.08280718501627536 from the actual values in the training data
# Triple Jump ['Long Jump' 'Shotput']
# There are 146 players with metric and 1090 NaNs.
# ['Long Jump', 'Triple Jump']
# There are 361 players with a Long Jump (predictor) value and 729 players with NaNs for Long Jump.
# True
# [1.14318716]
# The RMSE of the model on the training data is 31.433017847325424. The average Triple Jump of the training data is 447.76769911504425. On average, predictions are 0.07019938666734732 from the actual values in the training data
# Shotput ['Discus' 'Triple Jump' 'High Jump']
# There are 157 players with metric and 1079 NaNs.
# ['Discus', 'Shotput']
# There are 26 players with a Discus (predictor) value and 1053 players with NaNs for Discus.
# True
# [0.1876316]
# The RMSE of the model on the training data is 50.31507209298223. The average Shotput of the training data is 433.765625. On average, predictions are 0.11599598767878903 from the actual values in the training data
# Discus ['110 Meter Hurdles' 'Shotput' '300 Meter Hurdles']
# There are 106 players with metric and 1130 NaNs.
# ['110 Meter Hurdles', 'Discus']
# There are 72 players with a 110 Meter Hurdles (predictor) value and 1058 players with NaNs for 110 Meter Hurdles.
# True
# [255.11575803]
# The RMSE of the model on the training data is 4.045135769322116. The average Discus of the training data is 859.6666666666666. On average, predictions are 0.004705470069005952 from the actual values in the training data
# 100 Meter
# There are 230 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 351 NaN values for this metric
# There are 0 NaN values for this metric
# 110 Meter Hurdles
# There are 1161 NaN values for this metric
# There are 0 NaN values for this metric
# 300 Meter Hurdles
# There are 1165 NaN values for this metric
# There are 0 NaN values for this metric
# High Jump
# There are 1119 NaN values for this metric
# There are 0 NaN values for this metric
# Long Jump
# There are 762 NaN values for this metric
# There are 0 NaN values for this metric
# Triple Jump
# There are 1090 NaN values for this metric
# There are 0 NaN values for this metric
# Shotput
# There are 1079 NaN values for this metric
# There are 0 NaN values for this metric
# Discus
# There are 1130 NaN values for this metric
# There are 0 NaN values for this metric
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-51-7ca4acb44cae>:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean

# %%
ex_rb_FILLED[["100 Meter", "110 Meter Hurdles", "Long Jump"]]
# Out:
#       100 Meter  110 Meter Hurdles   Long Jump
# 4         11.74              17.52  207.500000
# 5         11.73              17.52  194.500000
# 8         11.24              17.52  219.250000
# 13        11.29              17.52  219.250000
# 14        11.12              17.52  206.500000
# ...         ...                ...         ...
# 7662      11.28              17.52  219.250000
# 7675      11.22              17.52  219.250000
# 7676      11.76              17.52  224.075318
# 7682      11.51              17.52  199.250000
# 7685      12.15              17.52  201.000000
#
# [1236 rows x 3 columns]

# %%
tf_data_with_pos.dropna(thresh = 4)
# Out:
#                                  Zcruit ID           Full Name  100 Meter  \
# 1     45be7538-29ad-4e4a-9d2e-be05b0d3f595         Jalik Lewis        NaN
# 2     ae1749c5-a0f1-4fbc-852b-1ac51f5b1404        Jaiden Brown        NaN
# 3     eb32fcc6-a8f5-41df-b524-a4fc824a14f3         Mark Phifer      12.51
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737      Gerimiah Brown      11.74
# 5     c98e0321-f3a4-4b85-ab2a-bbd16d46ea86         Isaac Jones      11.73
# ...                                    ...                 ...        ...
# 7681  f1873c0b-a931-4604-a33c-4439e32789eb        Jerod Thomas      12.26
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f       Tyler Bradley      11.51
# 7683  6bcf9f7b-4c2d-4db2-a19e-bdea9c358d04  Jesse James Garcia      12.23
# 7684  fb194f5e-bc21-4852-838b-443eebac9aaf     Isaiah Robinson      11.53
# 7685  167feedc-df71-41cd-a151-d34f8b20decf       Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 1         24.95                NaN                NaN       66.0     217.00
# 2         25.90                NaN                NaN        NaN        NaN
# 3         24.94                NaN                NaN        NaN        NaN
# 4         25.77                NaN              47.84        NaN     207.50
# 5         23.28                NaN                NaN        NaN     194.50
# ...         ...                ...                ...        ...        ...
# 7681        NaN                NaN                NaN       64.0        NaN
# 7682      23.05                NaN                NaN        NaN     199.25
# 7683      24.16                NaN                NaN        NaN     176.50
# 7684      24.10                NaN                NaN        NaN     234.00
# 7685      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus Position
# 1             NaN      NaN     NaN      NaN
# 2             NaN    490.5     NaN      NaN
# 3             NaN      NaN     NaN       CB
# 4             NaN      NaN     NaN       RB
# 5             NaN      NaN     NaN       RB
# ...           ...      ...     ...      ...
# 7681          NaN      NaN     NaN       QB
# 7682        433.5      NaN     NaN       RB
# 7683          NaN      NaN     NaN      NaN
# 7684          NaN      NaN     NaN       WR
# 7685          NaN      NaN     NaN       RB
#
# [7396 rows x 12 columns]

# %%
tf_data_with_pos
# Out:
#                                  Zcruit ID           Full Name  100 Meter  \
# 0     7b8c6df6-b548-4ed4-ae9b-4a741d7746c6    Bryson Lightfoot      11.25
# 1     45be7538-29ad-4e4a-9d2e-be05b0d3f595         Jalik Lewis        NaN
# 2     ae1749c5-a0f1-4fbc-852b-1ac51f5b1404        Jaiden Brown        NaN
# 3     eb32fcc6-a8f5-41df-b524-a4fc824a14f3         Mark Phifer      12.51
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737      Gerimiah Brown      11.74
# ...                                    ...                 ...        ...
# 7681  f1873c0b-a931-4604-a33c-4439e32789eb        Jerod Thomas      12.26
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f       Tyler Bradley      11.51
# 7683  6bcf9f7b-4c2d-4db2-a19e-bdea9c358d04  Jesse James Garcia      12.23
# 7684  fb194f5e-bc21-4852-838b-443eebac9aaf     Isaiah Robinson      11.53
# 7685  167feedc-df71-41cd-a151-d34f8b20decf       Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 0           NaN                NaN                NaN        NaN        NaN
# 1         24.95                NaN                NaN       66.0     217.00
# 2         25.90                NaN                NaN        NaN        NaN
# 3         24.94                NaN                NaN        NaN        NaN
# 4         25.77                NaN              47.84        NaN     207.50
# ...         ...                ...                ...        ...        ...
# 7681        NaN                NaN                NaN       64.0        NaN
# 7682      23.05                NaN                NaN        NaN     199.25
# 7683      24.16                NaN                NaN        NaN     176.50
# 7684      24.10                NaN                NaN        NaN     234.00
# 7685      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus Position
# 0             NaN      NaN     NaN      NaN
# 1             NaN      NaN     NaN      NaN
# 2             NaN    490.5     NaN      NaN
# 3             NaN      NaN     NaN       CB
# 4             NaN      NaN     NaN       RB
# ...           ...      ...     ...      ...
# 7681          NaN      NaN     NaN       QB
# 7682        433.5      NaN     NaN       RB
# 7683          NaN      NaN     NaN      NaN
# 7684          NaN      NaN     NaN       WR
# 7685          NaN      NaN     NaN       RB
#
# [7686 rows x 12 columns]

# %%
tf_data
# Out:
#                                  Zcruit ID         Player Name  100 Meter  \
# 0     7b8c6df6-b548-4ed4-ae9b-4a741d7746c6    Bryson Lightfoot      11.25
# 1     45be7538-29ad-4e4a-9d2e-be05b0d3f595         Jalik Lewis        NaN
# 2     ae1749c5-a0f1-4fbc-852b-1ac51f5b1404        Jaiden Brown        NaN
# 3     eb32fcc6-a8f5-41df-b524-a4fc824a14f3         Mark Phifer      12.51
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737      Gerimiah Brown      11.74
# ...                                    ...                 ...        ...
# 7667  f1873c0b-a931-4604-a33c-4439e32789eb        Jerod Thomas      12.26
# 7668  1f7b327a-510e-4070-a3cd-bc0d2433010f       Tyler Bradley      11.51
# 7669  6bcf9f7b-4c2d-4db2-a19e-bdea9c358d04  Jesse James Garcia      12.23
# 7670  fb194f5e-bc21-4852-838b-443eebac9aaf     Isaiah Robinson      11.53
# 7671  167feedc-df71-41cd-a151-d34f8b20decf       Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 0           NaN                NaN                NaN        NaN        NaN
# 1         24.95                NaN                NaN       66.0     217.00
# 2         25.90                NaN                NaN        NaN        NaN
# 3         24.94                NaN                NaN        NaN        NaN
# 4         25.77                NaN              47.84        NaN     207.50
# ...         ...                ...                ...        ...        ...
# 7667        NaN                NaN                NaN       64.0        NaN
# 7668      23.05                NaN                NaN        NaN     199.25
# 7669      24.16                NaN                NaN        NaN     176.50
# 7670      24.10                NaN                NaN        NaN     234.00
# 7671      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus
# 0             NaN      NaN     NaN
# 1             NaN      NaN     NaN
# 2             NaN    490.5     NaN
# 3             NaN      NaN     NaN
# 4             NaN      NaN     NaN
# ...           ...      ...     ...
# 7667          NaN      NaN     NaN
# 7668        433.5      NaN     NaN
# 7669          NaN      NaN     NaN
# 7670          NaN      NaN     NaN
# 7671          NaN      NaN     NaN
#
# [7672 rows x 11 columns]

# %%
tf_data_with_pos = tf_data_with_pos.dropna(thresh = 4)

# %%
tf_data_with_pos
# Out:
#                                  Zcruit ID           Full Name  100 Meter  \
# 1     45be7538-29ad-4e4a-9d2e-be05b0d3f595         Jalik Lewis        NaN
# 2     ae1749c5-a0f1-4fbc-852b-1ac51f5b1404        Jaiden Brown        NaN
# 3     eb32fcc6-a8f5-41df-b524-a4fc824a14f3         Mark Phifer      12.51
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737      Gerimiah Brown      11.74
# 5     c98e0321-f3a4-4b85-ab2a-bbd16d46ea86         Isaac Jones      11.73
# ...                                    ...                 ...        ...
# 7681  f1873c0b-a931-4604-a33c-4439e32789eb        Jerod Thomas      12.26
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f       Tyler Bradley      11.51
# 7683  6bcf9f7b-4c2d-4db2-a19e-bdea9c358d04  Jesse James Garcia      12.23
# 7684  fb194f5e-bc21-4852-838b-443eebac9aaf     Isaiah Robinson      11.53
# 7685  167feedc-df71-41cd-a151-d34f8b20decf       Jordan Garcia      12.15
#
#       200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  Long Jump  \
# 1         24.95                NaN                NaN       66.0     217.00
# 2         25.90                NaN                NaN        NaN        NaN
# 3         24.94                NaN                NaN        NaN        NaN
# 4         25.77                NaN              47.84        NaN     207.50
# 5         23.28                NaN                NaN        NaN     194.50
# ...         ...                ...                ...        ...        ...
# 7681        NaN                NaN                NaN       64.0        NaN
# 7682      23.05                NaN                NaN        NaN     199.25
# 7683      24.16                NaN                NaN        NaN     176.50
# 7684      24.10                NaN                NaN        NaN     234.00
# 7685      26.05                NaN                NaN       64.0     201.00
#
#       Triple Jump  Shotput  Discus Position
# 1             NaN      NaN     NaN      NaN
# 2             NaN    490.5     NaN      NaN
# 3             NaN      NaN     NaN       CB
# 4             NaN      NaN     NaN       RB
# 5             NaN      NaN     NaN       RB
# ...           ...      ...     ...      ...
# 7681          NaN      NaN     NaN       QB
# 7682        433.5      NaN     NaN       RB
# 7683          NaN      NaN     NaN      NaN
# 7684          NaN      NaN     NaN       WR
# 7685          NaN      NaN     NaN       RB
#
# [7396 rows x 12 columns]

# %%
# %%time
cleaned_tf_metrics_position_dataframes = {}
for position in positions:
    cleaned_tf_metrics_position_dataframes[position] = master_fillna(tf_data_with_pos, position, track_events + field_events)
# Out:
# WR
# {'100 Meter': 'There are 470 NaNs out of 1474 players', '200 Meter': 'There are 403 NaNs out of 1474 players', '110 Meter Hurdles': 'There are 1312 NaNs out of 1474 players', '300 Meter Hurdles': 'There are 1311 NaNs out of 1474 players', 'High Jump': 'There are 1167 NaNs out of 1474 players', 'Long Jump': 'There are 768 NaNs out of 1474 players', 'Triple Jump': 'There are 1177 NaNs out of 1474 players', 'Shotput': 'There are 1427 NaNs out of 1474 players', 'Discus': 'There are 1444 NaNs out of 1474 players'}
# 100 Meter ['200 Meter' '300 Meter Hurdles']
# There are 1004 players with metric and 470 NaNs.
# ['200 Meter', '100 Meter']
# There are 273 players with a 200 Meter (predictor) value and 197 players with NaNs for 200 Meter.
# True
# [0.31758863]
# The RMSE of the model on the training data is 0.5621377260998385. The average 100 Meter of the training data is 12.094736842105252. On average, predictions are 0.04647787987770644 from the actual values in the training data
# 200 Meter ['100 Meter' '110 Meter Hurdles']
# There are 1071 players with metric and 403 NaNs.
# ['100 Meter', '200 Meter']
# There are 206 players with a 100 Meter (predictor) value and 197 players with NaNs for 100 Meter.
# True
# [1.5397188]
# The RMSE of the model on the training data is 1.2377443899706517. The average 200 Meter of the training data is 24.79677944862156. On average, predictions are 0.04991553006047555 from the actual values in the training data
# 110 Meter Hurdles ['300 Meter Hurdles' 'Discus' '200 Meter']
# There are 162 players with metric and 1312 NaNs.
# ['300 Meter Hurdles', '110 Meter Hurdles']
# There are 52 players with a 300 Meter Hurdles (predictor) value and 1260 players with NaNs for 300 Meter Hurdles.
# True
# [0.31671364]
# The RMSE of the model on the training data is 1.4796834930099672. The average 110 Meter Hurdles of the training data is 18.078558558558555. On average, predictions are 0.08184742650898301 from the actual values in the training data
# 300 Meter Hurdles ['Discus' '110 Meter Hurdles' '100 Meter']
# There are 163 players with metric and 1311 NaNs.
# ['Discus', '300 Meter Hurdles']
# There are 27 players with a Discus (predictor) value and 1284 players with NaNs for Discus.
# True
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# [0.0299289]
# The RMSE of the model on the training data is 1.551026895201722. The average 300 Meter Hurdles of the training data is 44.14666666666667. On average, predictions are 0.03513349958928697 from the actual values in the training data
# High Jump ['Triple Jump' 'Long Jump']
# There are 307 players with metric and 1167 NaNs.
# ['Triple Jump', 'High Jump']
# There are 196 players with a Triple Jump (predictor) value and 971 players with NaNs for Triple Jump.
# True
# [0.06761343]
# The RMSE of the model on the training data is 4.676301701219336. The average High Jump of the training data is 64.29455445544555. On average, predictions are 0.0727324691931708 from the actual values in the training data
# Long Jump ['Triple Jump' 'High Jump']
# There are 706 players with metric and 768 NaNs.
# ['Triple Jump', 'Long Jump']
# There are 51 players with a Triple Jump (predictor) value and 717 players with NaNs for Triple Jump.
# True
# [0.37867905]
# The RMSE of the model on the training data is 18.3803524455509. The average Long Jump of the training data is 222.21341463414635. On average, predictions are 0.08271486433801684 from the actual values in the training data
# Triple Jump ['Long Jump' 'High Jump']
# There are 297 players with metric and 1177 NaNs.
# ['Long Jump', 'Triple Jump']
# There are 460 players with a Long Jump (predictor) value and 717 players with NaNs for Long Jump.
# True
# [1.08381551]
# The RMSE of the model on the training data is 31.095380669733007. The average Triple Jump of the training data is 458.3689024390244. On average, predictions are 0.06783920223268101 from the actual values in the training data
# Shotput []
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# Discus ['300 Meter Hurdles' '110 Meter Hurdles']
# There are 30 players with metric and 1444 NaNs.
# ['300 Meter Hurdles', 'Discus']
# There are 160 players with a 300 Meter Hurdles (predictor) value and 1284 players with NaNs for 300 Meter Hurdles.
# True
# [23.80155095]
# The RMSE of the model on the training data is 43.73978091057082. The average Discus of the training data is 1027.25. On average, predictions are 0.042579489813162154 from the actual values in the training data
# 100 Meter
# There are 470 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 403 NaN values for this metric
# There are 0 NaN values for this metric
# 110 Meter Hurdles
# There are 1312 NaN values for this metric
# There are 0 NaN values for this metric
# 300 Meter Hurdles
# There are 1311 NaN values for this metric
# There are 0 NaN values for this metric
# High Jump
# There are 1167 NaN values for this metric
# There are 0 NaN values for this metric
# Long Jump
# There are 768 NaN values for this metric
# There are 0 NaN values for this metric
# Triple Jump
# There are 1177 NaN values for this metric
# There are 0 NaN values for this metric
# Shotput
# There are 1427 NaN values for this metric
# There are 0 NaN values for this metric
# Discus
# There are 1444 NaN values for this metric
# There are 0 NaN values for this metric
# RB
# {'100 Meter': 'There are 230 NaNs out of 1236 players', '200 Meter': 'There are 351 NaNs out of 1236 players', '110 Meter Hurdles': 'There are 1161 NaNs out of 1236 players', '300 Meter Hurdles': 'There are 1165 NaNs out of 1236 players', 'High Jump': 'There are 1119 NaNs out of 1236 players', 'Long Jump': 'There are 762 NaNs out of 1236 players', 'Triple Jump': 'There are 1090 NaNs out of 1236 players', 'Shotput': 'There are 1079 NaNs out of 1236 players', 'Discus': 'There are 1130 NaNs out of 1236 players'}
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[metric] = completed_metrics[metric]
# 100 Meter ['200 Meter']
# There are 1006 players with metric and 230 NaNs.
# ['200 Meter', '100 Meter']
# There are 118 players with a 200 Meter (predictor) value and 112 players with NaNs for 200 Meter.
# True
# [0.25227193]
# The RMSE of the model on the training data is 0.6484463647379628. The average 100 Meter of the training data is 12.095449804432844. On average, predictions are 0.05361076894389778 from the actual values in the training data
# 200 Meter ['300 Meter Hurdles' '100 Meter']
# There are 885 players with metric and 351 NaNs.
# ['300 Meter Hurdles', '200 Meter']
# There are 32 players with a 300 Meter Hurdles (predictor) value and 319 players with NaNs for 300 Meter Hurdles.
# True
# [0.28429891]
# The RMSE of the model on the training data is 1.6264207462721445. The average 200 Meter of the training data is 25.518205128205125. On average, predictions are 0.06373570312257076 from the actual values in the training data
# 110 Meter Hurdles ['Discus' '300 Meter Hurdles']
# There are 75 players with metric and 1161 NaNs.
# ['Discus', '110 Meter Hurdles']
# There are 103 players with a Discus (predictor) value and 1058 players with NaNs for Discus.
# True
# [0.00391856]
# The RMSE of the model on the training data is 0.01585359919964183. The average 110 Meter Hurdles of the training data is 17.61. On average, predictions are 0.0009002611697695531 from the actual values in the training data
# 300 Meter Hurdles ['110 Meter Hurdles' 'Discus' '200 Meter']
# There are 71 players with metric and 1165 NaNs.
# ['110 Meter Hurdles', '300 Meter Hurdles']
# There are 31 players with a 110 Meter Hurdles (predictor) value and 1134 players with NaNs for 110 Meter Hurdles.
# True
# [1.40579733]
# The RMSE of the model on the training data is 2.5453924447680345. The average 300 Meter Hurdles of the training data is 45.7565909090909. On average, predictions are 0.0556289792179932 from the actual values in the training data
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# High Jump ['Shotput' 'Long Jump']
# There are 117 players with metric and 1119 NaNs.
# ['Shotput', 'High Jump']
# There are 147 players with a Shotput (predictor) value and 972 players with NaNs for Shotput.
# True
# [0.04761492]
# The RMSE of the model on the training data is 4.184827739251241. The average High Jump of the training data is 61.8716572. On average, predictions are 0.06763723372923072 from the actual values in the training data
# Long Jump ['Triple Jump' 'High Jump']
# There are 474 players with metric and 762 NaNs.
# ['Triple Jump', 'Long Jump']
# There are 33 players with a Triple Jump (predictor) value and 729 players with NaNs for Triple Jump.
# True
# [0.37025793]
# The RMSE of the model on the training data is 17.88873358609338. The average Long Jump of the training data is 216.0287610619469. On average, predictions are 0.08280718501627536 from the actual values in the training data
# Triple Jump ['Long Jump' 'Shotput']
# There are 146 players with metric and 1090 NaNs.
# ['Long Jump', 'Triple Jump']
# There are 361 players with a Long Jump (predictor) value and 729 players with NaNs for Long Jump.
# True
# [1.14318716]
# The RMSE of the model on the training data is 31.433017847325424. The average Triple Jump of the training data is 447.76769911504425. On average, predictions are 0.07019938666734732 from the actual values in the training data
# Shotput ['Discus' 'Triple Jump' 'High Jump']
# There are 157 players with metric and 1079 NaNs.
# ['Discus', 'Shotput']
# There are 26 players with a Discus (predictor) value and 1053 players with NaNs for Discus.
# True
# [0.1876316]
# The RMSE of the model on the training data is 50.31507209298223. The average Shotput of the training data is 433.765625. On average, predictions are 0.11599598767878903 from the actual values in the training data
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[metric] = completed_metrics[metric]
# Discus ['110 Meter Hurdles' 'Shotput' '300 Meter Hurdles']
# There are 106 players with metric and 1130 NaNs.
# ['110 Meter Hurdles', 'Discus']
# There are 72 players with a 110 Meter Hurdles (predictor) value and 1058 players with NaNs for 110 Meter Hurdles.
# True
# [255.11575803]
# The RMSE of the model on the training data is 4.045135769322116. The average Discus of the training data is 859.6666666666666. On average, predictions are 0.004705470069005952 from the actual values in the training data
# 100 Meter
# There are 230 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 351 NaN values for this metric
# There are 0 NaN values for this metric
# 110 Meter Hurdles
# There are 1161 NaN values for this metric
# There are 0 NaN values for this metric
# 300 Meter Hurdles
# There are 1165 NaN values for this metric
# There are 0 NaN values for this metric
# High Jump
# There are 1119 NaN values for this metric
# There are 0 NaN values for this metric
# Long Jump
# There are 762 NaN values for this metric
# There are 0 NaN values for this metric
# Triple Jump
# There are 1090 NaN values for this metric
# There are 0 NaN values for this metric
# Shotput
# There are 1079 NaN values for this metric
# There are 0 NaN values for this metric
# Discus
# There are 1130 NaN values for this metric
# There are 0 NaN values for this metric
# LB
# {'100 Meter': 'There are 298 NaNs out of 605 players', '200 Meter': 'There are 317 NaNs out of 605 players', '110 Meter Hurdles': 'There are 556 NaNs out of 605 players', '300 Meter Hurdles': 'There are 562 NaNs out of 605 players', 'High Jump': 'There are 532 NaNs out of 605 players', 'Long Jump': 'There are 459 NaNs out of 605 players', 'Triple Jump': 'There are 537 NaNs out of 605 players', 'Shotput': 'There are 315 NaNs out of 605 players', 'Discus': 'There are 392 NaNs out of 605 players'}
# 100 Meter ['200 Meter']
# There are 307 players with metric and 298 NaNs.
# ['200 Meter', '100 Meter']
# There are 77 players with a 200 Meter (predictor) value and 221 players with NaNs for 200 Meter.
# True
# [0.31874038]
# The RMSE of the model on the training data is 0.46982081570666695. The average 100 Meter of the training data is 12.472132701421803. On average, predictions are 0.03766964535689298 from the actual values in the training data
# 200 Meter ['100 Meter']
# There are 288 players with metric and 317 NaNs.
# ['100 Meter', '200 Meter']
# There are 96 players with a 100 Meter (predictor) value and 221 players with NaNs for 100 Meter.
# True
# [1.94930949]
# The RMSE of the model on the training data is 1.161860835607284. The average 200 Meter of the training data is 25.865497630331745. On average, predictions are 0.04491933046147167 from the actual values in the training data
# 110 Meter Hurdles ['300 Meter Hurdles']
# There are 49 players with metric and 556 NaNs.
# ['300 Meter Hurdles', '110 Meter Hurdles']
# There are 13 players with a 300 Meter Hurdles (predictor) value and 543 players with NaNs for 300 Meter Hurdles.
# True
# [0.40329836]
# The RMSE of the model on the training data is 1.7804976622346471. The average 110 Meter Hurdles of the training data is 18.668. On average, predictions are 0.09537699069180669 from the actual values in the training data
# 300 Meter Hurdles ['110 Meter Hurdles']
# There are 43 players with metric and 562 NaNs.
# ['110 Meter Hurdles', '300 Meter Hurdles']
# There are 19 players with a 110 Meter Hurdles (predictor) value and 543 players with NaNs for 110 Meter Hurdles.
# True
# [0.9149694]
# The RMSE of the model on the training data is 2.681831346229231. The average 300 Meter Hurdles of the training data is 46.852333333333334. On average, predictions are 0.05724008081196733 from the actual values in the training data
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# High Jump ['Triple Jump' 'Long Jump']
# There are 73 players with metric and 532 NaNs.
# ['Triple Jump', 'High Jump']
# There are 52 players with a Triple Jump (predictor) value and 480 players with NaNs for Triple Jump.
# True
# [0.07792292]
# The RMSE of the model on the training data is 3.3450940238049514. The average High Jump of the training data is 62.890625. On average, predictions are 0.053189072676650156 from the actual values in the training data
# Long Jump ['Triple Jump' 'High Jump']
# There are 146 players with metric and 459 NaNs.
# ['Triple Jump', 'Long Jump']
# There are 20 players with a Triple Jump (predictor) value and 439 players with NaNs for Triple Jump.
# True
# [0.33660167]
# The RMSE of the model on the training data is 18.910794685996315. The average Long Jump of the training data is 207.25520833333334. On average, predictions are 0.09124400220418899 from the actual values in the training data
# Triple Jump ['High Jump' 'Long Jump']
# There are 68 players with metric and 537 NaNs.
# ['High Jump', 'Triple Jump']
# There are 57 players with a High Jump (predictor) value and 480 players with NaNs for High Jump.
# True
# [6.37015834]
# The RMSE of the model on the training data is 30.24480793840551. The average Triple Jump of the training data is 442.359375. On average, predictions are 0.06837157670368241 from the actual values in the training data
# Shotput ['Discus']
# There are 290 players with metric and 315 NaNs.
# ['Discus', 'Shotput']
# There are 24 players with a Discus (predictor) value and 291 players with NaNs for Discus.
# True
# [0.16414496]
# The RMSE of the model on the training data is 61.08462904271711. The average Shotput of the training data is 436.0279248201058. On average, predictions are 0.1400933875231021 from the actual values in the training data
# Discus ['Shotput']
# There are 213 players with metric and 392 NaNs.
# ['Shotput', 'Discus']
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# There are 101 players with a Shotput (predictor) value and 291 players with NaNs for Shotput.
# True
# [2.18909926]
# The RMSE of the model on the training data is 223.07499449897426. The average Discus of the training data is 1132.8563224550264. On average, predictions are 0.1969137569145095 from the actual values in the training data
# 100 Meter
# There are 298 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 317 NaN values for this metric
# There are 0 NaN values for this metric
# 110 Meter Hurdles
# There are 556 NaN values for this metric
# There are 0 NaN values for this metric
# 300 Meter Hurdles
# There are 562 NaN values for this metric
# There are 0 NaN values for this metric
# High Jump
# There are 532 NaN values for this metric
# There are 0 NaN values for this metric
# Long Jump
# There are 459 NaN values for this metric
# There are 0 NaN values for this metric
# Triple Jump
# There are 537 NaN values for this metric
# There are 0 NaN values for this metric
# Shotput
# There are 315 NaN values for this metric
# There are 0 NaN values for this metric
# Discus
# There are 392 NaN values for this metric
# There are 0 NaN values for this metric
# QB
# {'100 Meter': 'There are 147 NaNs out of 350 players', '200 Meter': 'There are 135 NaNs out of 350 players', '110 Meter Hurdles': 'There are 307 NaNs out of 350 players', '300 Meter Hurdles': 'There are 298 NaNs out of 350 players', 'High Jump': 'There are 274 NaNs out of 350 players', 'Long Jump': 'There are 214 NaNs out of 350 players', 'Triple Jump': 'There are 277 NaNs out of 350 players', 'Shotput': 'There are 312 NaNs out of 350 players', 'Discus': 'There are 311 NaNs out of 350 players'}
# <ipython-input-150-ed9428628d98>:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[metric] = completed_metrics[metric]
# 100 Meter ['200 Meter' '300 Meter Hurdles' '110 Meter Hurdles']
# There are 203 players with metric and 147 NaNs.
# ['200 Meter', '100 Meter']
# There are 68 players with a 200 Meter (predictor) value and 79 players with NaNs for 200 Meter.
# True
# [0.26479812]
# The RMSE of the model on the training data is 0.4744841116237274. The average 100 Meter of the training data is 12.371360544217689. On average, predictions are 0.038353430079725456 from the actual values in the training data
# 200 Meter ['100 Meter' '110 Meter Hurdles' '300 Meter Hurdles']
# There are 215 players with metric and 135 NaNs.
# ['100 Meter', '200 Meter']
# There are 56 players with a 100 Meter (predictor) value and 79 players with NaNs for 100 Meter.
# True
# [2.02138766]
# The RMSE of the model on the training data is 1.310958760771062. The average 200 Meter of the training data is 25.51748299319727. On average, predictions are 0.05137492444378436 from the actual values in the training data
# 110 Meter Hurdles ['300 Meter Hurdles' '100 Meter' '200 Meter']
# There are 43 players with metric and 307 NaNs.
# ['300 Meter Hurdles', '110 Meter Hurdles']
# There are 21 players with a 300 Meter Hurdles (predictor) value and 286 players with NaNs for 300 Meter Hurdles.
# True
# [0.4923124]
# The RMSE of the model on the training data is 1.3710642033790537. The average 110 Meter Hurdles of the training data is 18.233225806451614. On average, predictions are 0.0751959207840183 from the actual values in the training data
# 300 Meter Hurdles ['110 Meter Hurdles' '100 Meter' '200 Meter']
# There are 52 players with metric and 298 NaNs.
# ['110 Meter Hurdles', '300 Meter Hurdles']
# There are 12 players with a 110 Meter Hurdles (predictor) value and 286 players with NaNs for 110 Meter Hurdles.
# True
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# [1.29451862]
# The RMSE of the model on the training data is 2.22326666008439. The average 300 Meter Hurdles of the training data is 45.885806451612915. On average, predictions are 0.04845216488521018 from the actual values in the training data
# High Jump ['Shotput' 'Long Jump' 'Triple Jump']
# There are 76 players with metric and 274 NaNs.
# ['Shotput', 'High Jump']
# There are 33 players with a Shotput (predictor) value and 241 players with NaNs for Shotput.
# True
# [0.03302169]
# The RMSE of the model on the training data is 2.730364680741326. The average High Jump of the training data is 62.95. On average, predictions are 0.04337354536523155 from the actual values in the training data
# Long Jump ['Triple Jump' 'High Jump' 'Discus']
# There are 136 players with metric and 214 NaNs.
# ['Triple Jump', 'Long Jump']
# There are 17 players with a Triple Jump (predictor) value and 197 players with NaNs for Triple Jump.
# True
# [0.26460737]
# The RMSE of the model on the training data is 18.26045643927761. The average Long Jump of the training data is 217.26785714285714. On average, predictions are 0.08404582564309578 from the actual values in the training data
# Triple Jump ['Long Jump' 'High Jump']
# There are 73 players with metric and 277 NaNs.
# ['Long Jump', 'Triple Jump']
# There are 80 players with a Long Jump (predictor) value and 197 players with NaNs for Long Jump.
# True
# [1.12009279]
# The RMSE of the model on the training data is 37.56969399175379. The average Triple Jump of the training data is 447.25. On average, predictions are 0.08400155168642547 from the actual values in the training data
# Shotput ['Discus' 'High Jump']
# There are 38 players with metric and 312 NaNs.
# ['Discus', 'Shotput']
# There are 13 players with a Discus (predictor) value and 299 players with NaNs for Discus.
# True
# [0.19667434]
# The RMSE of the model on the training data is 48.553911240466064. The average Shotput of the training data is 429.25. On average, predictions are 0.11311336340236706 from the actual values in the training data
# Discus ['Shotput' 'Long Jump']
# There are 39 players with metric and 311 NaNs.
# ['Shotput', 'Discus']
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[metric] = completed_metrics[metric]
# There are 12 players with a Shotput (predictor) value and 299 players with NaNs for Shotput.
# True
# [2.82242605]
# The RMSE of the model on the training data is 183.9338454373405. The average Discus of the training data is 1214.2211538461538. On average, predictions are 0.15148298549626946 from the actual values in the training data
# 100 Meter
# There are 147 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 135 NaN values for this metric
# There are 0 NaN values for this metric
# 110 Meter Hurdles
# There are 307 NaN values for this metric
# There are 0 NaN values for this metric
# 300 Meter Hurdles
# There are 298 NaN values for this metric
# There are 0 NaN values for this metric
# High Jump
# There are 274 NaN values for this metric
# There are 0 NaN values for this metric
# Long Jump
# There are 214 NaN values for this metric
# There are 0 NaN values for this metric
# Triple Jump
# There are 277 NaN values for this metric
# There are 0 NaN values for this metric
# Shotput
# There are 312 NaN values for this metric
# There are 0 NaN values for this metric
# Discus
# There are 311 NaN values for this metric
# There are 0 NaN values for this metric
# DE
# {'100 Meter': 'There are 210 NaNs out of 276 players', '200 Meter': 'There are 207 NaNs out of 276 players', '110 Meter Hurdles': 'There are 251 NaNs out of 276 players', '300 Meter Hurdles': 'There are 255 NaNs out of 276 players', 'High Jump': 'There are 247 NaNs out of 276 players', 'Long Jump': 'There are 251 NaNs out of 276 players', 'Triple Jump': 'There are 260 NaNs out of 276 players', 'Shotput': 'There are 69 NaNs out of 276 players', 'Discus': 'There are 101 NaNs out of 276 players'}
# 100 Meter ['200 Meter' '110 Meter Hurdles']
# There are 66 players with metric and 210 NaNs.
# ['200 Meter', '100 Meter']
# There are 21 players with a 200 Meter (predictor) value and 189 players with NaNs for 200 Meter.
# True
# [0.32904753]
# The RMSE of the model on the training data is 0.4249246560098252. The average 100 Meter of the training data is 12.728541666666663. On average, predictions are 0.033383608832629454 from the actual values in the training data
# 200 Meter ['100 Meter']
# There are 69 players with metric and 207 NaNs.
# ['100 Meter', '200 Meter']
# There are 18 players with a 100 Meter (predictor) value and 189 players with NaNs for 100 Meter.
# True
# [2.33470611]
# The RMSE of the model on the training data is 1.1318756594849113. The average 200 Meter of the training data is 26.500416666666663. On average, predictions are 0.04271161747085404 from the actual values in the training data
# 110 Meter Hurdles ['100 Meter']
# There are 25 players with metric and 251 NaNs.
# ['100 Meter', '110 Meter Hurdles']
# There are 59 players with a 100 Meter (predictor) value and 192 players with NaNs for 100 Meter.
# True
# [0.7086041]
# The RMSE of the model on the training data is 1.0048926346820966. The average 110 Meter Hurdles of the training data is 20.62285714285714. On average, predictions are 0.04872712969503101 from the actual values in the training data
# 300 Meter Hurdles []
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# High Jump ['Long Jump']
# There are 29 players with metric and 247 NaNs.
# ['Long Jump', 'High Jump']
# There are 13 players with a Long Jump (predictor) value and 234 players with NaNs for Long Jump.
# True
# [0.19201309]
# The RMSE of the model on the training data is 4.2562206246584235. The average High Jump of the training data is 62.4375. On average, predictions are 0.068167697692227 from the actual values in the training data
# Long Jump ['High Jump' 'Triple Jump' 'Discus']
# There are 25 players with metric and 251 NaNs.
# ['High Jump', 'Long Jump']
# There are 17 players with a High Jump (predictor) value and 234 players with NaNs for High Jump.
# True
# [2.49799903]
# The RMSE of the model on the training data is 15.351642556603869. The average Long Jump of the training data is 206.35416666666666. On average, predictions are 0.07439463328793394 from the actual values in the training data
# Triple Jump ['Long Jump']
# There are 16 players with metric and 260 NaNs.
# ['Long Jump', 'Triple Jump']
# There are 13 players with a Long Jump (predictor) value and 247 players with NaNs for Long Jump.
# True
# [1.06624159]
# The RMSE of the model on the training data is 24.78110156692209. The average Triple Jump of the training data is 438.7083333333333. On average, predictions are 0.05648650751316651 from the actual values in the training data
# Shotput ['Discus']
# There are 207 players with metric and 69 NaNs.
# ['Discus', 'Shotput']
# There are 14 players with a Discus (predictor) value and 55 players with NaNs for Discus.
# True
# [0.15098114]
# The RMSE of the model on the training data is 55.32460780939346. The average Shotput of the training data is 440.027950310559. On average, predictions are 0.12572975823546426 from the actual values in the training data
# Discus ['Shotput' 'Long Jump']
# There are 175 players with metric and 101 NaNs.
# ['Shotput', 'Discus']
# There are 46 players with a Shotput (predictor) value and 55 players with NaNs for Shotput.
# True
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[metric] = completed_metrics[metric]
# [2.58717616]
# The RMSE of the model on the training data is 229.01820115624517. The average Discus of the training data is 1171.552795031056. On average, predictions are 0.1954826125869763 from the actual values in the training data
# 100 Meter
# There are 210 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 207 NaN values for this metric
# There are 0 NaN values for this metric
# 110 Meter Hurdles
# There are 251 NaN values for this metric
# There are 0 NaN values for this metric
# 300 Meter Hurdles
# There are 255 NaN values for this metric
# There are 0 NaN values for this metric
# High Jump
# There are 247 NaN values for this metric
# There are 0 NaN values for this metric
# Long Jump
# There are 251 NaN values for this metric
# There are 0 NaN values for this metric
# Triple Jump
# There are 260 NaN values for this metric
# There are 0 NaN values for this metric
# Shotput
# There are 69 NaN values for this metric
# There are 0 NaN values for this metric
# Discus
# There are 101 NaN values for this metric
# There are 0 NaN values for this metric
# CB
# {'100 Meter': 'There are 171 NaNs out of 618 players', '200 Meter': 'There are 161 NaNs out of 618 players', '110 Meter Hurdles': 'There are 547 NaNs out of 618 players', '300 Meter Hurdles': 'There are 538 NaNs out of 618 players', 'High Jump': 'There are 522 NaNs out of 618 players', 'Long Jump': 'There are 343 NaNs out of 618 players', 'Triple Jump': 'There are 504 NaNs out of 618 players', 'Shotput': 'There are 608 NaNs out of 618 players', 'Discus': 'There are 609 NaNs out of 618 players'}
# 100 Meter ['200 Meter' '300 Meter Hurdles' '110 Meter Hurdles']
# There are 447 players with metric and 171 NaNs.
# ['200 Meter', '100 Meter']
# ...
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# High Jump []
# Long Jump []
# Triple Jump []
# Shotput ['Discus']
# There are 11 players with metric and 2 NaNs.
# ['Discus', 'Shotput']
# There are 0 players with a Discus (predictor) value and 2 players with NaNs for Discus.
# True
# [0.25712263]
# The RMSE of the model on the training data is 58.74507746150331. The average Shotput of the training data is 423.65. On average, predictions are 0.1386641743455761 from the actual values in the training data
# Discus ['Shotput']
# There are 10 players with metric and 3 NaNs.
# ['Shotput', 'Discus']
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-150-ed9428628d98>:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric_with_predictor_nulls[metric] = metric_mean
# <ipython-input-150-ed9428628d98>:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[metric] = completed_metrics[metric]
# There are 1 players with a Shotput (predictor) value and 2 players with NaNs for Shotput.
# True
# [2.52123532]
# The RMSE of the model on the training data is 183.95348440201985. The average Discus of the training data is 1162.6. On average, predictions are 0.15822594564082218 from the actual values in the training data
# 100 Meter
# There are 12 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 11 NaN values for this metric
# There are 0 NaN values for this metric
# 110 Meter Hurdles
# There are 13 NaN values for this metric
# There are 13 NaN values for this metric
# 300 Meter Hurdles
# There are 13 NaN values for this metric
# There are 13 NaN values for this metric
# High Jump
# There are 13 NaN values for this metric
# There are 13 NaN values for this metric
# Long Jump
# There are 12 NaN values for this metric
# There are 0 NaN values for this metric
# Triple Jump
# There are 11 NaN values for this metric
# There are 0 NaN values for this metric
# Shotput
# There are 2 NaN values for this metric
# There are 0 NaN values for this metric
# Discus
# There are 3 NaN values for this metric
# There are 0 NaN values for this metric
# P
# {'100 Meter': 'There are 1 NaNs out of 5 players', '200 Meter': 'There are 1 NaNs out of 5 players', '110 Meter Hurdles': 'There are 5 NaNs out of 5 players', '300 Meter Hurdles': 'There are 5 NaNs out of 5 players', 'High Jump': 'There are 4 NaNs out of 5 players', 'Long Jump': 'There are 0 NaNs out of 5 players', 'Triple Jump': 'There are 1 NaNs out of 5 players', 'Shotput': 'There are 5 NaNs out of 5 players', 'Discus': 'There are 4 NaNs out of 5 players'}
# 100 Meter ['Triple Jump']
# There are 4 players with metric and 1 NaNs.
# ['Triple Jump', '100 Meter']
# There are 1 players with a Triple Jump (predictor) value and 0 players with NaNs for Triple Jump.
# True
# [0.05165933]
# The RMSE of the model on the training data is 0.7992537963936442. The average 100 Meter of the training data is 12.903333333333334. On average, predictions are 0.06194165304006542 from the actual values in the training data
# 200 Meter ['Long Jump' 'Triple Jump']
# There are 4 players with metric and 1 NaNs.
# ['Long Jump', '200 Meter']
# There are 1 players with a Long Jump (predictor) value and 0 players with NaNs for Long Jump.
# True
# [0.15317099]
# The RMSE of the model on the training data is 1.3470338556255637. The average 200 Meter of the training data is 27.2425. On average, predictions are 0.04944604407178356 from the actual values in the training data
# 110 Meter Hurdles []
# 300 Meter Hurdles []
# High Jump []
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# Triple Jump ['Long Jump' '200 Meter' '100 Meter']
# There are 4 players with metric and 1 NaNs.
# ['Long Jump', 'Triple Jump']
# There are 1 players with a Long Jump (predictor) value and 0 players with NaNs for Long Jump.
# True
# [2.29574556]
# The RMSE of the model on the training data is 18.150519181307494. The average Triple Jump of the training data is 471.75. On average, predictions are 0.03847486842884471 from the actual values in the training data
# Shotput []
# Discus []
# 100 Meter
# There are 1 NaN values for this metric
# There are 0 NaN values for this metric
# 200 Meter
# There are 1 NaN values for this metric
# There are 0 NaN values for this metric
# 110 Meter Hurdles
# There are 5 NaN values for this metric
# There are 5 NaN values for this metric
# 300 Meter Hurdles
# There are 5 NaN values for this metric
# There are 5 NaN values for this metric
# High Jump
# There are 4 NaN values for this metric
# There are 0 NaN values for this metric
# Triple Jump
# There are 1 NaN values for this metric
# There are 0 NaN values for this metric
# Shotput
# There are 5 NaN values for this metric
# There are 5 NaN values for this metric
# Discus
# There are 4 NaN values for this metric
# There are 0 NaN values for this metric
# Wall time: 18.3 s
# <ipython-input-150-ed9428628d98>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles[metric + " " + "Percentile"] = only_percentiles.mean(axis=1)
# <ipython-input-150-ed9428628d98>:100: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_percentiles['Predicted' + " " + metric] = only_percentiles.apply(lambda x: percentile_to_value(metric, x[metric + " " + "Percentile"], metric_dict), axis = 1)
# <ipython-input-150-ed9428628d98>:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_metric[metric] = only_percentiles['Predicted' + " " + metric]
# <ipython-input-150-ed9428628d98>:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1[metric] = completed_metrics[metric]

# %% [markdown]
# ANY NaNs come from events in which NO player in that position has a recorded time/value. THis is because we can't generate the metric dict (the percentile values) for that event since no players have anything recorded. THus, while we get a percentile, we don't get a percentile to value mapping (all NaNs) because no values exist!

# %%
cleaned_tf_metrics_position_dataframes['OL'].isna().sum()
# Out:
# Zcruit ID              0
# Full Name              0
# Position               0
# 100 Meter              0
# 200 Meter              0
# 110 Meter Hurdles    314
# 300 Meter Hurdles      0
# High Jump              0
# Long Jump              0
# Triple Jump          314
# Shotput                0
# Discus                 0
# dtype: int64

# %%
cleaned_tf_metrics_position_dataframes['OL']
# Out:
#                                  Zcruit ID          Full Name Position  \
# 839   02059551-326b-4e7c-a43e-451a7485086c        Jared Oakes       OL
# 880   e0cf4e50-355c-4cf7-b70e-afbf61d0b9c2   Cody Breidenbach       OL
# 888   3d2bc3f0-4833-42d5-9ffd-25cb8d191193   Anthony Dantzler       OL
# 904   aba375f5-4307-447c-982e-0128e1c07f3f     Jeremiah Burch       OL
# 918   f496799b-8459-455c-9e06-5856cb03788b     Micah Harrison       OL
# ...                                    ...                ...      ...
# 7602  6f112ede-a5c4-4a51-83f7-9f9b8fa54883     Gage Stanaland       OL
# 7604  638f03cf-eefa-4aa3-8db0-dff7823ea283     Matthew Miller       OL
# 7615  73a3e865-ff9a-4190-9899-8cddaa22fd30  Sylvester Gethers       OL
# 7616  8ca463da-49bc-4b1e-8065-08ed82a6306f         Danny Dill       OL
# 7617  4ca0fd32-9c8d-494c-ba1b-bf8fbc14b534     Bryson Dickens       OL
#
#       100 Meter  200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  \
# 839        13.7      27.35                NaN              49.39       60.0
# 880        13.7      27.35                NaN              49.39       60.0
# 888        13.7      27.35                NaN              49.39       60.0
# 904        13.7      27.35                NaN              49.39       60.0
# 918        13.7      27.35                NaN              49.39       60.0
# ...         ...        ...                ...                ...        ...
# 7602       13.7      27.35                NaN              49.39       60.0
# 7604       13.7      27.35                NaN              49.39       60.0
# 7615       13.7      27.35                NaN              49.39       60.0
# 7616       13.7      27.35                NaN              49.39       60.0
# 7617       13.7      27.35                NaN              49.39       60.0
#
#       Long Jump  Triple Jump  Shotput       Discus
# 839       124.5          NaN   544.75  1376.642583
# 880       124.5          NaN   559.00  1251.000000
# 888       124.5          NaN   501.75  1268.717661
# 904       124.5          NaN   485.00  1413.000000
# 918       124.5          NaN   467.50   927.000000
# ...         ...          ...      ...          ...
# 7602      124.5          NaN   421.75  1265.000000
# 7604      124.5          NaN   400.00   811.000000
# 7615      124.5          NaN   332.00   871.000000
# 7616      124.5          NaN   366.50   876.750000
# 7617      124.5          NaN   368.50   860.000000
#
# [314 rows x 12 columns]

# %%
column_names = cleaned_tf_metrics_position_dataframes['QB'].columns
df = pd.DataFrame(columns = column_names)
for position in positions:
    df = df.append(cleaned_tf_metrics_position_dataframes[position])

# %%
df = df.sort_index()

# %%
df
# Out:
#                                  Zcruit ID              Full Name Position  \
# 3     eb32fcc6-a8f5-41df-b524-a4fc824a14f3            Mark Phifer       CB
# 4     9712f1c5-6319-49ba-b8df-70b4102d3737         Gerimiah Brown       RB
# 5     c98e0321-f3a4-4b85-ab2a-bbd16d46ea86            Isaac Jones       RB
# 6     7e546367-e3bd-44b4-a1e7-1b2cf182d224           David Godsey       WR
# 7     20396bae-d68b-4b18-858e-e341d20f2b85             Hunt Young       QB
# ...                                    ...                    ...      ...
# 7679  74467a51-ab05-4f1b-bd3d-8ec717c90b43  Savonte Sanford-Paige        S
# 7681  f1873c0b-a931-4604-a33c-4439e32789eb           Jerod Thomas       QB
# 7682  1f7b327a-510e-4070-a3cd-bc0d2433010f          Tyler Bradley       RB
# 7684  fb194f5e-bc21-4852-838b-443eebac9aaf        Isaiah Robinson       WR
# 7685  167feedc-df71-41cd-a151-d34f8b20decf          Jordan Garcia       RB
#
#       100 Meter  200 Meter  110 Meter Hurdles  300 Meter Hurdles  High Jump  \
# 3         12.51   24.94000             18.455             45.845      66.00
# 4         11.74   25.77000             17.520             47.840      63.00
# 5         11.73   23.28000             17.520             44.910      63.00
# 6         11.17   23.18000             17.910             44.810      64.00
# 7         12.22   24.68000             17.650             45.240      64.00
# ...         ...        ...                ...                ...        ...
# 7679      11.58   23.44000             17.675             46.575      59.75
# 7681      12.26   25.29238             17.650             45.240      64.00
# 7682      11.51   23.05000             17.520             44.910      63.00
# 7684      11.53   24.10000             17.910             44.810      64.00
# 7685      12.15   26.05000             17.520             44.910      64.00
#
#       Long Jump  Triple Jump     Shotput  Discus
# 3        212.50   450.875000  378.750000  1103.0
# 4        207.50   438.017729  436.750000   831.0
# 5        194.50   423.156296  436.750000   831.0
# 6        222.75   461.500000  471.597175   982.0
# 7        217.75   451.750000  430.250000  1173.5
# ...         ...          ...         ...     ...
# 7679     217.00   468.250000  453.000000  1226.0
# 7681     217.75   451.750000  430.250000  1173.5
# 7682     199.25   433.500000  436.750000   831.0
# 7684     234.00   471.143387  432.601133   982.0
# 7685     201.00   430.587012  436.750000   831.0
#
# [6948 rows x 12 columns]

# %% [markdown]
# Lost 400 rows?

# %%
df.to_csv('filled_tf_data.csv')

# %%
still_nan_events_for_positions = {}
for position in positions:
    series = df[df['Position'] == position].isna().sum() > 0
    still_nan_events_for_positions[position] = series[series].index.values

# %%
still_nan_events_for_positions
# Out:
# {'WR': array([], dtype=object),
#  'RB': array([], dtype=object),
#  'LB': array([], dtype=object),
#  'QB': array([], dtype=object),
#  'DE': array([], dtype=object),
#  'CB': array([], dtype=object),
#  'OL': array(['110 Meter Hurdles', 'Triple Jump'], dtype=object),
#  'DT': array(['High Jump'], dtype=object),
#  'S': array([], dtype=object),
#  'OT': array(['110 Meter Hurdles', '300 Meter Hurdles', 'Long Jump',
#         'Triple Jump'], dtype=object),
#  'OG': array(['110 Meter Hurdles', '300 Meter Hurdles', 'High Jump', 'Long Jump',
#         'Triple Jump'], dtype=object),
#  'TE': array([], dtype=object),
#  'ATH': array([], dtype=object),
#  'DB': array([], dtype=object),
#  'DL': array([], dtype=object),
#  'OC': array(['300 Meter Hurdles', 'High Jump', 'Long Jump', 'Triple Jump'],
#        dtype=object),
#  'K': array(['300 Meter Hurdles'], dtype=object),
#  'FB': array(['300 Meter Hurdles'], dtype=object),
#  'LS': array(['110 Meter Hurdles', '300 Meter Hurdles', 'High Jump'],
#        dtype=object),
#  'P': array(['110 Meter Hurdles', '300 Meter Hurdles', 'Shotput'], dtype=object)}

# %% [markdown]
# WR 	"100 Meter"	"200 Meter"	"110 Meter Hurdles"	"300 Meter Hurdles"	"High Jump"	"Long Jump"
# RB 	"100 Meter"	"110 Meter Hurdles"	"Long Jump"
# LB 	"Shotput"	"Discus"	"Hammer"
# QB 	"High Jump"
# DE 	"100 Meter"	"Shotput"	"Discus"	"Hammer"
# CB 	"100 Meter"	"200 Meter"	"110 Meter Hurdles"	"300 Meter Hurdles"	"High Jump"	"Long Jump"	"Triple Jump"
# OL	"High Jump"	"Long Jump"	"Triple Jump"	"Shotput"	"Discus"	"Hammer"
# DT 	"110 Meter Hurdles"	"300 Meter Hurdles"	"High Jump"	"Long Jump"	"Triple Jump"	"Shotput"	"Discus"	"Hammer"
#
# S 	"100 Meter"	"200 Meter"	"110 Meter Hurdles"	"300 Meter Hurdles"	"High Jump"	"Long Jump"	"Triple Jump"
# OT 	"High Jump"	"Long Jump"	"Triple Jump"	"Shotput"	"Discus"	"Hammer"
# OG
# TE 	"100 Meter"	"200 Meter"
# ATH	"100 Meter"	"200 Meter"	"110 Meter Hurdles"	"300 Meter Hurdles"	"High Jump"
# DB 	"100 Meter"	"200 Meter"
# DL	"High Jump"	"Shotput"	"Discus"
# OC 	"Shotput"	"Discus"	"Hammer"
# K
# FB
# LS
# P

# %%
df[df['Position'] == 'OC'].isna().sum()
# Out:
# Zcruit ID             0
# Full Name             0
# Position              0
# 100 Meter             0
# 200 Meter             0
# 110 Meter Hurdles     0
# 300 Meter Hurdles    98
# High Jump            98
# Long Jump            98
# Triple Jump          98
# Shotput               0
# Discus                0
# dtype: int64
